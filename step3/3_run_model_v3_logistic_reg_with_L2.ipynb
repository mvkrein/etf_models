# %%
import pandas as pd
import numpy as np
import os
import sklearn
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
import xgboost
from xgboost import XGBClassifier
# %matplotlib notebook

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 500)
pd.options.mode.chained_assignment = None  # default='warn'

# %%
data_path = '/home/mvkrein/etf_model/data'
etf_data_file = os.path.join(data_path,'etf_new_var_20180910.csv')
etf_data = pd.read_csv(etf_data_file,index_col=0)

# %%
etf_study_file = os.path.join(data_path,'ETF_list_min_6yr_history.csv')
etf_list = pd.read_csv(etf_study_file,index_col=0)
etf_data.sort_values(['Date','sym'],ascending=True,inplace=True)
etf_data.reset_index(drop=True,inplace=True)

# %%
drop_columns = ['Date','sym','p', 'v', 'p_L05', 'v_L05', 'p_L10', 'v_L10', 'p_L21', 'v_L21', 'p_L42', 'v_L42', 'p_L63', \
                'v_L63', 'p_L84', 'v_L84', 'p_L126', 'v_L126', 'p_L189', 'v_L189', 'p_L252', 'v_L252',\
                'p_L-21', 'v_L-21', 'delta_p_L05', 'delta_p_L10', 'delta_p_L21', 'delta_p_L42', 'delta_p_L63', \
                'delta_p_L84', 'delta_p_L126', 'delta_p_L189', 'delta_p_L252', 'delta_p_L-21', 'delta_v_L05',\
                'delta_v_L10', 'delta_v_L21', 'delta_v_L42', 'delta_v_L63', 'delta_v_L84', 'delta_v_L126', \
                'delta_v_L189', 'delta_v_L252','rank_p_L-21', 'ivv_delta_p_L-21', 'target']

rank_col = ['rank_p_L05','rank_p_L10','rank_p_L21','rank_p_L42',\
            'rank_p_L63','rank_p_L84','rank_p_L126','rank_p_L189','rank_p_L252']

# %%
all_columns = list(etf_data.columns)

# %%
include_columns = [x for x in all_columns if x not in drop_columns]
# include_columns = ['rank_p_L05','rank_p_L10','rank_p_L21','rank_p_L42',\
#             'rank_p_L63','rank_p_L84','rank_p_L126','rank_p_L189','rank_p_L252']
# include_columns = ['rank_p_L05','rank_p_L21','rank_p_L42','rank_p_L252']

# %%
len(include_columns)
# Out:
# 360

# %%
dates = list(etf_data['Date'].unique())
# dates[1671]

# %%
for i in range(0,1671):
    if dates[i] == '2018-07-09':
        print (i,dates[i])
# Out:
# 1638 2018-07-09

# %%
symbols = etf_list['Symbol'].unique()

# %%
len(symbols)
# Out:
# 153

# %%
#Each year has 252 trading dates.  Need two years to fully develop variables.
dt1 = 504 #This is the first day that all variables are developed
# dt1 = 504 + 21 + 273 #This is the first day that all variables are developed 2016-04-07
# make all dates relative to dt1
# for one year training - add 252
# to evaluate for one month outside the training window - add 273
# to predict for the first day outside of the evaluation window (have to lag 21) - add 294
dt_end = (len(dates) - 273 - 21) - 1
# dt2 = 1638 - 273 #restart for '2018-05-08'
# dt_end = dt1 + 1 #For testing on the first day only
etf_predict_file = os.path.join(data_path,'etf_pred_logistic_reg_L2_20180928.csv')

# %%
#Run grid search with cross validation to select best parameters
# i = dt1
# x_train = etf_data.loc[((etf_data['Date']>=dates[i]) & (etf_data['Date']<dates[i+252])),include_columns] #train with 12 mos
# y_train = etf_data.loc[((etf_data['Date']>=dates[i]) & (etf_data['Date']<dates[i+252])),['target']] #train with 12 mos
# x_train_nmpy = x_train.as_matrix()
# y_train_nmpy = np.ravel(y_train.as_matrix())

# param_grid = { 
# 'n_estimators': [100,300,500,700,1000],
# 'max_features': ['auto','log2',None],
# 'max_depth' : [4,5,6,7,8,None],
# 'criterion' :['gini','entropy']}

# rfc=RandomForestClassifier(n_jobs=32,random_state=54321)
# CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5, n_jobs=32, verbose=1)
# CV_rfc.fit(x_train_nmpy, y_train_nmpy)

#print(CV_rfc.best_params_)
#{'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'n_estimators': 700}

# %%
# for i in range(dt2,dt_end,21): #for restart
for i in range(dt1,dt_end,21):
    print("Building model to predict for ",dates[i+273])
    x_train = etf_data.loc[((etf_data['Date']>=dates[i]) & (etf_data['Date']<dates[i+252])),include_columns] #train with 12 mos
    y_train = etf_data.loc[((etf_data['Date']>=dates[i]) & (etf_data['Date']<dates[i+252])),['target']] #train with 12 mos

#predict one day
    x_test = etf_data.loc[(etf_data['Date']==dates[i+273]),include_columns] #predict one day-must be 21 days removed from training
    y_test = etf_data.loc[(etf_data['Date']==dates[i+273]),['target']] #predict if etf >= market
    returns = etf_data.loc[(etf_data['Date']==dates[i+273]),['delta_p_L-21']]
    mkt_return = etf_data.loc[(etf_data['Date']==dates[i+273]),['ivv_delta_p_L-21']]
    x_train_nmpy = x_train.as_matrix()
    y_train_nmpy = np.ravel(y_train.as_matrix())
#     x_eval_nmpy = x_eval.as_matrix()
#     y_eval_nmpy = y_eval.as_matrix()
    x_test_nmpy = x_test.as_matrix()
    y_test_nmpy = np.ravel(y_test.as_matrix())
    returns_nmpy = returns.as_matrix()
    mkt_return_nmpy = mkt_return.as_matrix()
    
    lr = LogisticRegression(penalty='l2',C=0.8,random_state=54321)

    lr.fit(x_train_nmpy, y_train_nmpy)
    
    y_pred_model = lr.predict_proba(x_test_nmpy)[:,1]
    y_train_model = lr.predict(x_train_nmpy)
    y_test_model = lr.predict(x_test_nmpy)

    y_check = np.column_stack((y_test_nmpy, y_pred_model,mkt_return_nmpy,returns_nmpy))
    y_check_df = pd.DataFrame(y_check,columns=['true_value','pred_value','mkt_return','returns'])
    y_check_df.sort_values('pred_value',inplace=True,ascending=False)
    y_check_df.reset_index(inplace=True,drop=True)
    t_hold = y_check_df['pred_value'][14]
    
    model_coef = pd.DataFrame({'Feature':include_columns,'Coefficient': np.ravel(lr.coef_)})
    model_coef.sort_values(by='Coefficient',inplace=True,ascending=False) 
    model_coef.reset_index(drop=True,inplace=True)
    print('*****************************')
    print('Variables with largest coefficients:')
    print(model_coef.head(5))
    print(model_coef.tail(5))
    print('*****************************')
    print('roc_auc_score on training: {:.4f}'.format(roc_auc_score(y_train_nmpy,y_train_model)))
    print('roc_auc_score on testing: {:.4f}'.format(roc_auc_score(y_test_nmpy,y_test_model)))
    print('*****************************')
    print('Confusion Matrix Threshold: {:.6f}'.format(t_hold))
    print('*****************************')
    print('Model Eval Results:')
    print('*****************************')
    confusion = confusion_matrix(y_test_nmpy, (y_pred_model>=t_hold).astype(int))
#     fpr, tpr, thresholds = roc_curve(y_test_nmpy, (y_model_array>0.5).astype(int), pos_label=1)
    precision = confusion[1,1]/(confusion[1,1]+confusion[0,1])
    print('Confusion Matrix:\n',confusion)
    print('Precision:',round(precision,4))

    print("Model Top Five Picks")
    print(" Avg rtn top 5:", round(y_check_df['returns'][0:5].mean(),4))
    print(y_check_df.head(5))
    print("Model 2nd Five Picks")
    print(" Avg rtn 2nd 5:", round(y_check_df['returns'][5:10].mean(),4))
    print(y_check_df.iloc[5:10,])
    print("Model 3rd Five Picks")
    print(" Avg rtn 3rd 5:", round(y_check_df['returns'][10:15].mean(),4))
    print(y_check_df.iloc[10:15,])    
    print("Model Bottom Five Picks")
    print(" Avg rtn bottom 5:", round(y_check_df['returns'][-5:].mean(),4))
    print(y_check_df.tail(5))
    print('********************************************************')
    if i == dt1:
        predict_data = etf_data.loc[(etf_data['Date']==dates[i+273]),['Date','sym','rank_p_L-21']]
        predict_data['predict'] = y_pred_model
        predict_data.to_csv(etf_predict_file)
    else:
        predict_data = etf_data.loc[(etf_data['Date']==dates[i+273]),['Date','sym','rank_p_L-21']]
        predict_data['predict'] = y_pred_model
        predict_data.to_csv(etf_predict_file,header=False,mode='a')
# Out:
# Building model to predict for  2015-02-05
# *****************************
# Variables with largest coefficients:
#    Coefficient                 Feature
# 0     3.725513      w63_rank_p_L42_avg
# 1     3.725513      w63_rank_v_L42_avg
# 2     3.472036  ivv_w42_rank_p_L84_avg
# 3     3.472036  ivv_w42_rank_v_L84_avg
# 4     2.521587     w42_rank_v_L252_avg
#      Coefficient                  Feature
# 355    -3.168311  ivv_w21_rank_p_L189_avg
# 356    -3.365727      w63_rank_p_L252_avg
# 357    -3.365727      w63_rank_v_L252_avg
# 358    -3.388579       w84_rank_v_L84_avg
# 359    -3.388579       w84_rank_p_L84_avg
# *****************************
# roc_auc_score on training: 0.6664
# roc_auc_score on testing: 0.5000
# *****************************
# Confusion Matrix Threshold: 0.314949
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[103   3]
#  [ 35  12]]
# Precision: 0.8
# Model Top Five Picks
#  Avg rtn top 5: 0.0483
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.433987    0.010741  0.060291
# 1         1.0    0.433434    0.010741  0.031835
# 2         1.0    0.408952    0.010741  0.040959
# 3         1.0    0.394001    0.010741  0.036401
# 4         1.0    0.373348    0.010741  0.071770
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0312
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.341313    0.010741  0.008588
# 6         1.0    0.340281    0.010741  0.040056
# 7         1.0    0.339506    0.010741  0.012487
# 8         1.0    0.338917    0.010741  0.069374
# 9         1.0    0.337016    0.010741  0.025627
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.007
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.336776    0.010741  0.012149
# 11         1.0    0.333162    0.010741  0.026210
# 12         0.0    0.329561    0.010741  0.010065
# 13         0.0    0.316644    0.010741 -0.025338
# 14         1.0    0.314949    0.010741  0.011787
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0141
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.067530    0.010741 -0.006699
# 149         0.0    0.066123    0.010741 -0.006829
# 150         1.0    0.065364    0.010741  0.012313
# 151         0.0    0.055968    0.010741 -0.055893
# 152         0.0    0.039671    0.010741 -0.013518
# ********************************************************
# Building model to predict for  2015-03-09
# *****************************
# Variables with largest coefficients:
#    Coefficient                 Feature
# 0     3.438566  ivv_w42_rank_v_L84_avg
# 1     3.438566  ivv_w42_rank_p_L84_avg
# 2     3.306513     w42_rank_v_L252_avg
# 3     3.306513     w42_rank_p_L252_avg
# 4     3.239200      w63_rank_v_L42_avg
#      Coefficient              Feature
# 355    -2.868876   w42_rank_p_L05_avg
# 356    -3.149515   w84_rank_v_L84_avg
# 357    -3.149515   w84_rank_p_L84_avg
# 358    -4.151340  w63_rank_p_L252_avg
# 359    -4.151340  w63_rank_v_L252_avg
# *****************************
# roc_auc_score on training: 0.6743
# roc_auc_score on testing: 0.5410
# *****************************
# Confusion Matrix Threshold: 0.469352
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[ 18   1]
#  [120  14]]
# Precision: 0.9333
# Model Top Five Picks
#  Avg rtn top 5: 0.091
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.669098     0.00266  0.076116
# 1         1.0    0.663045     0.00266  0.082243
# 2         1.0    0.640033     0.00266  0.042591
# 3         1.0    0.625950     0.00266  0.075889
# 4         1.0    0.583854     0.00266  0.178278
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0698
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.570903     0.00266  0.130311
# 6         1.0    0.533523     0.00266  0.074383
# 7         1.0    0.532296     0.00266  0.094222
# 8         1.0    0.524209     0.00266  0.037737
# 9         1.0    0.513295     0.00266  0.012494
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0412
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.507046     0.00266  0.058454
# 11         1.0    0.497739     0.00266  0.084889
# 12         1.0    0.492703     0.00266  0.053008
# 13         1.0    0.479411     0.00266  0.011494
# 14         0.0    0.469352     0.00266 -0.001606
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0002
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.134333     0.00266 -0.025271
# 149         1.0    0.131842     0.00266  0.039362
# 150         0.0    0.110751     0.00266 -0.018820
# 151         1.0    0.091290     0.00266  0.030000
# 152         0.0    0.046966     0.00266 -0.024067
# ********************************************************
# Building model to predict for  2015-04-08
# *****************************
# Variables with largest coefficients:
#    Coefficient                 Feature
# 0     3.515608     w42_rank_v_L252_avg
# 1     3.515608     w42_rank_p_L252_avg
# 2     3.221680      w63_rank_p_L42_avg
# 3     3.221680      w63_rank_v_L42_avg
# 4     3.182461  ivv_w42_rank_p_L84_avg
#      Coefficient              Feature
# 355    -3.420534  w252_rank_p_L84_avg
# 356    -3.650973  w252_rank_v_L63_avg
# 357    -3.650973  w252_rank_p_L63_avg
# 358    -3.990248  w63_rank_v_L252_avg
# 359    -3.990248  w63_rank_p_L252_avg
# *****************************
# roc_auc_score on training: 0.7036
# roc_auc_score on testing: 0.5000
# *****************************
# Confusion Matrix Threshold: 0.175717
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[98  8]
#  [40  7]]
# Precision: 0.4667
# Model Top Five Picks
#  Avg rtn top 5: 0.0013
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.404580    0.004202  0.055012
# 1         0.0    0.358825    0.004202 -0.040441
# 2         1.0    0.276353    0.004202  0.015691
# 3         0.0    0.239699    0.004202 -0.022443
# 4         0.0    0.234772    0.004202 -0.001081
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0024
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.233027    0.004202 -0.018170
# 6         0.0    0.225756    0.004202  0.001100
# 7         1.0    0.215246    0.004202  0.023496
# 8         1.0    0.207899    0.004202  0.005074
# 9         0.0    0.204962    0.004202  0.000384
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0043
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.191246    0.004202  0.022573
# 11         0.0    0.183142    0.004202 -0.039707
# 12         1.0    0.178525    0.004202  0.020979
# 13         0.0    0.175724    0.004202 -0.001154
# 14         1.0    0.175717    0.004202  0.019034
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0356
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.008750    0.004202 -0.048323
# 149         0.0    0.007667    0.004202 -0.057728
# 150         1.0    0.006335    0.004202  0.022831
# 151         0.0    0.006017    0.004202 -0.028592
# 152         0.0    0.004067    0.004202 -0.066340
# ********************************************************
# Building model to predict for  2015-05-07
# *****************************
# Variables with largest coefficients:
#    Coefficient                 Feature
# 0     3.674329  ivv_w42_rank_v_L84_avg
# 1     3.674329  ivv_w42_rank_p_L84_avg
# 2     3.508543      w63_rank_v_L42_avg
# 3     3.508543      w63_rank_p_L42_avg
# 4     3.466259     w42_rank_v_L252_avg
#      Coefficient                 Feature
# 355    -2.535106    w126_rank_p_L189_avg
# 356    -2.679740  ivv_w63_rank_p_L21_avg
# 357    -2.679740  ivv_w63_rank_v_L21_avg
# 358    -4.003653     w63_rank_v_L252_avg
# 359    -4.003653     w63_rank_p_L252_avg
# *****************************
# roc_auc_score on training: 0.6993
# roc_auc_score on testing: 0.6064
# *****************************
# Confusion Matrix Threshold: 0.540428
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[90  5]
#  [48 10]]
# Precision: 0.6667
# Model Top Five Picks
#  Avg rtn top 5: 0.0081
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.825086   -0.001902  0.038891
# 1         0.0    0.803391   -0.001902 -0.069268
# 2         1.0    0.689350   -0.001902  0.035501
# 3         0.0    0.676428   -0.001902 -0.023092
# 4         1.0    0.655909   -0.001902  0.058227
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.011
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.623776   -0.001902 -0.022569
# 6         1.0    0.622834   -0.001902  0.060737
# 7         1.0    0.620544   -0.001902  0.018136
# 8         1.0    0.599045   -0.001902  0.001999
# 9         0.0    0.571279   -0.001902 -0.003366
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0159
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.555441   -0.001902 -0.003791
# 11         1.0    0.546812   -0.001902  0.006066
# 12         1.0    0.543863   -0.001902  0.004224
# 13         1.0    0.542394   -0.001902  0.045688
# 14         1.0    0.540428   -0.001902  0.027294
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0525
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.060376   -0.001902 -0.028465
# 149         0.0    0.055626   -0.001902 -0.029327
# 150         0.0    0.054937   -0.001902 -0.050082
# 151         0.0    0.039978   -0.001902 -0.086982
# 152         0.0    0.009753   -0.001902 -0.067742
# ********************************************************
# Building model to predict for  2015-06-08
# *****************************
# Variables with largest coefficients:
#    Coefficient                 Feature
# 0     4.163242  ivv_w42_rank_p_L84_avg
# 1     4.163242  ivv_w42_rank_v_L84_avg
# 2     3.092213      w63_rank_v_L42_avg
# 3     3.092213      w63_rank_p_L42_avg
# 4     2.981030     w42_rank_v_L252_avg
#      Coefficient                 Feature
# 355    -2.949286  ivv_w63_rank_v_L21_avg
# 356    -3.637342      w42_rank_p_L63_avg
# 357    -3.637342      w42_rank_v_L63_avg
# 358    -4.230600     w63_rank_v_L252_avg
# 359    -4.230600     w63_rank_p_L252_avg
# *****************************
# roc_auc_score on training: 0.7098
# roc_auc_score on testing: 0.4946
# *****************************
# Confusion Matrix Threshold: 0.261727
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[81 11]
#  [57  4]]
# Precision: 0.2667
# Model Top Five Picks
#  Avg rtn top 5: -0.1152
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.548020    -0.01377 -0.367158
# 1         1.0    0.465735    -0.01377 -0.011492
# 2         0.0    0.419437    -0.01377 -0.052173
# 3         0.0    0.399100    -0.01377 -0.127098
# 4         0.0    0.358971    -0.01377 -0.018068
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0405
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.337297    -0.01377 -0.039553
# 6         0.0    0.333736    -0.01377 -0.042537
# 7         0.0    0.321806    -0.01377 -0.064442
# 8         1.0    0.310638    -0.01377 -0.010439
# 9         0.0    0.301583    -0.01377 -0.045718
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0559
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.293649    -0.01377 -0.076194
# 11         0.0    0.284305    -0.01377 -0.086011
# 12         0.0    0.268977    -0.01377 -0.104046
# 13         1.0    0.263715    -0.01377 -0.011724
# 14         1.0    0.261727    -0.01377 -0.001540
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0247
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.037763    -0.01377  0.042595
# 149         1.0    0.036887    -0.01377  0.041074
# 150         0.0    0.036096    -0.01377 -0.063370
# 151         0.0    0.031049    -0.01377 -0.079822
# 152         0.0    0.030615    -0.01377 -0.063771
# ********************************************************
# Building model to predict for  2015-07-08
# *****************************
# Variables with largest coefficients:
#    Coefficient                 Feature
# 0     3.895743    w189_rank_v_L252_avg
# 1     3.895743    w189_rank_p_L252_avg
# 2     3.867268  ivv_w42_rank_v_L84_avg
# 3     3.867268  ivv_w42_rank_p_L84_avg
# 4     3.229015     w252_rank_v_L05_avg
#      Coefficient              Feature
# 355    -3.488191  w252_rank_v_L63_avg
# 356    -3.799416  w63_rank_v_L252_avg
# 357    -3.799416  w63_rank_p_L252_avg
# 358    -3.919172   w42_rank_p_L63_avg
# 359    -3.919172   w42_rank_v_L63_avg
# *****************************
# roc_auc_score on training: 0.7239
# roc_auc_score on testing: 0.5079
# *****************************
# Confusion Matrix Threshold: 0.305965
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[90  0]
#  [48 15]]
# Precision: 1.0
# Model Top Five Picks
#  Avg rtn top 5: 0.066
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.851585    0.018605  0.187063
# 1         1.0    0.491292    0.018605  0.033998
# 2         1.0    0.415939    0.018605  0.022837
# 3         1.0    0.411491    0.018605  0.054453
# 4         1.0    0.396297    0.018605  0.031509
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0433
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.389778    0.018605  0.038189
# 6         1.0    0.386069    0.018605  0.081400
# 7         1.0    0.367424    0.018605  0.029531
# 8         1.0    0.356338    0.018605  0.045514
# 9         1.0    0.355600    0.018605  0.021705
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0575
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.352342    0.018605  0.079743
# 11         1.0    0.345574    0.018605  0.045770
# 12         1.0    0.340309    0.018605  0.037741
# 13         1.0    0.313153    0.018605  0.059678
# 14         1.0    0.305965    0.018605  0.064440
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0151
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.024003    0.018605 -0.045047
# 149         1.0    0.021451    0.018605  0.041403
# 150         1.0    0.019081    0.018605  0.041711
# 151         0.0    0.017462    0.018605  0.007485
# 152         1.0    0.017053    0.018605  0.029782
# ********************************************************
# Building model to predict for  2015-08-06
# *****************************
# Variables with largest coefficients:
#    Coefficient               Feature
# 0     4.219746  w189_rank_p_L252_avg
# 1     4.219746  w189_rank_v_L252_avg
# 2     4.027998  w189_rank_p_L126_avg
# 3     4.027998  w189_rank_v_L126_avg
# 4     4.015628   w252_rank_v_L05_avg
#      Coefficient                 Feature
# 355    -3.230338      w42_rank_p_L63_avg
# 356    -3.278559  ivv_w63_rank_p_L42_avg
# 357    -3.278559  ivv_w63_rank_v_L42_avg
# 358    -4.086065     w63_rank_p_L252_avg
# 359    -4.086065     w63_rank_v_L252_avg
# *****************************
# roc_auc_score on training: 0.7259
# roc_auc_score on testing: 0.5584
# *****************************
# Confusion Matrix Threshold: 0.623891
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[66  4]
#  [72 11]]
# Precision: 0.7333
# Model Top Five Picks
#  Avg rtn top 5: -0.0512
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.855103   -0.076446  0.005111
# 1         1.0    0.767788   -0.076446 -0.054852
# 2         0.0    0.744298   -0.076446 -0.099677
# 3         1.0    0.742600   -0.076446 -0.053717
# 4         1.0    0.714958   -0.076446 -0.053102
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0676
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.700556   -0.076446 -0.064639
# 6         0.0    0.688994   -0.076446 -0.081060
# 7         1.0    0.673912   -0.076446 -0.060969
# 8         1.0    0.657104   -0.076446 -0.070703
# 9         1.0    0.646475   -0.076446 -0.060650
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0741
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.644279   -0.076446 -0.058504
# 11         1.0    0.639971   -0.076446 -0.064390
# 12         0.0    0.633909   -0.076446 -0.101854
# 13         1.0    0.624596   -0.076446 -0.068521
# 14         0.0    0.623891   -0.076446 -0.077072
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.117
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.011199   -0.076446 -0.063880
# 149         1.0    0.009578   -0.076446 -0.060486
# 150         0.0    0.008505   -0.076446 -0.154767
# 151         0.0    0.008399   -0.076446 -0.162802
# 152         0.0    0.002320   -0.076446 -0.143239
# ********************************************************
# Building model to predict for  2015-09-04
# *****************************
# Variables with largest coefficients:
#    Coefficient                 Feature
# 0     3.955658    w189_rank_p_L252_avg
# 1     3.955658    w189_rank_v_L252_avg
# 2     3.946900  ivv_w42_rank_p_L84_avg
# 3     3.946900  ivv_w42_rank_v_L84_avg
# 4     3.645518    w189_rank_v_L126_avg
#      Coefficient              Feature
# 355    -3.693823  w126_rank_p_L42_avg
# 356    -3.957693  w252_rank_v_L63_avg
# 357    -3.957693  w252_rank_p_L63_avg
# 358    -3.998402  w63_rank_p_L252_avg
# 359    -3.998402  w63_rank_v_L252_avg
# *****************************
# roc_auc_score on training: 0.7305
# roc_auc_score on testing: 0.5203
# *****************************
# Confusion Matrix Threshold: 0.929466
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[84  5]
#  [54 10]]
# Precision: 0.6667
# Model Top Five Picks
#  Avg rtn top 5: 0.0713
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.981319    0.032631  0.093914
# 1         1.0    0.980144    0.032631  0.095076
# 2         1.0    0.976904    0.032631  0.070399
# 3         1.0    0.973220    0.032631  0.089282
# 4         0.0    0.970401    0.032631  0.007958
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0663
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.959421    0.032631  0.036335
# 6         1.0    0.959055    0.032631  0.062937
# 7         1.0    0.957082    0.032631  0.102190
# 8         1.0    0.953996    0.032631  0.090397
# 9         1.0    0.950503    0.032631  0.039448
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0123
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.949849    0.032631  0.041018
# 11         0.0    0.948994    0.032631  0.009425
# 12         0.0    0.935689    0.032631 -0.021609
# 13         0.0    0.931702    0.032631  0.020264
# 14         0.0    0.929466    0.032631  0.012185
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0095
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.466312    0.032631  0.004776
# 149         1.0    0.425004    0.032631  0.070767
# 150         0.0    0.414521    0.032631 -0.041594
# 151         0.0    0.413912    0.032631  0.027751
# 152         0.0    0.408209    0.032631 -0.014258
# ********************************************************
# Building model to predict for  2015-10-06
# *****************************
# Variables with largest coefficients:
#    Coefficient                 Feature
# 0     4.624650    w189_rank_v_L252_avg
# 1     4.624650    w189_rank_p_L252_avg
# 2     3.358237    w189_rank_v_L126_avg
# 3     3.358237    w189_rank_p_L126_avg
# 4     3.297175  ivv_w42_rank_p_L84_avg
#      Coefficient              Feature
# 355    -3.608783  w252_rank_p_L63_avg
# 356    -4.122415   w42_rank_v_L63_avg
# 357    -4.122415   w42_rank_p_L63_avg
# 358    -4.346905  w126_rank_v_L42_avg
# 359    -4.346905  w126_rank_p_L42_avg
# *****************************
# roc_auc_score on training: 0.7257
# roc_auc_score on testing: 0.5271
# *****************************
# Confusion Matrix Threshold: 0.877118
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[121  10]
#  [ 17   5]]
# Precision: 0.3333
# Model Top Five Picks
#  Avg rtn top 5: 0.0551
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.956159    0.063911 -0.008892
# 1         1.0    0.936116    0.063911  0.089200
# 2         1.0    0.921046    0.063911  0.104081
# 3         0.0    0.907866    0.063911  0.046727
# 4         0.0    0.905188    0.063911  0.044555
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0278
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.901779    0.063911  0.018380
# 6         1.0    0.900761    0.063911  0.065964
# 7         0.0    0.897731    0.063911  0.026787
# 8         0.0    0.891166    0.063911  0.029483
# 9         0.0    0.886902    0.063911 -0.001387
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0297
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.885278    0.063911 -0.045786
# 11         1.0    0.883564    0.063911  0.064830
# 12         1.0    0.882120    0.063911  0.075032
# 13         0.0    0.879268    0.063911  0.030561
# 14         0.0    0.877118    0.063911  0.023881
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0541
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.268080    0.063911  0.053350
# 149         0.0    0.256786    0.063911  0.035642
# 150         1.0    0.254619    0.063911  0.072384
# 151         0.0    0.214295    0.063911  0.054756
# 152         0.0    0.205244    0.063911  0.054163
# ********************************************************
# Building model to predict for  2015-11-04
# *****************************
# Variables with largest coefficients:
#    Coefficient                 Feature
# 0     5.132520    w189_rank_p_L252_avg
# 1     5.132520    w189_rank_v_L252_avg
# 2     3.944978  ivv_w42_rank_v_L84_avg
# 3     3.944978  ivv_w42_rank_p_L84_avg
# 4     3.754796    w189_rank_p_L126_avg
#      Coefficient               Feature
# 355    -3.527897  w189_rank_p_L189_avg
# 356    -3.896940   w126_rank_p_L42_avg
# 357    -3.896940   w126_rank_v_L42_avg
# 358    -3.912763    w42_rank_v_L63_avg
# 359    -3.912763    w42_rank_p_L63_avg
# *****************************
# roc_auc_score on training: 0.7229
# roc_auc_score on testing: 0.5691
# *****************************
# Confusion Matrix Threshold: 0.828173
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[74 10]
#  [64  5]]
# Precision: 0.3333
# Model Top Five Picks
#  Avg rtn top 5: -0.0367
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.972604   -0.003687 -0.057326
# 1         0.0    0.923522   -0.003687 -0.057692
# 2         0.0    0.878501   -0.003687 -0.087869
# 3         0.0    0.858750   -0.003687 -0.008807
# 4         1.0    0.856126   -0.003687  0.028113
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.036
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.855869   -0.003687 -0.094929
# 6         0.0    0.851071   -0.003687 -0.052065
# 7         0.0    0.848004   -0.003687 -0.026054
# 8         1.0    0.847622   -0.003687 -0.000364
# 9         0.0    0.839177   -0.003687 -0.006480
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0276
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.838322   -0.003687 -0.113050
# 11         1.0    0.836054   -0.003687 -0.000974
# 12         0.0    0.830339   -0.003687 -0.020979
# 13         1.0    0.829944   -0.003687 -0.001586
# 14         1.0    0.828173   -0.003687 -0.001357
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0291
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.280744   -0.003687 -0.036261
# 149         0.0    0.203095   -0.003687 -0.029400
# 150         0.0    0.134489   -0.003687 -0.044990
# 151         0.0    0.123282   -0.003687 -0.033092
# 152         1.0    0.069305   -0.003687 -0.001742
# ********************************************************
# Building model to predict for  2015-12-04
# *****************************
# Variables with largest coefficients:
#    Coefficient                 Feature
# 0     4.858635    w189_rank_p_L252_avg
# 1     4.858635    w189_rank_v_L252_avg
# 2     4.254466  ivv_w42_rank_p_L84_avg
# 3     4.254466  ivv_w42_rank_v_L84_avg
# 4     3.555500    w189_rank_v_L126_avg
#      Coefficient              Feature
# 355    -3.131733   w84_rank_p_L10_avg
# 356    -3.993236   w42_rank_p_L63_avg
# 357    -3.993236   w42_rank_v_L63_avg
# 358    -5.017421  w126_rank_p_L42_avg
# 359    -5.017421  w126_rank_v_L42_avg
# *****************************
# roc_auc_score on training: 0.7215
# roc_auc_score on testing: 0.3758
# *****************************
# Confusion Matrix Threshold: 0.848292
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[71 10]
#  [67  5]]
# Precision: 0.3333
# Model Top Five Picks
#  Avg rtn top 5: -0.059
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.949259   -0.046016 -0.074912
# 1         1.0    0.942594   -0.046016 -0.003755
# 2         0.0    0.927726   -0.046016 -0.111326
# 3         1.0    0.927287   -0.046016 -0.038236
# 4         0.0    0.902658   -0.046016 -0.066970
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0651
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.883093   -0.046016 -0.069309
# 6         0.0    0.880453   -0.046016 -0.053945
# 7         1.0    0.876822   -0.046016 -0.042543
# 8         0.0    0.875449   -0.046016 -0.082203
# 9         0.0    0.873750   -0.046016 -0.077346
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0546
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.866624   -0.046016 -0.091774
# 11         0.0    0.861991   -0.046016 -0.079213
# 12         1.0    0.861910   -0.046016 -0.042207
# 13         1.0    0.855861   -0.046016 -0.011894
# 14         0.0    0.848292   -0.046016 -0.048112
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.011
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.106748   -0.046016 -0.023972
# 149         1.0    0.106396   -0.046016 -0.000060
# 150         1.0    0.074381   -0.046016 -0.000901
# 151         1.0    0.059176   -0.046016  0.006667
# 152         1.0    0.049759   -0.046016 -0.036770
# ********************************************************
# Building model to predict for  2016-01-06
# *****************************
# Variables with largest coefficients:
#    Coefficient                 Feature
# 0     4.450928    w189_rank_v_L252_avg
# 1     4.450928    w189_rank_p_L252_avg
# 2     3.822058     w126_rank_v_L21_avg
# 3     3.822058     w126_rank_p_L21_avg
# 4     3.703234  ivv_w42_rank_v_L84_avg
#      Coefficient               Feature
# 355    -2.861463    w84_rank_p_L10_avg
# 356    -3.414487  w126_rank_p_L126_avg
# 357    -3.414487  w126_rank_v_L126_avg
# 358    -4.131640   w126_rank_v_L42_avg
# 359    -4.131640   w126_rank_p_L42_avg
# *****************************
# roc_auc_score on training: 0.7170
# roc_auc_score on testing: 0.3758
# *****************************
# Confusion Matrix Threshold: 0.691806
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[48 12]
#  [90  3]]
# Precision: 0.2
# Model Top Five Picks
#  Avg rtn top 5: -0.1056
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.877288   -0.054663 -0.157275
# 1         0.0    0.837482   -0.054663 -0.121793
# 2         0.0    0.830946   -0.054663 -0.077506
# 3         0.0    0.818936   -0.054663 -0.112000
# 4         0.0    0.787233   -0.054663 -0.059386
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0516
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.767202   -0.054663  0.009464
# 6         0.0    0.722734   -0.054663 -0.091890
# 7         0.0    0.710972   -0.054663 -0.067246
# 8         1.0    0.707800   -0.054663 -0.049311
# 9         0.0    0.705126   -0.054663 -0.058877
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0741
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.702314   -0.054663 -0.050509
# 11         0.0    0.696166   -0.054663 -0.065334
# 12         0.0    0.695911   -0.054663 -0.061607
# 13         0.0    0.693053   -0.054663 -0.097807
# 14         0.0    0.691806   -0.054663 -0.095238
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0074
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.213085   -0.054663 -0.019373
# 149         1.0    0.212625   -0.054663  0.016264
# 150         0.0    0.209565   -0.054663 -0.097678
# 151         1.0    0.205304   -0.054663  0.038818
# 152         1.0    0.160337   -0.054663  0.024871
# ********************************************************
# Building model to predict for  2016-02-05
# *****************************
# Variables with largest coefficients:
#    Coefficient                  Feature
# 0     4.591959     w189_rank_p_L252_avg
# 1     4.591959     w189_rank_v_L252_avg
# 2     3.839508      w84_rank_v_L126_avg
# 3     3.839508      w84_rank_p_L126_avg
# 4     3.276969  ivv_w42_rank_v_L252_avg
#      Coefficient               Feature
# 355    -3.382601  w126_rank_v_L126_avg
# 356    -3.675246   w63_rank_p_L252_avg
# 357    -3.675246   w63_rank_v_L252_avg
# 358    -4.343501   w126_rank_v_L42_avg
# 359    -4.343501   w126_rank_p_L42_avg
# *****************************
# roc_auc_score on training: 0.7147
# roc_auc_score on testing: 0.4778
# *****************************
# Confusion Matrix Threshold: 0.609933
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[81  9]
#  [57  6]]
# Precision: 0.4
# Model Top Five Picks
#  Avg rtn top 5: 0.0456
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.733237    0.055758  0.097434
# 1         0.0    0.724842    0.055758  0.049184
# 2         1.0    0.717954    0.055758  0.077209
# 3         0.0    0.699054    0.055758 -0.000586
# 4         0.0    0.684540    0.055758  0.004795
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0265
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.670537    0.055758  0.000000
# 6         1.0    0.665391    0.055758  0.091413
# 7         0.0    0.663303    0.055758 -0.003247
# 8         0.0    0.646640    0.055758  0.050241
# 9         0.0    0.645445    0.055758 -0.005671
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0581
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.639689    0.055758 -0.005545
# 11         0.0    0.636950    0.055758  0.055450
# 12         1.0    0.622673    0.055758  0.096087
# 13         1.0    0.614185    0.055758  0.079004
# 14         1.0    0.609933    0.055758  0.065396
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0309
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.082603    0.055758  0.050488
# 149         0.0    0.079589    0.055758  0.027119
# 150         0.0    0.076972    0.055758  0.015181
# 151         0.0    0.068814    0.055758  0.029451
# 152         0.0    0.049426    0.055758  0.032186
# ********************************************************
# Building model to predict for  2016-03-08
# *****************************
# Variables with largest coefficients:
#    Coefficient               Feature
# 0     4.194772  w189_rank_v_L252_avg
# 1     4.194772  w189_rank_p_L252_avg
# 2     4.030286   w84_rank_p_L126_avg
# 3     4.030286   w84_rank_v_L126_avg
# 4     3.661321   w126_rank_p_L21_avg
#      Coefficient               Feature
# 355    -3.635075   w126_rank_v_L42_avg
# 356    -3.744098  w126_rank_p_L126_avg
# 357    -3.744098  w126_rank_v_L126_avg
# 358    -4.530537   w63_rank_p_L252_avg
# 359    -4.530537   w63_rank_v_L252_avg
# *****************************
# roc_auc_score on training: 0.7027
# roc_auc_score on testing: 0.4858
# *****************************
# Confusion Matrix Threshold: 0.382586
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[98  8]
#  [40  7]]
# Precision: 0.4667
# Model Top Five Picks
#  Avg rtn top 5: 0.0047
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.736302    0.033627 -0.021911
# 1         0.0    0.730439    0.033627 -0.005695
# 2         0.0    0.509831    0.033627  0.014635
# 3         0.0    0.453878    0.033627  0.032824
# 4         0.0    0.451655    0.033627  0.003731
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0319
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.449630    0.033627 -0.024218
# 6         1.0    0.440544    0.033627  0.055297
# 7         0.0    0.440249    0.033627  0.033009
# 8         1.0    0.436920    0.033627  0.058610
# 9         1.0    0.413936    0.033627  0.036910
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0532
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.409292    0.033627  0.079704
# 11         1.0    0.402710    0.033627  0.059693
# 12         1.0    0.400175    0.033627  0.046431
# 13         0.0    0.391295    0.033627  0.027695
# 14         1.0    0.382586    0.033627  0.052428
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.023395    0.033627 -0.044877
# 149         0.0    0.010985    0.033627 -0.009576
# 150         0.0    0.010322    0.033627 -0.015612
# 151         1.0    0.008522    0.033627  0.036725
# 152         0.0    0.007426    0.033627  0.033325
# ********************************************************
# Building model to predict for  2016-04-07
# *****************************
# Variables with largest coefficients:
#    Coefficient               Feature
# 0     4.450301  w189_rank_v_L252_avg
# 1     4.450301  w189_rank_p_L252_avg
# 2     4.045390   w126_rank_v_L21_avg
# 3     4.045390   w126_rank_p_L21_avg
# 4     3.630881   w252_rank_v_L21_avg
#      Coefficient               Feature
# 355    -3.401774   w126_rank_p_L42_avg
# 356    -3.841968  w252_rank_p_L126_avg
# 357    -3.841968  w252_rank_v_L126_avg
# 358    -4.626097   w63_rank_v_L252_avg
# 359    -4.626097   w63_rank_p_L252_avg
# *****************************
# roc_auc_score on training: 0.7047
# roc_auc_score on testing: 0.4897
# *****************************
# Confusion Matrix Threshold: 0.340469
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[59  4]
#  [79 11]]
# Precision: 0.7333
# Model Top Five Picks
#  Avg rtn top 5: -0.0091
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.883892    0.008977 -0.090559
# 1         0.0    0.819613    0.008977 -0.079832
# 2         1.0    0.518640    0.008977  0.061634
# 3         1.0    0.490920    0.008977  0.040135
# 4         1.0    0.396241    0.008977  0.023040
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0026
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.395235    0.008977  0.018583
# 6         1.0    0.392180    0.008977  0.019932
# 7         0.0    0.382285    0.008977 -0.011566
# 8         0.0    0.369657    0.008977 -0.034560
# 9         1.0    0.364624    0.008977  0.020519
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0439
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.361124    0.008977  0.014694
# 11         1.0    0.360683    0.008977  0.031162
# 12         1.0    0.356566    0.008977  0.013279
# 13         1.0    0.344669    0.008977  0.125000
# 14         1.0    0.340469    0.008977  0.035325
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.001
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.030889    0.008977 -0.011236
# 149         0.0    0.029545    0.008977 -0.005029
# 150         0.0    0.029447    0.008977 -0.007082
# 151         0.0    0.022045    0.008977 -0.038139
# 152         1.0    0.009065    0.008977  0.056305
# ********************************************************
# Building model to predict for  2016-05-06
# *****************************
# Variables with largest coefficients:
#    Coefficient                  Feature
# 0     4.454040      w126_rank_p_L21_avg
# 1     4.454040      w126_rank_v_L21_avg
# 2     4.158832  ivv_w42_rank_v_L126_avg
# 3     4.158832  ivv_w42_rank_p_L126_avg
# 4     4.010008     w189_rank_v_L252_avg
#      Coefficient               Feature
# 355    -3.013104    w84_rank_v_L10_avg
# 356    -3.350521  w126_rank_v_L126_avg
# 357    -3.350521  w126_rank_p_L126_avg
# 358    -4.612427   w63_rank_v_L252_avg
# 359    -4.612427   w63_rank_p_L252_avg
# *****************************
# roc_auc_score on training: 0.6998
# roc_auc_score on testing: 0.4436
# *****************************
# Confusion Matrix Threshold: 0.875262
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[54 10]
#  [84  5]]
# Precision: 0.3333
# Model Top Five Picks
#  Avg rtn top 5: 0.081
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.987415    0.028819  0.091978
# 1         1.0    0.982891    0.028819  0.114706
# 2         1.0    0.947461    0.028819  0.036516
# 3         1.0    0.919111    0.028819  0.086085
# 4         1.0    0.913874    0.028819  0.075592
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0005
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.912747    0.028819  0.001526
# 6         0.0    0.907056    0.028819  0.000009
# 7         0.0    0.898702    0.028819 -0.000105
# 8         0.0    0.893234    0.028819  0.002900
# 9         0.0    0.892458    0.028819 -0.001709
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0025
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.889250    0.028819  0.002679
# 11         0.0    0.887385    0.028819  0.003776
# 12         0.0    0.887254    0.028819  0.002575
# 13         0.0    0.880417    0.028819  0.001896
# 14         0.0    0.875262    0.028819  0.001385
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0498
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.384271    0.028819  0.096401
# 149         1.0    0.296298    0.028819  0.039563
# 150         1.0    0.273530    0.028819  0.036133
# 151         1.0    0.246710    0.028819  0.043194
# 152         1.0    0.095663    0.028819  0.033784
# ********************************************************
# Building model to predict for  2016-06-07
# *****************************
# Variables with largest coefficients:
#    Coefficient               Feature
# 0     4.377565   w126_rank_v_L21_avg
# 1     4.377565   w126_rank_p_L21_avg
# 2     4.341260   w252_rank_v_L42_avg
# 3     4.341260   w252_rank_p_L42_avg
# 4     4.218077  w189_rank_p_L252_avg
#      Coefficient               Feature
# 355    -2.940986  w126_rank_p_L126_avg
# 356    -3.091004  w252_rank_p_L126_avg
# 357    -3.091004  w252_rank_v_L126_avg
# 358    -4.738212   w63_rank_v_L252_avg
# 359    -4.738212   w63_rank_p_L252_avg
# *****************************
# roc_auc_score on training: 0.6958
# roc_auc_score on testing: 0.5603
# *****************************
# Confusion Matrix Threshold: 0.395024
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[93  2]
#  [45 13]]
# Precision: 0.8667
# Model Top Five Picks
#  Avg rtn top 5: 0.0551
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.761727   -0.005191  0.077340
# 1         1.0    0.652789   -0.005191  0.062289
# 2         1.0    0.636280   -0.005191  0.058194
# 3         1.0    0.563784   -0.005191  0.040056
# 4         1.0    0.526679   -0.005191  0.037809
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0348
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.512662   -0.005191  0.030851
# 6         1.0    0.511165   -0.005191  0.047154
# 7         1.0    0.482282   -0.005191  0.093411
# 8         0.0    0.481810   -0.005191 -0.024282
# 9         1.0    0.459018   -0.005191  0.026897
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0151
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.458894   -0.005191  0.022709
# 11         1.0    0.439434   -0.005191 -0.002053
# 12         1.0    0.421107   -0.005191  0.060322
# 13         0.0    0.402620   -0.005191 -0.021007
# 14         1.0    0.395024   -0.005191  0.015557
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.058
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.037165   -0.005191 -0.085344
# 149         0.0    0.036259   -0.005191 -0.008762
# 150         0.0    0.026170   -0.005191 -0.077806
# 151         0.0    0.019578   -0.005191 -0.075920
# 152         0.0    0.014608   -0.005191 -0.042341
# ********************************************************
# Building model to predict for  2016-07-07
# *****************************
# Variables with largest coefficients:
#    Coefficient               Feature
# 0     3.959770  w189_rank_v_L252_avg
# 1     3.959770  w189_rank_p_L252_avg
# 2     3.864754   w252_rank_v_L42_avg
# 3     3.864754   w252_rank_p_L42_avg
# 4     3.674851   w126_rank_v_L21_avg
#      Coefficient              Feature
# 355    -2.900088  w126_rank_v_L42_avg
# 356    -3.053899   w84_rank_v_L84_avg
# 357    -3.053899   w84_rank_p_L84_avg
# 358    -4.676958  w63_rank_v_L252_avg
# 359    -4.676958  w63_rank_p_L252_avg
# *****************************
# roc_auc_score on training: 0.6875
# roc_auc_score on testing: 0.6695
# *****************************
# Confusion Matrix Threshold: 0.787252
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[57  4]
#  [81 11]]
# Precision: 0.7333
# Model Top Five Picks
#  Avg rtn top 5: 0.1172
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.948042    0.041489  0.048595
# 1         1.0    0.928339    0.041489  0.175680
# 2         1.0    0.920275    0.041489  0.225937
# 3         1.0    0.883098    0.041489  0.119874
# 4         0.0    0.877428    0.041489  0.016030
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0495
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.868984    0.041489  0.040554
# 6         0.0    0.865539    0.041489  0.021686
# 7         1.0    0.832530    0.041489  0.135173
# 8         0.0    0.824362    0.041489  0.007600
# 9         1.0    0.824042    0.041489  0.042716
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0719
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.815094    0.041489  0.085523
# 11         1.0    0.813199    0.041489  0.089839
# 12         1.0    0.806076    0.041489  0.074118
# 13         1.0    0.803682    0.041489  0.053090
# 14         1.0    0.787252    0.041489  0.057030
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0196
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.359263    0.041489 -0.022637
# 149         0.0    0.331856    0.041489  0.000000
# 150         1.0    0.326818    0.041489  0.044108
# 151         0.0    0.286725    0.041489  0.017231
# 152         1.0    0.252472    0.041489  0.059052
# ********************************************************
# Building model to predict for  2016-08-05
# *****************************
# Variables with largest coefficients:
#    Coefficient               Feature
# 0     4.198137   w252_rank_p_L42_avg
# 1     4.198137   w252_rank_v_L42_avg
# 2     4.144711  w189_rank_p_L252_avg
# 3     4.144711  w189_rank_v_L252_avg
# 4     3.710653   w84_rank_v_L126_avg
#      Coefficient              Feature
# 355    -3.043526   w84_rank_v_L05_avg
# 356    -3.482326   w84_rank_v_L84_avg
# 357    -3.482326   w84_rank_p_L84_avg
# 358    -4.555086  w63_rank_p_L252_avg
# 359    -4.555086  w63_rank_v_L252_avg
# *****************************
# roc_auc_score on training: 0.6949
# roc_auc_score on testing: 0.5331
# *****************************
# Confusion Matrix Threshold: 0.768772
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[ 35   4]
#  [103  11]]
# Precision: 0.7333
# Model Top Five Picks
#  Avg rtn top 5: 0.0398
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.923086    0.004421  0.051487
# 1         1.0    0.890296    0.004421  0.071390
# 2         1.0    0.876994    0.004421  0.025385
# 3         0.0    0.870674    0.004421 -0.033391
# 4         1.0    0.856909    0.004421  0.084112
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0228
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.851639    0.004421  0.003277
# 6         1.0    0.851504    0.004421  0.025326
# 7         1.0    0.839609    0.004421  0.051188
# 8         1.0    0.816552    0.004421  0.040238
# 9         0.0    0.816382    0.004421 -0.005850
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0433
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.816359    0.004421  0.060218
# 11         1.0    0.812712    0.004421  0.042998
# 12         1.0    0.774966    0.004421  0.062998
# 13         1.0    0.773820    0.004421  0.046256
# 14         0.0    0.768772    0.004421  0.003968
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0124
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.195665    0.004421  0.043419
# 149         0.0    0.172899    0.004421 -0.014706
# 150         0.0    0.171230    0.004421 -0.005539
# 151         1.0    0.162998    0.004421  0.016861
# 152         1.0    0.153690    0.004421  0.021873
# ********************************************************
# Building model to predict for  2016-09-06
# *****************************
# Variables with largest coefficients:
#    Coefficient              Feature
# 0     4.494553  w252_rank_p_L42_avg
# 1     4.494553  w252_rank_v_L42_avg
# 2     4.396440  w84_rank_v_L126_avg
# 3     4.396440  w84_rank_p_L126_avg
# 4     3.549576  w126_rank_v_L21_avg
#      Coefficient               Feature
# 355    -2.604379  w189_rank_v_L126_avg
# 356    -3.772426    w84_rank_p_L84_avg
# 357    -3.772426    w84_rank_v_L84_avg
# 358    -3.936142   w63_rank_v_L252_avg
# 359    -3.936142   w63_rank_p_L252_avg
# *****************************
# roc_auc_score on training: 0.7169
# roc_auc_score on testing: 0.4688
# *****************************
# Confusion Matrix Threshold: 0.789102
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[51  6]
#  [87  9]]
# Precision: 0.6
# Model Top Five Picks
#  Avg rtn top 5: 0.0221
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.893400   -0.010794 -0.001150
# 1         1.0    0.886350   -0.010794 -0.001543
# 2         1.0    0.866180   -0.010794  0.016212
# 3         1.0    0.857675   -0.010794  0.059566
# 4         1.0    0.849920   -0.010794  0.037321
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0187
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.834303   -0.010794 -0.016060
# 6         1.0    0.831272   -0.010794 -0.009555
# 7         0.0    0.825381   -0.010794 -0.019834
# 8         0.0    0.820331   -0.010794 -0.013338
# 9         0.0    0.819635   -0.010794 -0.034502
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0016
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.805251   -0.010794 -0.009241
# 11         0.0    0.796471   -0.010794 -0.011552
# 12         0.0    0.794861   -0.010794 -0.015063
# 13         1.0    0.791716   -0.010794 -0.005651
# 14         1.0    0.789102   -0.010794  0.033515
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0062
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.205260   -0.010794  0.009054
# 149         1.0    0.172273   -0.010794  0.015308
# 150         1.0    0.160872   -0.010794  0.003189
# 151         1.0    0.152672   -0.010794  0.024350
# 152         0.0    0.141774   -0.010794 -0.020721
# ********************************************************
# Building model to predict for  2016-10-05
# *****************************
# Variables with largest coefficients:
#    Coefficient              Feature
# 0     4.636475  w84_rank_v_L126_avg
# 1     4.636475  w84_rank_p_L126_avg
# 2     3.370754  w252_rank_p_L42_avg
# 3     3.370754  w252_rank_v_L42_avg
# 4     2.960524   w63_rank_p_L63_avg
#      Coefficient               Feature
# 355    -3.225815  w189_rank_v_L126_avg
# 356    -3.556778   w63_rank_p_L252_avg
# 357    -3.556778   w63_rank_v_L252_avg
# 358    -4.874071    w84_rank_p_L84_avg
# 359    -4.874071    w84_rank_v_L84_avg
# *****************************
# roc_auc_score on training: 0.7305
# roc_auc_score on testing: 0.4729
# *****************************
# Confusion Matrix Threshold: 0.558762
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[64  9]
#  [74  6]]
# Precision: 0.4
# Model Top Five Picks
#  Avg rtn top 5: -0.0855
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.857284   -0.031675 -0.147890
# 1         0.0    0.723553   -0.031675 -0.047674
# 2         0.0    0.722609   -0.031675 -0.151066
# 3         0.0    0.688601   -0.031675 -0.055869
# 4         1.0    0.667041   -0.031675 -0.025112
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0276
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.663839   -0.031675  0.033828
# 6         1.0    0.660050   -0.031675 -0.027161
# 7         1.0    0.618286   -0.031675 -0.022890
# 8         0.0    0.615171   -0.031675 -0.076631
# 9         0.0    0.608337   -0.031675 -0.045033
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0479
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.603389   -0.031675 -0.027982
# 11         0.0    0.581302   -0.031675 -0.073389
# 12         0.0    0.578964   -0.031675 -0.072206
# 13         1.0    0.570337   -0.031675 -0.024738
# 14         0.0    0.558762   -0.031675 -0.041341
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0076
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.073814   -0.031675 -0.029354
# 149         0.0    0.073288   -0.031675 -0.045559
# 150         1.0    0.055933   -0.031675 -0.003311
# 151         1.0    0.019251   -0.031675  0.023529
# 152         1.0    0.018060   -0.031675  0.016896
# ********************************************************
# Building model to predict for  2016-11-03
# ...
#    Coefficient                  Feature
# 0     4.917981       w84_rank_v_L84_avg
# 1     4.917981       w84_rank_p_L84_avg
# 2     3.109106      w42_rank_p_L126_avg
# 3     3.109106      w42_rank_v_L126_avg
# 4     3.060892  ivv_w63_rank_p_L189_avg
#      Coefficient                  Feature
# 355    -2.311814       w63_rank_v_L63_avg
# 356    -2.593747  ivv_w42_rank_v_L252_avg
# 357    -2.593747  ivv_w42_rank_p_L252_avg
# 358    -2.992730      w84_rank_v_L126_avg
# 359    -2.992730      w84_rank_p_L126_avg
# *****************************
# roc_auc_score on training: 0.7080
# roc_auc_score on testing: 0.4830
# *****************************
# Confusion Matrix Threshold: 0.413314
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[72  9]
#  [66  6]]
# Precision: 0.4
# Model Top Five Picks
#  Avg rtn top 5: -0.0388
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.605487   -0.014782 -0.071847
# 1         1.0    0.551416   -0.014782  0.020792
# 2         0.0    0.540235   -0.014782 -0.093819
# 3         0.0    0.536732   -0.014782 -0.031646
# 4         0.0    0.510573   -0.014782 -0.017348
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0149
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.508912   -0.014782  0.005806
# 6         0.0    0.500571   -0.014782 -0.021149
# 7         0.0    0.469449   -0.014782 -0.028566
# 8         0.0    0.468847   -0.014782 -0.038006
# 9         1.0    0.457942   -0.014782  0.007660
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0121
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.454806   -0.014782 -0.008542
# 11         1.0    0.447181   -0.014782 -0.007545
# 12         0.0    0.431033   -0.014782 -0.015678
# 13         1.0    0.415357   -0.014782  0.016454
# 14         0.0    0.413314   -0.014782 -0.045287
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.043
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.113618   -0.014782 -0.069426
# 149         1.0    0.111861   -0.014782  0.000180
# 150         0.0    0.096261   -0.014782 -0.059233
# 151         0.0    0.065343   -0.014782 -0.018970
# 152         0.0    0.054320   -0.014782 -0.067536
# ********************************************************
# Building model to predict for  2018-02-06
# *****************************
# Variables with largest coefficients:
#    Coefficient                  Feature
# 0     4.185671       w84_rank_p_L84_avg
# 1     4.185671       w84_rank_v_L84_avg
# 2     2.988259  ivv_w63_rank_p_L189_avg
# 3     2.988259  ivv_w63_rank_v_L189_avg
# 4     2.662234      w42_rank_v_L126_avg
#      Coefficient                  Feature
# 355    -2.088279  ivv_w42_rank_v_L252_avg
# 356    -2.695566      w84_rank_p_L126_avg
# 357    -2.695566      w84_rank_v_L126_avg
# 358    -2.777379     w126_rank_v_L252_avg
# 359    -2.777379     w126_rank_p_L252_avg
# *****************************
# roc_auc_score on training: 0.6976
# roc_auc_score on testing: 0.4781
# *****************************
# Confusion Matrix Threshold: 0.422355
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[101  13]
#  [ 37   2]]
# Precision: 0.1333
# Model Top Five Picks
#  Avg rtn top 5: -0.0026
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.628140    0.017953 -0.037759
# 1         0.0    0.565611    0.017953 -0.010701
# 2         0.0    0.516311    0.017953  0.012117
# 3         0.0    0.501171    0.017953  0.014836
# 4         0.0    0.500370    0.017953  0.008631
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0171
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.493288    0.017953 -0.002727
# 6         1.0    0.467964    0.017953  0.053501
# 7         0.0    0.460893    0.017953 -0.006764
# 8         1.0    0.441691    0.017953  0.035364
# 9         0.0    0.441409    0.017953  0.006016
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0025
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.436297    0.017953 -0.001182
# 11         0.0    0.435930    0.017953  0.013675
# 12         0.0    0.430425    0.017953 -0.005774
# 13         0.0    0.426353    0.017953 -0.023670
# 14         0.0    0.422355    0.017953  0.004517
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0003
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.065235    0.017953 -0.002467
# 149         0.0    0.064141    0.017953  0.000944
# 150         0.0    0.058300    0.017953 -0.001136
# 151         0.0    0.058181    0.017953 -0.000884
# 152         0.0    0.054329    0.017953  0.001814
# ********************************************************
# Building model to predict for  2018-03-08
# *****************************
# Variables with largest coefficients:
#    Coefficient                  Feature
# 0     3.669428       w84_rank_p_L84_avg
# 1     3.669428       w84_rank_v_L84_avg
# 2     2.887333  ivv_w63_rank_v_L189_avg
# 3     2.887333  ivv_w63_rank_p_L189_avg
# 4     2.706254      w42_rank_v_L126_avg
#      Coefficient                  Feature
# 355    -2.431178  ivv_w42_rank_p_L252_avg
# 356    -2.526770     w126_rank_v_L252_avg
# 357    -2.526770     w126_rank_p_L252_avg
# 358    -2.601803      w84_rank_v_L126_avg
# 359    -2.601803      w84_rank_p_L126_avg
# *****************************
# roc_auc_score on training: 0.6930
# roc_auc_score on testing: 0.4700
# *****************************
# Confusion Matrix Threshold: 0.797558
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[ 22   2]
#  [116  13]]
# Precision: 0.8667
# Model Top Five Picks
#  Avg rtn top 5: 0.0015
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.922297   -0.044343  0.005199
# 1         1.0    0.889778   -0.044343  0.008038
# 2         1.0    0.886297   -0.044343  0.003772
# 3         1.0    0.882250   -0.044343 -0.005621
# 4         1.0    0.880459   -0.044343 -0.003862
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0061
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.867372   -0.044343 -0.011322
# 6         1.0    0.834202   -0.044343 -0.028336
# 7         1.0    0.831800   -0.044343  0.014475
# 8         1.0    0.824836   -0.044343  0.000000
# 9         1.0    0.822980   -0.044343 -0.005119
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0375
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.813565   -0.044343 -0.045403
# 11         1.0    0.811738   -0.044343 -0.024337
# 12         1.0    0.811649   -0.044343 -0.026050
# 13         0.0    0.800961   -0.044343 -0.059633
# 14         1.0    0.797558   -0.044343 -0.032272
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0071
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.258155   -0.044343  0.009544
# 149         0.0    0.254020   -0.044343 -0.068146
# 150         1.0    0.215373   -0.044343 -0.034711
# 151         1.0    0.206167   -0.044343  0.028421
# 152         1.0    0.201930   -0.044343  0.029567
# ********************************************************
# Building model to predict for  2018-04-09
# *****************************
# Variables with largest coefficients:
#    Coefficient                  Feature
# 0     2.868152       w84_rank_v_L84_avg
# 1     2.868152       w84_rank_p_L84_avg
# 2     2.857177  ivv_w63_rank_v_L189_avg
# 3     2.857177  ivv_w63_rank_p_L189_avg
# 4     2.604114      w42_rank_v_L126_avg
#      Coefficient               Feature
# 355    -2.168962   w252_rank_p_L63_avg
# 356    -2.371378   w84_rank_v_L126_avg
# 357    -2.371378   w84_rank_p_L126_avg
# 358    -2.750310  w126_rank_v_L252_avg
# 359    -2.750310  w126_rank_p_L252_avg
# *****************************
# roc_auc_score on training: 0.6976
# roc_auc_score on testing: 0.4869
# *****************************
# Confusion Matrix Threshold: 0.791821
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[105   7]
#  [ 33   8]]
# Precision: 0.5333
# Model Top Five Picks
#  Avg rtn top 5: -0.0152
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.914290    0.022764 -0.001938
# 1         1.0    0.879899    0.022764  0.031170
# 2         0.0    0.876825    0.022764 -0.010277
# 3         0.0    0.859329    0.022764 -0.164500
# 4         1.0    0.858293    0.022764  0.069579
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.03
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.850319    0.022764  0.034237
# 6         1.0    0.845492    0.022764  0.029807
# 7         1.0    0.837101    0.022764  0.035460
# 8         1.0    0.823057    0.022764  0.033984
# 9         0.0    0.813110    0.022764  0.016599
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0198
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.811060    0.022764 -0.026591
# 11         0.0    0.804506    0.022764  0.007614
# 12         1.0    0.804007    0.022764  0.073632
# 13         0.0    0.799993    0.022764 -0.000863
# 14         1.0    0.791821    0.022764  0.044996
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0127
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.398838    0.022764  0.028887
# 149         0.0    0.392851    0.022764 -0.032006
# 150         1.0    0.368299    0.022764  0.038359
# 151         0.0    0.339838    0.022764 -0.001026
# 152         1.0    0.294242    0.022764  0.029447
# ********************************************************
# Building model to predict for  2018-05-08
# *****************************
# Variables with largest coefficients:
#    Coefficient               Feature
# 0     3.022138  w252_rank_p_L189_avg
# 1     3.022138  w252_rank_v_L189_avg
# 2     2.947276   w42_rank_v_L126_avg
# 3     2.947276   w42_rank_p_L126_avg
# 4     2.717586   w252_rank_p_L05_avg
#      Coefficient               Feature
# 355    -2.469594  w126_rank_v_L252_avg
# 356    -2.609044   w252_rank_v_L84_avg
# 357    -2.609044   w252_rank_p_L84_avg
# 358    -2.625356   w252_rank_v_L63_avg
# 359    -2.625356   w252_rank_p_L63_avg
# *****************************
# roc_auc_score on training: 0.6990
# roc_auc_score on testing: 0.5144
# *****************************
# Confusion Matrix Threshold: 0.782548
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[111  11]
#  [ 27   4]]
# Precision: 0.2667
# Model Top Five Picks
#  Avg rtn top 5: -0.0012
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.927975    0.039378 -0.035907
# 1         0.0    0.876874    0.039378  0.003334
# 2         0.0    0.862110    0.039378  0.000000
# 3         0.0    0.851721    0.039378 -0.023572
# 4         1.0    0.850964    0.039378  0.050207
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0131
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.834320    0.039378 -0.031086
# 6         1.0    0.827693    0.039378  0.040264
# 7         0.0    0.820082    0.039378 -0.046808
# 8         0.0    0.818200    0.039378  0.028807
# 9         0.0    0.809136    0.039378 -0.056563
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0232
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.800752    0.039378 -0.035745
# 11         1.0    0.799399    0.039378  0.044529
# 12         1.0    0.797415    0.039378  0.065064
# 13         0.0    0.785393    0.039378  0.024724
# 14         0.0    0.782548    0.039378  0.017358
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0082
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.283693    0.039378 -0.008449
# 149         0.0    0.194185    0.039378 -0.005666
# 150         0.0    0.185417    0.039378  0.026825
# 151         0.0    0.165114    0.039378  0.004237
# 152         0.0    0.068287    0.039378  0.024161
# ********************************************************
# Building model to predict for  2018-06-07
# *****************************
# Variables with largest coefficients:
#    Coefficient               Feature
# 0     3.456494  w252_rank_v_L189_avg
# 1     3.456494  w252_rank_p_L189_avg
# 2     2.850022   w42_rank_p_L126_avg
# 3     2.850022   w42_rank_v_L126_avg
# 4     2.463286    w84_rank_v_L05_avg
#      Coefficient              Feature
# 355    -2.510651  w252_rank_p_L84_avg
# 356    -2.699566  w252_rank_v_L63_avg
# 357    -2.699566  w252_rank_p_L63_avg
# 358    -3.625628  w84_rank_v_L126_avg
# 359    -3.625628  w84_rank_p_L126_avg
# *****************************
# roc_auc_score on training: 0.7134
# roc_auc_score on testing: 0.4732
# *****************************
# Confusion Matrix Threshold: 0.911744
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[87 10]
#  [51  5]]
# Precision: 0.3333
# Model Top Five Picks
#  Avg rtn top 5: -0.0098
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.981246    0.006674 -0.025759
# 1         0.0    0.980675    0.006674 -0.092768
# 2         1.0    0.979369    0.006674  0.057552
# 3         0.0    0.976845    0.006674 -0.046723
# 4         1.0    0.972037    0.006674  0.058831
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0134
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.970946    0.006674 -0.096621
# 6         1.0    0.967613    0.006674  0.164132
# 7         1.0    0.966504    0.006674  0.022205
# 8         1.0    0.957841    0.006674  0.042369
# 9         0.0    0.950769    0.006674 -0.065221
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0306
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.942362    0.006674 -0.045882
# 11         0.0    0.932231    0.006674 -0.041820
# 12         0.0    0.931186    0.006674 -0.009267
# 13         0.0    0.917391    0.006674 -0.011277
# 14         0.0    0.911744    0.006674 -0.044768
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0168
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.525916    0.006674  0.001044
# 149         1.0    0.506051    0.006674  0.032759
# 150         1.0    0.475812    0.006674  0.009295
# 151         1.0    0.455901    0.006674  0.011274
# 152         1.0    0.434326    0.006674  0.029686
# ********************************************************
# Building model to predict for  2018-07-09
# *****************************
# Variables with largest coefficients:
#    Coefficient                  Feature
# 0     4.594170     w252_rank_v_L189_avg
# 1     4.594170     w252_rank_p_L189_avg
# 2     3.124587  ivv_w21_rank_p_L189_avg
# 3     3.124587  ivv_w21_rank_v_L189_avg
# 4     2.972743     w189_rank_v_L252_avg
#      Coefficient               Feature
# 355    -3.138747  w252_rank_v_L252_avg
# 356    -3.725403   w84_rank_p_L126_avg
# 357    -3.725403   w84_rank_v_L126_avg
# 358    -3.783089   w252_rank_v_L63_avg
# 359    -3.783089   w252_rank_p_L63_avg
# *****************************
# roc_auc_score on training: 0.7040
# roc_auc_score on testing: 0.4518
# *****************************
# Confusion Matrix Threshold: 0.658411
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[114  10]
#  [ 24   5]]
# Precision: 0.3333
# Model Top Five Picks
#  Avg rtn top 5: 0.0274
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.860381    0.027376  0.007524
# 1         1.0    0.846771    0.027376  0.073643
# 2         0.0    0.840835    0.027376 -0.038342
# 3         1.0    0.828467    0.027376  0.035503
# 4         1.0    0.817333    0.027376  0.058922
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0116
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.749642    0.027376  0.048126
# 6         0.0    0.729859    0.027376 -0.011736
# 7         1.0    0.727591    0.027376  0.064360
# 8         0.0    0.725954    0.027376 -0.028942
# 9         0.0    0.711618    0.027376 -0.129697
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0067
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.708786    0.027376  0.012281
# 11         0.0    0.691473    0.027376 -0.012614
# 12         0.0    0.669019    0.027376 -0.008546
# 13         0.0    0.664491    0.027376 -0.038143
# 14         0.0    0.658411    0.027376  0.013441
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0018
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.256625    0.027376 -0.032514
# 149         1.0    0.233247    0.027376  0.049634
# 150         0.0    0.180215    0.027376 -0.013146
# 151         0.0    0.167745    0.027376  0.018281
# 152         0.0    0.158965    0.027376 -0.013180
# ********************************************************

# %%
np.ravel(lr.coef_).shape
# Out:
# (360,)

# %%
import pandas as pd
import numpy as np
import os
import sklearn
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
import xgboost
from xgboost import XGBClassifier
# %matplotlib notebook

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 500)
pd.options.mode.chained_assignment = None  # default='warn'

# %%
data_path = '/home/mvkrein/etf_model/data'
etf_data_file = os.path.join(data_path,'etf_new_var_20180910.csv')
etf_data = pd.read_csv(etf_data_file,index_col=0)

# %%
etf_study_file = os.path.join(data_path,'ETF_list_min_6yr_history.csv')
etf_list = pd.read_csv(etf_study_file,index_col=0)
etf_data.sort_values(['Date','sym'],ascending=True,inplace=True)
etf_data.reset_index(drop=True,inplace=True)

# %%
drop_columns = ['Date','sym','p', 'v', 'p_L05', 'v_L05', 'p_L10', 'v_L10', 'p_L21', 'v_L21', 'p_L42', 'v_L42', 'p_L63', \
                'v_L63', 'p_L84', 'v_L84', 'p_L126', 'v_L126', 'p_L189', 'v_L189', 'p_L252', 'v_L252',\
                'p_L-21', 'v_L-21', 'delta_p_L05', 'delta_p_L10', 'delta_p_L21', 'delta_p_L42', 'delta_p_L63', \
                'delta_p_L84', 'delta_p_L126', 'delta_p_L189', 'delta_p_L252', 'delta_p_L-21', 'delta_v_L05',\
                'delta_v_L10', 'delta_v_L21', 'delta_v_L42', 'delta_v_L63', 'delta_v_L84', 'delta_v_L126', \
                'delta_v_L189', 'delta_v_L252','rank_p_L-21', 'ivv_delta_p_L-21', 'target']

rank_col = ['rank_p_L05','rank_p_L10','rank_p_L21','rank_p_L42',\
            'rank_p_L63','rank_p_L84','rank_p_L126','rank_p_L189','rank_p_L252']

# %%
all_columns = list(etf_data.columns)

# %%
include_columns = [x for x in all_columns if x not in drop_columns]
# include_columns = ['rank_p_L05','rank_p_L10','rank_p_L21','rank_p_L42',\
#             'rank_p_L63','rank_p_L84','rank_p_L126','rank_p_L189','rank_p_L252']
# include_columns = ['rank_p_L05','rank_p_L21','rank_p_L42','rank_p_L252']

# %%
len(include_columns)
# Out:
# 360

# %%
dates = list(etf_data['Date'].unique())
# dates[1671]

# %%
for i in range(0,1671):
    if dates[i] == '2016-04-07':
        print (i,dates[i])
# Out:
# 1071 2016-04-07

# %%
symbols = etf_list['Symbol'].unique()

# %%
len(symbols)
# Out:
# 153

# %%
#Each year has 252 trading dates.  Need two years to fully develop variables.
dt1 = 504 #This is the first day that all variables are developed
# dt1 = 504 + 21 + 273 #This is the first day that all variables are developed 2016-04-07
# make all dates relative to dt1
# for one year training - add 252
# to evaluate for one month outside the training window - add 273
# to predict for the first day outside of the evaluation window (have to lag 21) - add 294
dt_end = (len(dates) - 273 - 21) - 1
dt2 = 1071 - 273 #restart for '2018-05-08'
# dt_end = dt1 + 1 #For testing on the first day only
etf_predict_file = os.path.join(data_path,'etf_pred_random_forest_20180927_depth8.csv')

# %%
#Run grid search with cross validation to select best parameters
# i = dt1
# x_train = etf_data.loc[((etf_data['Date']>=dates[i]) & (etf_data['Date']<dates[i+252])),include_columns] #train with 12 mos
# y_train = etf_data.loc[((etf_data['Date']>=dates[i]) & (etf_data['Date']<dates[i+252])),['target']] #train with 12 mos
# x_train_nmpy = x_train.as_matrix()
# y_train_nmpy = np.ravel(y_train.as_matrix())

# param_grid = { 
# 'n_estimators': [100,300,500,700,1000],
# 'max_features': ['auto','log2',None],
# 'max_depth' : [4,5,6,7,8,None],
# 'criterion' :['gini','entropy']}

# rfc=RandomForestClassifier(n_jobs=32,random_state=54321)
# CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5, n_jobs=32, verbose=1)
# CV_rfc.fit(x_train_nmpy, y_train_nmpy)

#print(CV_rfc.best_params_)
#{'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'n_estimators': 700}

# %%
#for i in range(dt2,dt_end,21): #for restart
for i in range(dt2,dt_end,21):
    print("Building model to predict for ",dates[i+273])
    x_train = etf_data.loc[((etf_data['Date']>=dates[i]) & (etf_data['Date']<dates[i+252])),include_columns] #train with 12 mos
    y_train = etf_data.loc[((etf_data['Date']>=dates[i]) & (etf_data['Date']<dates[i+252])),['target']] #train with 12 mos

#predict one day
    x_test = etf_data.loc[(etf_data['Date']==dates[i+273]),include_columns] #predict one day-must be 21 days removed from training
    y_test = etf_data.loc[(etf_data['Date']==dates[i+273]),['target']] #predict if etf >= market
    returns = etf_data.loc[(etf_data['Date']==dates[i+273]),['delta_p_L-21']]
    mkt_return = etf_data.loc[(etf_data['Date']==dates[i+273]),['ivv_delta_p_L-21']]
    x_train_nmpy = x_train.as_matrix()
    y_train_nmpy = np.ravel(y_train.as_matrix())
#     x_eval_nmpy = x_eval.as_matrix()
#     y_eval_nmpy = y_eval.as_matrix()
    x_test_nmpy = x_test.as_matrix()
    y_test_nmpy = np.ravel(y_test.as_matrix())
    returns_nmpy = returns.as_matrix()
    mkt_return_nmpy = mkt_return.as_matrix()
    
#     rf = RandomForestClassifier(**CV_rfc.best_params_,n_jobs=32,random_state=54321,verbose=1)

    rf = RandomForestClassifier(n_estimators=700, n_jobs=32, max_depth=8, criterion='gini',
                                verbose=0,max_features=None,random_state=54321)
    rf.fit(x_train_nmpy, y_train_nmpy)
    
    y_pred_model = rf.predict_proba(x_test_nmpy)[:,1]
    y_train_model = rf.predict(x_train_nmpy)
    y_test_model = rf.predict(x_test_nmpy)
    
    feat_import = pd.DataFrame({'Feature':include_columns,'Importance': rf.feature_importances_})
    feat_import.sort_values(by='Importance',inplace=True,ascending=False) 
    feat_import.reset_index(drop=True,inplace=True)

    y_check = np.column_stack((y_test_nmpy, y_pred_model,mkt_return_nmpy,returns_nmpy))
    y_check_df = pd.DataFrame(y_check,columns=['true_value','pred_value','mkt_return','returns'])
    y_check_df.sort_values('pred_value',inplace=True,ascending=False)
    y_check_df.reset_index(inplace=True,drop=True)
    t_hold = y_check_df['pred_value'][14]
    
    print('Model Variable Importance Top 10:')
    print(feat_import.iloc[0:10,])
    print('*****************************')
    print('roc_auc_score on training: {:.4f}'.format(roc_auc_score(y_train_nmpy,y_train_model)))
    print('roc_auc_score on testing: {:.4f}'.format(roc_auc_score(y_test_nmpy,y_test_model)))
    print('*****************************')
    print('Confusion Matrix Threshold: {:.6f}'.format(t_hold))
    print('*****************************')
    print('Model Eval Results:')
    print('*****************************')
    confusion = confusion_matrix(y_test_nmpy, (y_pred_model>=t_hold).astype(int))
#     fpr, tpr, thresholds = roc_curve(y_test_nmpy, (y_model_array>0.5).astype(int), pos_label=1)
    precision = confusion[1,1]/(confusion[1,1]+confusion[0,1])
    print('Confusion Matrix:\n',confusion)
    print('Precision:',round(precision,4))
    print("Model Top Five Picks")
    print(" Avg rtn top 5:", round(y_check_df['returns'][0:5].mean(),4))
    print(y_check_df.head(5))
    print("Model 2nd Five Picks")
    print(" Avg rtn 2nd 5:", round(y_check_df['returns'][5:10].mean(),4))
    print(y_check_df.iloc[5:10,])
    print("Model 3rd Five Picks")
    print(" Avg rtn 3rd 5:", round(y_check_df['returns'][10:15].mean(),4))
    print(y_check_df.iloc[10:15,])    
    print("Model Bottom Five Picks")
    print(" Avg rtn bottom 5:", round(y_check_df['returns'][-5:].mean(),4))
    print(y_check_df.tail(5))
    print('********************************************************')
    if i == dt1:
        predict_data = etf_data.loc[(etf_data['Date']==dates[i+273]),['Date','sym','rank_p_L-21']]
        predict_data['predict'] = y_pred_model
        predict_data.to_csv(etf_predict_file)
    else:
        predict_data = etf_data.loc[(etf_data['Date']==dates[i+273]),['Date','sym','rank_p_L-21']]
        predict_data['predict'] = y_pred_model
        predict_data.to_csv(etf_predict_file,header=False,mode='a')
# Out:
# Building model to predict for  2016-04-07
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0     w252_rank_v_L252_avg    0.023874
# 1     w252_rank_p_L252_avg    0.022771
# 2       w21_rank_v_L42_avg    0.018086
# 3       w21_rank_p_L42_avg    0.017960
# 4  ivv_w42_rank_v_L189_avg    0.017607
# 5  ivv_w42_rank_p_L189_avg    0.017142
# 6       w84_rank_p_L21_avg    0.015891
# 7       w84_rank_v_L21_avg    0.015470
# 8       w84_rank_p_L63_avg    0.014362
# 9   ivv_w21_rank_p_L84_avg    0.013907
# *****************************
# roc_auc_score on training: 0.8308
# roc_auc_score on testing: 0.4675
# *****************************
# Confusion Matrix Threshold: 0.502893
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[55  8]
#  [83  7]]
# Precision: 0.4667
# Model Top Five Picks
#  Avg rtn top 5: 0.0066
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.617652    0.008977  0.031162
# 1         0.0    0.598084    0.008977 -0.006562
# 2         0.0    0.597196    0.008977 -0.021853
# 3         1.0    0.596232    0.008977  0.035325
# 4         0.0    0.595216    0.008977 -0.005213
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0059
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.591686    0.008977 -0.008125
# 6         0.0    0.577205    0.008977 -0.011566
# 7         0.0    0.572719    0.008977  0.007748
# 8         0.0    0.546835    0.008977 -0.090559
# 9         1.0    0.542538    0.008977  0.073036
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0214
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.540046    0.008977  0.015138
# 11         0.0    0.513826    0.008977 -0.034560
# 12         1.0    0.506443    0.008977  0.061634
# 13         1.0    0.505866    0.008977  0.048138
# 14         1.0    0.502893    0.008977  0.016619
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0321
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.234779    0.008977  0.001673
# 149         0.0    0.231522    0.008977  0.004243
# 150         1.0    0.230827    0.008977  0.148481
# 151         0.0    0.229559    0.008977  0.004684
# 152         0.0    0.229050    0.008977  0.001627
# ********************************************************
# Building model to predict for  2016-05-06
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w42_rank_v_L189_avg    0.024672
# 1     w252_rank_v_L252_avg    0.023861
# 2  ivv_w42_rank_p_L189_avg    0.023567
# 3       w42_rank_v_L42_avg    0.022886
# 4     w252_rank_p_L252_avg    0.022351
# 5       w42_rank_p_L42_avg    0.021779
# 6      w189_rank_v_L05_avg    0.010868
# 7      w189_rank_p_L05_avg    0.009797
# 8       w21_rank_v_L21_avg    0.008900
# 9   ivv_w84_rank_p_L05_avg    0.008853
# *****************************
# roc_auc_score on training: 0.8358
# roc_auc_score on testing: 0.5427
# *****************************
# Confusion Matrix Threshold: 0.457782
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[63  1]
#  [75 14]]
# Precision: 0.9333
# Model Top Five Picks
#  Avg rtn top 5: 0.0656
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.596336    0.028819  0.065389
# 1         1.0    0.582519    0.028819  0.116694
# 2         1.0    0.556344    0.028819  0.061077
# 3         0.0    0.549125    0.028819  0.028148
# 4         1.0    0.543347    0.028819  0.056833
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0411
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.539272    0.028819  0.048301
# 6         1.0    0.513589    0.028819  0.030409
# 7         1.0    0.508342    0.028819  0.035509
# 8         1.0    0.507029    0.028819  0.035037
# 9         1.0    0.502103    0.028819  0.056140
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0588
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.493540    0.028819  0.080520
# 11         1.0    0.490320    0.028819  0.034314
# 12         1.0    0.474598    0.028819  0.050798
# 13         1.0    0.467961    0.028819  0.036516
# 14         1.0    0.457782    0.028819  0.091978
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0299
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.206313    0.028819  0.034655
# 149         0.0    0.205908    0.028819  0.028774
# 150         1.0    0.204680    0.028819  0.033818
# 151         0.0    0.204256    0.028819  0.025768
# 152         0.0    0.172278    0.028819  0.026675
# ********************************************************
# Building model to predict for  2016-06-07
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w42_rank_p_L189_avg    0.031771
# 1  ivv_w42_rank_v_L189_avg    0.031280
# 2       w42_rank_v_L42_avg    0.022912
# 3       w42_rank_p_L42_avg    0.022183
# 4     w252_rank_v_L252_avg    0.019538
# 5     w252_rank_p_L252_avg    0.018207
# 6       w84_rank_v_L63_avg    0.016787
# 7  ivv_w84_rank_v_L189_avg    0.016291
# 8       w84_rank_p_L63_avg    0.016098
# 9  ivv_w84_rank_p_L189_avg    0.015500
# *****************************
# roc_auc_score on training: 0.8133
# roc_auc_score on testing: 0.6633
# *****************************
# Confusion Matrix Threshold: 0.545185
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[94  1]
#  [44 14]]
# Precision: 0.9333
# Model Top Five Picks
#  Avg rtn top 5: 0.0033
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.624457   -0.005191  0.000652
# 1         1.0    0.622523   -0.005191  0.004119
# 2         1.0    0.616192   -0.005191  0.002178
# 3         1.0    0.597952   -0.005191  0.004288
# 4         1.0    0.584001   -0.005191  0.005503
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0231
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.583856   -0.005191  0.006133
# 6         1.0    0.580185   -0.005191  0.014330
# 7         0.0    0.577550   -0.005191 -0.156508
# 8         1.0    0.573201   -0.005191  0.006936
# 9         1.0    0.566276   -0.005191  0.013779
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0165
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.565088   -0.005191  0.009068
# 11         1.0    0.554541   -0.005191  0.018371
# 12         1.0    0.554302   -0.005191  0.013386
# 13         1.0    0.552745   -0.005191  0.021916
# 14         1.0    0.545185   -0.005191  0.019973
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0399
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.241281   -0.005191 -0.075920
# 149         0.0    0.240459   -0.005191 -0.023581
# 150         0.0    0.232253   -0.005191 -0.023849
# 151         1.0    0.221080   -0.005191  0.001466
# 152         0.0    0.217043   -0.005191 -0.077806
# ********************************************************
# Building model to predict for  2016-07-07
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w42_rank_v_L189_avg    0.032300
# 1  ivv_w42_rank_p_L189_avg    0.030114
# 2  ivv_w189_rank_v_L42_avg    0.018149
# 3     w252_rank_v_L252_avg    0.017655
# 4  ivv_w189_rank_p_L42_avg    0.017548
# 5     w252_rank_p_L252_avg    0.016464
# 6       w21_rank_v_L42_avg    0.015467
# 7       w21_rank_p_L42_avg    0.015323
# 8       w42_rank_v_L42_avg    0.014859
# 9       w42_rank_p_L42_avg    0.014077
# *****************************
# roc_auc_score on training: 0.8185
# roc_auc_score on testing: 0.4915
# *****************************
# Confusion Matrix Threshold: 0.503524
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[54  7]
#  [84  8]]
# Precision: 0.5333
# Model Top Five Picks
#  Avg rtn top 5: 0.0482
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.643362    0.041489  0.085523
# 1         0.0    0.625814    0.041489  0.007990
# 2         1.0    0.617834    0.041489  0.045748
# 3         1.0    0.576848    0.041489  0.054285
# 4         1.0    0.564248    0.041489  0.047430
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0356
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.563545    0.041489  0.145776
# 6         1.0    0.559285    0.041489  0.048595
# 7         0.0    0.549497    0.041489  0.018425
# 8         0.0    0.544695    0.041489 -0.003711
# 9         0.0    0.539717    0.041489 -0.030848
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0335
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.526594    0.041489  0.021686
# 11         1.0    0.523636    0.041489  0.049280
# 12         0.0    0.510468    0.041489  0.027149
# 13         1.0    0.504553    0.041489  0.044108
# 14         0.0    0.503524    0.041489  0.025317
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0587
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.303781    0.041489  0.070715
# 149         1.0    0.302735    0.041489  0.052703
# 150         0.0    0.288139    0.041489  0.003704
# 151         1.0    0.280978    0.041489  0.109954
# 152         1.0    0.270859    0.041489  0.056257
# ********************************************************
# Building model to predict for  2016-08-05
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w42_rank_p_L189_avg    0.029163
# 1  ivv_w42_rank_v_L189_avg    0.027441
# 2  ivv_w189_rank_v_L42_avg    0.022062
# 3  ivv_w189_rank_p_L42_avg    0.020409
# 4  ivv_w10_rank_p_L189_avg    0.015766
# 5       w21_rank_p_L42_avg    0.015167
# 6  ivv_w10_rank_v_L189_avg    0.015107
# 7       w21_rank_v_L42_avg    0.014162
# 8     w252_rank_v_L252_avg    0.014073
# 9     w252_rank_p_L252_avg    0.013833
# *****************************
# roc_auc_score on training: 0.8245
# roc_auc_score on testing: 0.6242
# *****************************
# Confusion Matrix Threshold: 0.563144
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[ 37   2]
#  [101  13]]
# Precision: 0.8667
# Model Top Five Picks
#  Avg rtn top 5: 0.0406
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.592686    0.004421  0.024905
# 1         1.0    0.589547    0.004421  0.097877
# 2         1.0    0.574165    0.004421  0.016002
# 3         1.0    0.569980    0.004421  0.007326
# 4         1.0    0.569346    0.004421  0.057083
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0265
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.566895    0.004421  0.027841
# 6         1.0    0.566157    0.004421  0.060218
# 7         1.0    0.566157    0.004421  0.042214
# 8         1.0    0.566080    0.004421  0.043257
# 9         0.0    0.565725    0.004421 -0.041109
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0437
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.565031    0.004421  0.050592
# 11         0.0    0.563420    0.004421  0.003772
# 12         1.0    0.563330    0.004421  0.071390
# 13         1.0    0.563172    0.004421  0.051188
# 14         1.0    0.563144    0.004421  0.041753
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0109
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.283454    0.004421  0.013395
# 149         0.0    0.280163    0.004421  0.001279
# 150         1.0    0.278903    0.004421  0.007857
# 151         1.0    0.267124    0.004421  0.010177
# 152         1.0    0.263817    0.004421  0.021848
# ********************************************************
# Building model to predict for  2016-09-06
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0       w21_rank_p_L42_avg    0.026422
# 1  ivv_w42_rank_v_L189_avg    0.026099
# 2       w21_rank_v_L42_avg    0.025798
# 3  ivv_w189_rank_v_L42_avg    0.025616
# 4  ivv_w42_rank_p_L189_avg    0.024478
# 5  ivv_w10_rank_v_L252_avg    0.024306
# 6  ivv_w189_rank_p_L42_avg    0.023392
# 7  ivv_w10_rank_p_L252_avg    0.021193
# 8       w42_rank_p_L84_avg    0.019194
# 9       w42_rank_v_L84_avg    0.018741
# *****************************
# roc_auc_score on training: 0.8212
# roc_auc_score on testing: 0.5630
# *****************************
# Confusion Matrix Threshold: 0.672316
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[56  1]
#  [82 14]]
# Precision: 0.9333
# Model Top Five Picks
#  Avg rtn top 5: 0.0238
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.722671   -0.010794 -0.001543
# 1         1.0    0.721839   -0.010794  0.060375
# 2         1.0    0.717272   -0.010794  0.059566
# 3         1.0    0.704360   -0.010794  0.002784
# 4         1.0    0.694257   -0.010794 -0.002062
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0099
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.694049   -0.010794 -0.001424
# 6         1.0    0.692076   -0.010794 -0.002188
# 7         1.0    0.686450   -0.010794 -0.004151
# 8         1.0    0.685737   -0.010794  0.000208
# 9         0.0    0.679640   -0.010794 -0.041901
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0036
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.677589   -0.010794 -0.004666
# 11         1.0    0.676627   -0.010794 -0.008041
# 12         1.0    0.675933   -0.010794 -0.001596
# 13         1.0    0.673661   -0.010794 -0.003797
# 14         1.0    0.672316   -0.010794  0.000295
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0059
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.378080   -0.010794 -0.010530
# 149         0.0    0.369888   -0.010794 -0.015100
# 150         0.0    0.369604   -0.010794 -0.011240
# 151         0.0    0.365291   -0.010794 -0.017177
# 152         1.0    0.354978   -0.010794  0.024350
# ********************************************************
# Building model to predict for  2016-10-05
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0       w21_rank_v_L42_avg    0.037860
# 1  ivv_w189_rank_v_L42_avg    0.031313
# 2       w21_rank_p_L42_avg    0.031209
# 3  ivv_w189_rank_p_L42_avg    0.029323
# 4  ivv_w42_rank_p_L189_avg    0.024337
# 5  ivv_w42_rank_v_L189_avg    0.020352
# 6       w84_rank_v_L63_avg    0.020147
# 7       w84_rank_p_L63_avg    0.019231
# 8     w252_rank_v_L252_avg    0.013706
# 9     w252_rank_p_L252_avg    0.013394
# *****************************
# roc_auc_score on training: 0.8206
# roc_auc_score on testing: 0.5488
# *****************************
# Confusion Matrix Threshold: 0.385643
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[70  3]
#  [68 12]]
# Precision: 0.8
# Model Top Five Picks
#  Avg rtn top 5: -0.0293
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.768620   -0.031675 -0.047916
# 1         1.0    0.713257   -0.031675 -0.023110
# 2         1.0    0.708739   -0.031675 -0.027193
# 3         1.0    0.665006   -0.031675 -0.009812
# 4         0.0    0.652388   -0.031675 -0.038622
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0148
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.646148   -0.031675 -0.023841
# 6         1.0    0.614222   -0.031675 -0.023882
# 7         1.0    0.569622   -0.031675 -0.025112
# 8         1.0    0.540820   -0.031675  0.027005
# 9         1.0    0.526699   -0.031675 -0.027982
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0223
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.514119   -0.031675 -0.027945
# 11         1.0    0.509096   -0.031675  0.033828
# 12         0.0    0.438262   -0.031675 -0.083903
# 13         1.0    0.388702   -0.031675 -0.003097
# 14         1.0    0.385643   -0.031675 -0.030441
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0424
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.021308   -0.031675 -0.038651
# 149         0.0    0.020836   -0.031675 -0.040000
# 150         0.0    0.020104   -0.031675 -0.050724
# 151         0.0    0.016256   -0.031675 -0.033894
# 152         0.0    0.015251   -0.031675 -0.048797
# ********************************************************
# Building model to predict for  2016-11-03
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0   ivv_w63_rank_p_L126_avg    0.022609
# 1        w21_rank_v_L42_avg    0.022370
# 2   ivv_w63_rank_v_L126_avg    0.021985
# 3        w21_rank_p_L42_avg    0.018999
# 4        w42_rank_v_L84_avg    0.018867
# 5        w42_rank_p_L84_avg    0.018458
# 6  ivv_w252_rank_p_L252_avg    0.016301
# 7   ivv_w84_rank_v_L189_avg    0.014155
# 8   ivv_w84_rank_p_L189_avg    0.013669
# 9  ivv_w252_rank_v_L252_avg    0.013178
# *****************************
# roc_auc_score on training: 0.8140
# roc_auc_score on testing: 0.5153
# *****************************
# Confusion Matrix Threshold: 0.486937
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[106  10]
#  [ 32   5]]
# Precision: 0.3333
# Model Top Five Picks
#  Avg rtn top 5: 0.0547
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.637912    0.057947  0.088136
# 1         1.0    0.624933    0.057947  0.184885
# 2         0.0    0.618086    0.057947 -0.003799
# 3         0.0    0.561135    0.057947 -0.014310
# 4         0.0    0.534590    0.057947  0.018722
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0408
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.533375    0.057947  0.022309
# 6         1.0    0.532355    0.057947  0.171829
# 7         0.0    0.522936    0.057947  0.032367
# 8         0.0    0.521612    0.057947  0.030402
# 9         0.0    0.515423    0.057947 -0.052962
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0311
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.509645    0.057947  0.073719
# 11         0.0    0.506660    0.057947 -0.043619
# 12         0.0    0.500539    0.057947 -0.008985
# 13         0.0    0.490266    0.057947  0.047044
# 14         1.0    0.486937    0.057947  0.087302
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.011
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.279305    0.057947 -0.055249
# 149         0.0    0.271027    0.057947  0.027218
# 150         0.0    0.240038    0.057947  0.046653
# 151         0.0    0.197463    0.057947 -0.037324
# 152         0.0    0.174458    0.057947 -0.036252
# ********************************************************
# Building model to predict for  2016-12-05
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w63_rank_p_L126_avg    0.022934
# 1  ivv_w63_rank_v_L126_avg    0.021285
# 2       w21_rank_p_L42_avg    0.020197
# 3       w42_rank_v_L84_avg    0.018919
# 4       w21_rank_v_L42_avg    0.018363
# 5       w42_rank_p_L84_avg    0.017146
# 6  ivv_w42_rank_p_L189_avg    0.013306
# 7  ivv_w42_rank_v_L189_avg    0.013240
# 8     w126_rank_v_L126_avg    0.012745
# 9     w126_rank_p_L126_avg    0.012558
# *****************************
# roc_auc_score on training: 0.8213
# roc_auc_score on testing: 0.4818
# *****************************
# Confusion Matrix Threshold: 0.655357
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[71 12]
#  [67  3]]
# Precision: 0.2
# Model Top Five Picks
#  Avg rtn top 5: 0.029
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.716000    0.030848  0.029975
# 1         0.0    0.707344    0.030848  0.029843
# 2         1.0    0.700542    0.030848  0.030848
# 3         0.0    0.695922    0.030848  0.022735
# 4         1.0    0.693811    0.030848  0.031357
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0295
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.689574    0.030848  0.030050
# 6         0.0    0.687804    0.030848  0.029299
# 7         0.0    0.687674    0.030848  0.025978
# 8         1.0    0.687531    0.030848  0.031787
# 9         0.0    0.682055    0.030848  0.030478
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0254
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.680338    0.030848  0.027470
# 11         0.0    0.679781    0.030848  0.030181
# 12         0.0    0.666694    0.030848  0.029324
# 13         0.0    0.659014    0.030848  0.019882
# 14         0.0    0.655357    0.030848  0.020370
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0255
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.134931    0.030848  0.024013
# 149         1.0    0.116544    0.030848  0.058481
# 150         0.0    0.111981    0.030848 -0.013448
# 151         1.0    0.100523    0.030848  0.031600
# 152         0.0    0.099048    0.030848  0.026708
# ********************************************************
# Building model to predict for  2017-01-05
# Model Variable Importance Top 10:
#                 Feature  Importance
# 0  w252_rank_v_L252_avg    0.017349
# 1  w252_rank_p_L252_avg    0.017134
# 2    w84_rank_p_L42_avg    0.012293
# 3           rank_p_L189    0.012271
# 4           rank_v_L189    0.012146
# 5   w252_rank_p_L05_avg    0.011472
# 6  w189_rank_v_L126_avg    0.011040
# 7    w84_rank_v_L42_avg    0.010659
# 8   w252_rank_v_L05_avg    0.010642
# 9  w126_rank_v_L189_avg    0.010606
# *****************************
# roc_auc_score on training: 0.8556
# roc_auc_score on testing: 0.4757
# *****************************
# Confusion Matrix Threshold: 0.570823
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[70 12]
#  [68  3]]
# Precision: 0.2
# Model Top Five Picks
#  Avg rtn top 5: -0.0042
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.664377    0.011592  0.007632
# 1         0.0    0.641932    0.011592  0.002030
# 2         0.0    0.633397    0.011592 -0.011509
# 3         0.0    0.629706    0.011592 -0.012773
# 4         0.0    0.625008    0.011592 -0.006288
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0024
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.619526    0.011592  0.012078
# 6         0.0    0.616812    0.011592 -0.002668
# 7         0.0    0.612418    0.011592  0.006066
# 8         0.0    0.609847    0.011592 -0.006385
# 9         0.0    0.607666    0.011592  0.002778
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.005
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.595271    0.011592  0.010680
# 11         0.0    0.594884    0.011592 -0.020184
# 12         1.0    0.591708    0.011592  0.017468
# 13         1.0    0.590339    0.011592  0.016349
# 14         0.0    0.570823    0.011592  0.000586
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0015
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.231877    0.011592  0.005702
# 149         0.0    0.229543    0.011592  0.006923
# 150         0.0    0.228231    0.011592 -0.025810
# 151         1.0    0.225848    0.011592  0.024477
# 152         0.0    0.224157    0.011592 -0.018622
# ********************************************************
# Building model to predict for  2017-02-06
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0   ivv_w63_rank_p_L63_avg    0.031045
# 1   ivv_w63_rank_v_L63_avg    0.029993
# 2   ivv_w42_rank_p_L42_avg    0.027274
# 3   ivv_w42_rank_v_L42_avg    0.027183
# 4      w21_rank_v_L252_avg    0.021226
# 5      w21_rank_p_L252_avg    0.020681
# 6  ivv_w126_rank_p_L63_avg    0.015239
# 7     w252_rank_p_L252_avg    0.014746
# 8     w252_rank_v_L252_avg    0.014409
# 9  ivv_w126_rank_v_L63_avg    0.013710
# *****************************
# roc_auc_score on training: 0.8469
# roc_auc_score on testing: 0.4579
# *****************************
# Confusion Matrix Threshold: 0.696684
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[120  13]
#  [ 18   2]]
# Precision: 0.1333
# Model Top Five Picks
#  Avg rtn top 5: 0.0097
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.808080    0.033467 -0.002435
# 1         0.0    0.776349    0.033467 -0.002503
# 2         0.0    0.768608    0.033467  0.003220
# 3         0.0    0.746406    0.033467  0.031213
# 4         0.0    0.730747    0.033467  0.018931
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0168
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.730518    0.033467  0.017675
# 6         1.0    0.727431    0.033467  0.050242
# 7         0.0    0.727213    0.033467 -0.003124
# 8         0.0    0.725938    0.033467  0.002550
# 9         0.0    0.720589    0.033467  0.016491
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0064
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.720521    0.033467  0.000000
# 11         0.0    0.718638    0.033467 -0.000303
# 12         0.0    0.717129    0.033467 -0.007957
# 13         1.0    0.712166    0.033467  0.037389
# 14         0.0    0.696684    0.033467  0.002760
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0048
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.398276    0.033467  0.040146
# 149         0.0    0.383929    0.033467  0.014780
# 150         0.0    0.376026    0.033467  0.015147
# 151         0.0    0.358791    0.033467 -0.016664
# 152         0.0    0.301605    0.033467 -0.077487
# ********************************************************
# Building model to predict for  2017-03-08
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0   ivv_w63_rank_p_L63_avg    0.026931
# 1   ivv_w63_rank_v_L63_avg    0.025081
# 2   ivv_w42_rank_p_L42_avg    0.024996
# 3  ivv_w10_rank_v_L252_avg    0.023118
# 4   ivv_w42_rank_v_L42_avg    0.022728
# 5  ivv_w126_rank_p_L63_avg    0.021062
# 6  ivv_w126_rank_v_L63_avg    0.019656
# 7  ivv_w10_rank_p_L252_avg    0.019261
# 8      w21_rank_p_L252_avg    0.019110
# 9      w21_rank_v_L252_avg    0.017395
# *****************************
# roc_auc_score on training: 0.8235
# roc_auc_score on testing: 0.5892
# *****************************
# Confusion Matrix Threshold: 0.678576
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[ 24   1]
#  [114  14]]
# Precision: 0.9333
# Model Top Five Picks
#  Avg rtn top 5: 0.0044
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.715322   -0.000638  0.024321
# 1         1.0    0.714041   -0.000638  0.019604
# 2         0.0    0.713063   -0.000638 -0.035871
# 3         1.0    0.706941   -0.000638  0.014361
# 4         1.0    0.705802   -0.000638 -0.000196
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.013
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.705104   -0.000638  0.031216
# 6         1.0    0.703483   -0.000638  0.016615
# 7         1.0    0.698681   -0.000638  0.012558
# 8         1.0    0.696403   -0.000638  0.000699
# 9         1.0    0.690621   -0.000638  0.004013
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0069
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.685355   -0.000638  0.012256
# 11         1.0    0.685286   -0.000638  0.012190
# 12         1.0    0.683159   -0.000638  0.003776
# 13         1.0    0.679064   -0.000638  0.000682
# 14         1.0    0.678576   -0.000638  0.005617
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.022
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.358775   -0.000638  0.009368
# 149         1.0    0.325295   -0.000638  0.042671
# 150         1.0    0.324288   -0.000638  0.013727
# 151         1.0    0.323660   -0.000638  0.007730
# 152         1.0    0.265336   -0.000638  0.036374
# ********************************************************
# Building model to predict for  2017-04-06
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w252_rank_v_L05_avg    0.053961
# 1  ivv_w252_rank_p_L05_avg    0.053224
# 2      w21_rank_p_L252_avg    0.030099
# 3      w21_rank_v_L252_avg    0.029466
# 4   ivv_w42_rank_p_L42_avg    0.029156
# 5   ivv_w42_rank_v_L42_avg    0.028964
# 6               rank_v_L10    0.015072
# 7               rank_p_L10    0.014812
# 8      w126_rank_p_L05_avg    0.010401
# 9      w63_rank_v_L252_avg    0.010081
# *****************************
# roc_auc_score on training: 0.8440
# roc_auc_score on testing: 0.5745
# *****************************
# Confusion Matrix Threshold: 0.611691
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[76  8]
#  [62  7]]
# Precision: 0.4667
# Model Top Five Picks
#  Avg rtn top 5: 0.0116
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.721616    0.018024  0.038997
# 1         0.0    0.703516    0.018024  0.004267
# 2         0.0    0.695073    0.018024 -0.015099
# 3         0.0    0.660925    0.018024  0.010588
# 4         1.0    0.645756    0.018024  0.019128
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0134
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.644805    0.018024  0.019684
# 6         1.0    0.642246    0.018024  0.018024
# 7         0.0    0.635579    0.018024  0.017814
# 8         0.0    0.629016    0.018024 -0.039096
# 9         1.0    0.625897    0.018024  0.050742
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0307
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.623669    0.018024  0.013268
# 11         1.0    0.612538    0.018024  0.053535
# 12         0.0    0.612380    0.018024  0.013704
# 13         0.0    0.612318    0.018024  0.004527
# 14         1.0    0.611691    0.018024  0.068467
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0006
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.182443    0.018024  0.009165
# 149         0.0    0.181542    0.018024  0.002298
# 150         0.0    0.176163    0.018024  0.003733
# 151         0.0    0.169123    0.018024  0.002582
# 152         0.0    0.120340    0.018024 -0.020747
# ********************************************************
# Building model to predict for  2017-05-08
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w63_rank_p_L189_avg    0.057456
# 1  ivv_w63_rank_v_L189_avg    0.055562
# 2      w63_rank_p_L252_avg    0.031608
# 3      w63_rank_v_L252_avg    0.031022
# 4  ivv_w252_rank_v_L10_avg    0.021647
# 5  ivv_w252_rank_p_L10_avg    0.021082
# 6               rank_v_L10    0.015785
# 7               rank_p_L10    0.015356
# 8     w252_rank_v_L252_avg    0.013234
# 9     w252_rank_p_L252_avg    0.012976
# *****************************
# roc_auc_score on training: 0.8409
# roc_auc_score on testing: 0.4228
# *****************************
# Confusion Matrix Threshold: 0.608138
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[64 11]
#  [74  4]]
# Precision: 0.2667
# Model Top Five Picks
#  Avg rtn top 5: 0.0143
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.648723    0.016918 -0.007093
# 1         0.0    0.646249    0.016918 -0.021403
# 2         0.0    0.638493    0.016918 -0.003932
# 3         1.0    0.631661    0.016918  0.073572
# 4         1.0    0.628486    0.016918  0.030231
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.006
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.628386    0.016918  0.028481
# 6         1.0    0.625877    0.016918  0.028816
# 7         0.0    0.622958    0.016918  0.007002
# 8         0.0    0.622769    0.016918 -0.087813
# 9         0.0    0.621184    0.016918 -0.006700
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0181
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.617566    0.016918 -0.040798
# 11         0.0    0.615716    0.016918 -0.074023
# 12         0.0    0.615251    0.016918  0.007335
# 13         0.0    0.610251    0.016918  0.002957
# 14         0.0    0.608138    0.016918  0.014223
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0132
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.243322    0.016918 -0.002548
# 149         0.0    0.239885    0.016918  0.016496
# 150         0.0    0.232816    0.016918 -0.000192
# 151         0.0    0.219157    0.016918  0.015761
# 152         1.0    0.206817    0.016918  0.036371
# ********************************************************
# Building model to predict for  2017-06-07
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w63_rank_p_L189_avg    0.054846
# 1  ivv_w63_rank_v_L189_avg    0.053983
# 2      w63_rank_v_L252_avg    0.033188
# 3      w63_rank_p_L252_avg    0.031544
# 4  ivv_w252_rank_v_L10_avg    0.023370
# 5  ivv_w252_rank_p_L10_avg    0.022898
# 6       w84_rank_p_L21_avg    0.020005
# 7       w84_rank_v_L21_avg    0.019136
# 8     w252_rank_p_L252_avg    0.018878
# 9     w252_rank_v_L252_avg    0.018785
# *****************************
# roc_auc_score on training: 0.8458
# roc_auc_score on testing: 0.5546
# *****************************
# Confusion Matrix Threshold: 0.569461
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[87  6]
#  [51  9]]
# Precision: 0.6
# Model Top Five Picks
#  Avg rtn top 5: 0.0074
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.650321   -0.001747 -0.001687
# 1         1.0    0.610705   -0.001747  0.031768
# 2         1.0    0.605845   -0.001747  0.008537
# 3         1.0    0.601084   -0.001747 -0.001314
# 4         1.0    0.598965   -0.001747 -0.000354
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0075
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.598593   -0.001747 -0.003086
# 6         1.0    0.598020   -0.001747 -0.001747
# 7         0.0    0.587049   -0.001747 -0.012287
# 8         0.0    0.586684   -0.001747 -0.006859
# 9         0.0    0.585700   -0.001747 -0.013315
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0023
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.580328   -0.001747 -0.000185
# 11         1.0    0.577759   -0.001747  0.000356
# 12         1.0    0.574065   -0.001747  0.023072
# 13         0.0    0.573380   -0.001747 -0.032880
# 14         0.0    0.569461   -0.001747 -0.001860
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0063
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.120163   -0.001747 -0.014335
# 149         0.0    0.111797   -0.001747 -0.002835
# 150         0.0    0.109627   -0.001747 -0.002563
# 151         0.0    0.086730   -0.001747 -0.007519
# 152         0.0    0.076975   -0.001747 -0.004285
# ********************************************************
# Building model to predict for  2017-07-07
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w63_rank_p_L189_avg    0.061904
# 1  ivv_w63_rank_v_L189_avg    0.059963
# 2      w63_rank_p_L252_avg    0.032375
# 3      w63_rank_v_L252_avg    0.031905
# 4     w252_rank_v_L252_avg    0.021558
# 5     w252_rank_p_L252_avg    0.020963
# 6      w189_rank_v_L05_avg    0.015963
# 7      w189_rank_p_L05_avg    0.015795
# 8  ivv_w10_rank_p_L126_avg    0.015005
# 9              rank_p_L189    0.013962
# *****************************
# roc_auc_score on training: 0.8455
# roc_auc_score on testing: 0.5791
# *****************************
# Confusion Matrix Threshold: 0.503300
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[75  2]
#  [63 13]]
# Precision: 0.8667
# Model Top Five Picks
#  Avg rtn top 5: 0.0679
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.574080     0.02384  0.036594
# 1         1.0    0.562924     0.02384  0.040733
# 2         1.0    0.559579     0.02384  0.155606
# 3         1.0    0.545196     0.02384  0.054471
# 4         1.0    0.543949     0.02384  0.052142
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0681
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.528245     0.02384  0.090909
# 6         1.0    0.528217     0.02384  0.050591
# 7         1.0    0.527041     0.02384  0.139125
# 8         0.0    0.521347     0.02384  0.021364
# 9         1.0    0.516300     0.02384  0.038627
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0469
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.516110     0.02384  0.023680
# 11         1.0    0.508924     0.02384  0.056917
# 12         1.0    0.505570     0.02384  0.041513
# 13         1.0    0.504281     0.02384  0.072787
# 14         1.0    0.503300     0.02384  0.039362
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0059
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.273909     0.02384  0.006952
# 149         0.0    0.264565     0.02384  0.000970
# 150         0.0    0.263533     0.02384  0.002382
# 151         0.0    0.257436     0.02384  0.005509
# 152         0.0    0.255228     0.02384  0.013495
# ********************************************************
# Building model to predict for  2017-08-07
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w252_rank_p_L05_avg    0.035024
# 1  ivv_w252_rank_v_L05_avg    0.033908
# 2  ivv_w63_rank_p_L189_avg    0.025083
# 3  ivv_w63_rank_v_L189_avg    0.024534
# 4      w63_rank_p_L252_avg    0.020094
# 5     w252_rank_p_L252_avg    0.019518
# 6      w63_rank_v_L252_avg    0.018748
# 7     w252_rank_v_L252_avg    0.018578
# 8  ivv_w10_rank_v_L126_avg    0.016274
# 9  ivv_w10_rank_p_L126_avg    0.014901
# *****************************
# roc_auc_score on training: 0.8707
# roc_auc_score on testing: 0.3725
# *****************************
# Confusion Matrix Threshold: 0.573746
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[46  5]
#  [92 10]]
# Precision: 0.6667
# Model Top Five Picks
#  Avg rtn top 5: -0.0028
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.657866   -0.003647 -0.035303
# 1         1.0    0.648236   -0.003647 -0.001206
# 2         1.0    0.644790   -0.003647  0.010811
# 3         0.0    0.644355   -0.003647 -0.006752
# 4         1.0    0.633698   -0.003647  0.018235
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0036
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.631979   -0.003647 -0.013245
# 6         0.0    0.618758   -0.003647 -0.011902
# 7         1.0    0.615750   -0.003647  0.016709
# 8         1.0    0.614589   -0.003647  0.008384
# 9         0.0    0.613746   -0.003647 -0.018109
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0068
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.597218   -0.003647  0.001951
# 11         1.0    0.588276   -0.003647 -0.003361
# 12         1.0    0.585932   -0.003647  0.004427
# 13         1.0    0.582161   -0.003647  0.005809
# 14         1.0    0.573746   -0.003647  0.025294
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0066
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.133563   -0.003647  0.009376
# 149         1.0    0.133385   -0.003647  0.005621
# 150         1.0    0.132916   -0.003647  0.005627
# 151         1.0    0.128402   -0.003647  0.007011
# 152         1.0    0.115280   -0.003647  0.005480
# ********************************************************
# Building model to predict for  2017-09-06
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w252_rank_v_L10_avg    0.031460
# 1  ivv_w252_rank_p_L10_avg    0.029028
# 2  ivv_w42_rank_v_L189_avg    0.022906
# 3  ivv_w42_rank_p_L189_avg    0.021435
# 4     w252_rank_p_L252_avg    0.018195
# 5     w252_rank_v_L252_avg    0.017940
# 6  ivv_w189_rank_v_L63_avg    0.015325
# 7  ivv_w189_rank_p_L63_avg    0.015111
# 8       w63_rank_v_L21_avg    0.009297
# 9   ivv_w21_rank_v_L05_avg    0.009045
# *****************************
# roc_auc_score on training: 0.8660
# roc_auc_score on testing: 0.4525
# *****************************
# Confusion Matrix Threshold: 0.497714
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[91 13]
#  [47  2]]
# Precision: 0.1333
# Model Top Five Picks
#  Avg rtn top 5: -0.0062
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.587984    0.036537  0.029363
# 1         0.0    0.563638    0.036537 -0.004376
# 2         0.0    0.538061    0.036537 -0.038804
# 3         0.0    0.536849    0.036537  0.020052
# 4         0.0    0.536230    0.036537 -0.037322
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0048
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.523532    0.036537  0.006379
# 6         0.0    0.521194    0.036537  0.028226
# 7         0.0    0.519174    0.036537 -0.044295
# 8         0.0    0.517730    0.036537  0.024511
# 9         0.0    0.515653    0.036537  0.009301
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0294
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.510347    0.036537  0.005088
# 11         0.0    0.509415    0.036537  0.022824
# 12         1.0    0.501622    0.036537  0.070723
# 13         1.0    0.499497    0.036537  0.037500
# 14         0.0    0.497714    0.036537  0.010982
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0354
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.188739    0.036537 -0.006316
# 149         1.0    0.186027    0.036537  0.080050
# 150         0.0    0.183398    0.036537 -0.002296
# 151         1.0    0.182718    0.036537  0.107059
# 152         0.0    0.181646    0.036537 -0.001537
# ********************************************************
# Building model to predict for  2017-10-05
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0   ivv_w126_rank_p_L05_avg    0.031908
# 1   ivv_w126_rank_v_L05_avg    0.030607
# 2   ivv_w189_rank_p_L05_avg    0.023332
# 3   ivv_w189_rank_v_L05_avg    0.022279
# 4      w252_rank_p_L252_avg    0.015013
# 5      w252_rank_v_L252_avg    0.014755
# 6  ivv_w189_rank_v_L126_avg    0.013515
# 7  ivv_w189_rank_p_L126_avg    0.013166
# 8               rank_v_L189    0.012630
# 9         w5_rank_p_L84_avg    0.012520
# *****************************
# roc_auc_score on training: 0.8757
# roc_auc_score on testing: 0.5505
# *****************************
# Confusion Matrix Threshold: 0.470437
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[103   8]
#  [ 35   7]]
# Precision: 0.4667
# Model Top Five Picks
#  Avg rtn top 5: 0.0262
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.598609    0.014822  0.001369
# 1         1.0    0.583037    0.014822  0.016957
# 2         1.0    0.544817    0.014822  0.062555
# 3         1.0    0.544089    0.014822  0.029140
# 4         1.0    0.514353    0.014822  0.020873
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0084
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.511486    0.014822 -0.015708
# 6         1.0    0.505513    0.014822  0.017282
# 7         1.0    0.490303    0.014822  0.024491
# 8         0.0    0.487741    0.014822  0.001641
# 9         0.0    0.487393    0.014822  0.014287
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0131
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.484204    0.014822  0.075035
# 11         0.0    0.482763    0.014822 -0.013671
# 12         0.0    0.480525    0.014822  0.008338
# 13         0.0    0.477207    0.014822 -0.000467
# 14         0.0    0.470437    0.014822 -0.003892
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0094
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.127429    0.014822 -0.013872
# 149         0.0    0.121650    0.014822 -0.002084
# 150         0.0    0.118734    0.014822 -0.018722
# 151         0.0    0.105647    0.014822 -0.002523
# 152         0.0    0.089229    0.014822 -0.010036
# ********************************************************
# Building model to predict for  2017-11-03
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w126_rank_p_L05_avg    0.037943
# 1  ivv_w126_rank_v_L05_avg    0.036723
# 2  ivv_w189_rank_v_L05_avg    0.027818
# 3  ivv_w189_rank_p_L05_avg    0.026265
# 4        w5_rank_p_L84_avg    0.016784
# 5     w252_rank_p_L252_avg    0.015911
# 6     w252_rank_v_L252_avg    0.015163
# 7     w189_rank_v_L126_avg    0.014848
# 8     w189_rank_p_L126_avg    0.014644
# 9        w5_rank_v_L84_avg    0.014168
# *****************************
# roc_auc_score on training: 0.8731
# roc_auc_score on testing: 0.5567
# *****************************
# Confusion Matrix Threshold: 0.692402
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[108  11]
#  [ 30   4]]
# Precision: 0.2667
# Model Top Five Picks
#  Avg rtn top 5: 0.0249
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.772122    0.018487  0.051119
# 1         1.0    0.734673    0.018487  0.028094
# 2         0.0    0.731076    0.018487  0.007673
# 3         0.0    0.727667    0.018487  0.000873
# 4         1.0    0.724385    0.018487  0.036677
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0005
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.724260    0.018487  0.015611
# 6         1.0    0.721521    0.018487  0.020975
# 7         0.0    0.709400    0.018487  0.002310
# 8         0.0    0.705641    0.018487 -0.003276
# 9         0.0    0.704831    0.018487 -0.038256
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0114
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.702434    0.018487  0.001318
# 11         0.0    0.701752    0.018487 -0.043342
# 12         0.0    0.699599    0.018487 -0.005511
# 13         0.0    0.693886    0.018487 -0.002151
# 14         0.0    0.692402    0.018487 -0.007077
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0019
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.355120    0.018487 -0.000507
# 149         0.0    0.348402    0.018487 -0.002507
# 150         0.0    0.344019    0.018487 -0.018205
# 151         1.0    0.320856    0.018487  0.089537
# 152         0.0    0.313258    0.018487 -0.058990
# ********************************************************
# Building model to predict for  2017-12-05
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w42_rank_v_L189_avg    0.054450
# 1  ivv_w42_rank_p_L189_avg    0.051230
# 2   ivv_w63_rank_v_L42_avg    0.029369
# 3   ivv_w63_rank_p_L42_avg    0.028745
# 4   ivv_w63_rank_v_L21_avg    0.019558
# 5   ivv_w63_rank_p_L21_avg    0.019123
# 6        w5_rank_v_L84_avg    0.017634
# 7       w84_rank_v_L21_avg    0.016609
# 8        w5_rank_p_L84_avg    0.016237
# 9       w84_rank_p_L21_avg    0.015853
# *****************************
# roc_auc_score on training: 0.8542
# roc_auc_score on testing: 0.5427
# *****************************
# Confusion Matrix Threshold: 0.504921
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[74  5]
#  [64 10]]
# Precision: 0.6667
# Model Top Five Picks
#  Avg rtn top 5: 0.0587
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.643982    0.043916  0.137926
# 1         1.0    0.589873    0.043916  0.053191
# 2         1.0    0.558382    0.043916  0.048639
# 3         0.0    0.556476    0.043916 -0.006613
# 4         1.0    0.556187    0.043916  0.060217
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0609
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.555187    0.043916  0.039463
# 6         1.0    0.552515    0.043916  0.075990
# 7         1.0    0.543319    0.043916  0.076017
# 8         1.0    0.534885    0.043916  0.051569
# 9         1.0    0.534501    0.043916  0.061664
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0464
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.532560    0.043916  0.036387
# 11         0.0    0.523334    0.043916  0.000508
# 12         1.0    0.513840    0.043916  0.051981
# 13         1.0    0.511215    0.043916  0.101562
# 14         0.0    0.504921    0.043916  0.041646
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0019
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.092600    0.043916  0.001081
# 149         0.0    0.091837    0.043916  0.000048
# 150         0.0    0.091666    0.043916 -0.002014
# 151         0.0    0.091378    0.043916 -0.001525
# 152         0.0    0.087338    0.043916  0.011864
# ********************************************************
# Building model to predict for  2018-01-05
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0  ivv_w252_rank_v_L126_avg    0.044876
# 1  ivv_w252_rank_p_L126_avg    0.042911
# 2  ivv_w126_rank_v_L189_avg    0.029731
# 3  ivv_w126_rank_p_L189_avg    0.028940
# 4       w21_rank_p_L252_avg    0.019353
# 5         w5_rank_v_L84_avg    0.018757
# 6       w21_rank_v_L252_avg    0.018328
# 7         w5_rank_p_L84_avg    0.017689
# 8      w252_rank_v_L252_avg    0.013094
# 9      w252_rank_p_L252_avg    0.013000
# *****************************
# roc_auc_score on training: 0.8702
# roc_auc_score on testing: 0.5139
# *****************************
# Confusion Matrix Threshold: 0.666759
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[74  7]
#  [64  8]]
# Precision: 0.5333
# Model Top Five Picks
#  Avg rtn top 5: -0.0083
#    true_value  pred_value  mkt_return   returns
# 0         1.0    0.737069   -0.014782  0.022507
# 1         0.0    0.733875   -0.014782 -0.021420
# 2         1.0    0.718977   -0.014782 -0.007356
# 3         1.0    0.714123   -0.014782 -0.003403
# 4         0.0    0.710198   -0.014782 -0.031915
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0147
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.703855   -0.014782 -0.030817
# 6         1.0    0.701344   -0.014782 -0.013745
# 7         1.0    0.690268   -0.014782 -0.001512
# 8         1.0    0.687767   -0.014782 -0.001240
# 9         0.0    0.686135   -0.014782 -0.026152
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0306
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.676768   -0.014782 -0.002717
# 11         0.0    0.671093   -0.014782 -0.035142
# 12         0.0    0.668724   -0.014782 -0.078477
# 13         1.0    0.667895   -0.014782 -0.004279
# 14         0.0    0.666759   -0.014782 -0.032546
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0277
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.352337   -0.014782 -0.018970
# 149         0.0    0.333745   -0.014782 -0.093819
# 150         1.0    0.322071   -0.014782  0.021816
# 151         0.0    0.310006   -0.014782 -0.017383
# 152         0.0    0.300380   -0.014782 -0.030264
# ********************************************************
# Building model to predict for  2018-02-06
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0  ivv_w126_rank_v_L126_avg    0.059460
# 1  ivv_w126_rank_p_L126_avg    0.057099
# 2    ivv_w63_rank_p_L21_avg    0.025582
# 3    ivv_w63_rank_v_L21_avg    0.024631
# 4       w126_rank_v_L42_avg    0.016431
# 5      w126_rank_p_L252_avg    0.015984
# 6       w126_rank_p_L42_avg    0.015584
# 7      w126_rank_v_L252_avg    0.013385
# 8      w189_rank_v_L189_avg    0.013053
# 9        w84_rank_p_L21_avg    0.011451
# *****************************
# roc_auc_score on training: 0.8625
# roc_auc_score on testing: 0.4922
# *****************************
# Confusion Matrix Threshold: 0.849627
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[105   9]
#  [ 33   6]]
# Precision: 0.4
# Model Top Five Picks
#  Avg rtn top 5: 0.0113
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.882864    0.017953  0.004493
# 1         0.0    0.880699    0.017953  0.017880
# 2         0.0    0.878041    0.017953  0.002311
# 3         0.0    0.868212    0.017953  0.006664
# 4         1.0    0.867607    0.017953  0.025204
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0115
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.866857    0.017953  0.026129
# 6         0.0    0.865957    0.017953  0.015801
# 7         0.0    0.863930    0.017953 -0.013598
# 8         1.0    0.861194    0.017953  0.026590
# 9         0.0    0.858759    0.017953  0.002377
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0039
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.857919    0.017953  0.025797
# 11         0.0    0.855908    0.017953 -0.048677
# 12         1.0    0.855204    0.017953  0.021452
# 13         0.0    0.853379    0.017953  0.001241
# 14         1.0    0.849627    0.017953  0.019438
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0212
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.371464    0.017953 -0.057685
# 149         0.0    0.358278    0.017953 -0.008170
# 150         1.0    0.340830    0.017953  0.099450
# 151         0.0    0.313223    0.017953 -0.006755
# 152         1.0    0.275646    0.017953  0.078982
# ********************************************************
# Building model to predict for  2018-03-08
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0        w21_rank_v_L05_avg    0.025908
# 1   ivv_w84_rank_p_L126_avg    0.025474
# 2   ivv_w63_rank_v_L189_avg    0.024454
# 3        w21_rank_p_L05_avg    0.023400
# 4   ivv_w84_rank_v_L126_avg    0.022563
# 5   ivv_w42_rank_p_L189_avg    0.021913
# 6   ivv_w42_rank_v_L189_avg    0.021704
# 7   ivv_w63_rank_p_L189_avg    0.021481
# 8      w252_rank_p_L252_avg    0.018149
# 9  ivv_w252_rank_v_L126_avg    0.018105
# *****************************
# roc_auc_score on training: 0.8511
# roc_auc_score on testing: 0.4520
# *****************************
# Confusion Matrix Threshold: 0.581113
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[ 16   8]
#  [122   7]]
# Precision: 0.4667
# Model Top Five Picks
#  Avg rtn top 5: -0.0598
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.672632   -0.044343 -0.062868
# 1         0.0    0.658697   -0.044343 -0.059633
# 2         0.0    0.646177   -0.044343 -0.054159
# 3         0.0    0.644568   -0.044343 -0.052896
# 4         0.0    0.632394   -0.044343 -0.069438
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0058
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.616619   -0.044343 -0.016672
# 6         1.0    0.603766   -0.044343  0.006993
# 7         1.0    0.599523   -0.044343  0.021527
# 8         1.0    0.594217   -0.044343  0.027278
# 9         0.0    0.593711   -0.044343 -0.068146
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0464
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.589274   -0.044343 -0.029210
# 11         0.0    0.585237   -0.044343 -0.050612
# 12         1.0    0.583559   -0.044343  0.028368
# 13         0.0    0.581219   -0.044343 -0.151991
# 14         1.0    0.581113   -0.044343 -0.028336
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0124
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.379606   -0.044343 -0.043595
# 149         1.0    0.378493   -0.044343 -0.020541
# 150         1.0    0.373253   -0.044343  0.014475
# 151         1.0    0.366552   -0.044343 -0.005805
# 152         1.0    0.331900   -0.044343 -0.006782
# ********************************************************
# Building model to predict for  2018-04-09
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w42_rank_p_L189_avg    0.046900
# 1  ivv_w42_rank_v_L189_avg    0.045668
# 2  ivv_w84_rank_p_L126_avg    0.035581
# 3  ivv_w84_rank_v_L126_avg    0.031360
# 4       w21_rank_v_L05_avg    0.019456
# 5       w21_rank_p_L05_avg    0.018685
# 6     w189_rank_p_L252_avg    0.016059
# 7     w189_rank_v_L252_avg    0.014988
# 8     w252_rank_v_L252_avg    0.014294
# 9     w252_rank_p_L252_avg    0.013821
# *****************************
# roc_auc_score on training: 0.8583
# roc_auc_score on testing: 0.4825
# *****************************
# Confusion Matrix Threshold: 0.857671
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[97 15]
#  [41  0]]
# Precision: 0.0
# Model Top Five Picks
#  Avg rtn top 5: -0.0098
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.895836    0.022764 -0.032006
# 1         0.0    0.891691    0.022764  0.000923
# 2         0.0    0.890619    0.022764 -0.003213
# 3         0.0    0.881861    0.022764  0.000083
# 4         0.0    0.876913    0.022764 -0.014898
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0021
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.865587    0.022764  0.000292
# 6         0.0    0.864404    0.022764 -0.006437
# 7         0.0    0.863885    0.022764 -0.011038
# 8         0.0    0.860630    0.022764  0.016743
# 9         0.0    0.860600    0.022764 -0.010002
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0119
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.860118    0.022764 -0.040167
# 11         0.0    0.859115    0.022764  0.001672
# 12         0.0    0.858489    0.022764 -0.006290
# 13         0.0    0.857825    0.022764 -0.006998
# 14         0.0    0.857671    0.022764 -0.007632
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0232
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.432515    0.022764 -0.039884
# 149         0.0    0.431566    0.022764 -0.054136
# 150         0.0    0.402011    0.022764 -0.030627
# 151         0.0    0.362902    0.022764 -0.026591
# 152         1.0    0.360192    0.022764  0.035460
# ********************************************************
# Building model to predict for  2018-05-08
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0   ivv_w84_rank_p_L63_avg    0.036322
# 1  ivv_w84_rank_p_L126_avg    0.033833
# 2   ivv_w84_rank_v_L63_avg    0.033496
# 3  ivv_w84_rank_v_L126_avg    0.031893
# 4       w21_rank_p_L05_avg    0.027187
# 5       w21_rank_v_L05_avg    0.024830
# 6  ivv_w42_rank_v_L189_avg    0.022575
# 7  ivv_w42_rank_p_L189_avg    0.021250
# 8     w189_rank_p_L252_avg    0.017517
# 9     w189_rank_v_L252_avg    0.017381
# *****************************
# roc_auc_score on training: 0.8386
# roc_auc_score on testing: 0.4938
# *****************************
# Confusion Matrix Threshold: 0.527872
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[111  11]
#  [ 27   4]]
# Precision: 0.2667
# Model Top Five Picks
#  Avg rtn top 5: 0.0006
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.690333    0.039378 -0.004186
# 1         1.0    0.679489    0.039378  0.050207
# 2         0.0    0.676683    0.039378 -0.007260
# 3         0.0    0.651352    0.039378 -0.035745
# 4         0.0    0.572962    0.039378 -0.000190
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0006
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.566319    0.039378 -0.017874
# 6         0.0    0.561541    0.039378 -0.028985
# 7         0.0    0.560678    0.039378 -0.023572
# 8         0.0    0.548619    0.039378  0.027217
# 9         1.0    0.546204    0.039378  0.040264
# Model 3rd Five Picks
#  Avg rtn 3rd 5: 0.0247
#     true_value  pred_value  mkt_return   returns
# 10         1.0    0.543165    0.039378  0.042582
# 11         0.0    0.538638    0.039378 -0.011335
# 12         0.0    0.530877    0.039378  0.028417
# 13         1.0    0.529237    0.039378  0.041155
# 14         0.0    0.527872    0.039378  0.022431
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0005
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.197719    0.039378  0.007129
# 149         0.0    0.186048    0.039378  0.004783
# 150         0.0    0.185077    0.039378  0.006450
# 151         0.0    0.180654    0.039378 -0.019287
# 152         0.0    0.165127    0.039378  0.003625
# ********************************************************
# Building model to predict for  2018-06-07
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0    ivv_w84_rank_v_L63_avg    0.043810
# 1    ivv_w84_rank_p_L63_avg    0.037590
# 2      w252_rank_p_L252_avg    0.024870
# 3      w252_rank_v_L252_avg    0.024372
# 4  ivv_w126_rank_p_L252_avg    0.020119
# 5      w189_rank_v_L189_avg    0.018507
# 6  ivv_w126_rank_v_L252_avg    0.018178
# 7      w189_rank_p_L189_avg    0.017572
# 8   ivv_w63_rank_p_L189_avg    0.014789
# 9   ivv_w63_rank_v_L189_avg    0.014213
# *****************************
# roc_auc_score on training: 0.8520
# roc_auc_score on testing: 0.4149
# *****************************
# Confusion Matrix Threshold: 0.697625
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[85 12]
#  [53  3]]
# Precision: 0.2
# Model Top Five Picks
#  Avg rtn top 5: -0.0341
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.760912    0.006674 -0.096621
# 1         0.0    0.750571    0.006674 -0.029123
# 2         1.0    0.740038    0.006674  0.022205
# 3         0.0    0.733845    0.006674 -0.020365
# 4         0.0    0.724008    0.006674 -0.046723
# Model 2nd Five Picks
#  Avg rtn 2nd 5: -0.0148
#    true_value  pred_value  mkt_return   returns
# 5         0.0    0.723106    0.006674 -0.011277
# 6         0.0    0.718181    0.006674 -0.039560
# 7         1.0    0.716907    0.006674  0.022087
# 8         0.0    0.716114    0.006674 -0.044768
# 9         0.0    0.714723    0.006674 -0.000563
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0349
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.705660    0.006674 -0.004684
# 11         0.0    0.704677    0.006674 -0.058702
# 12         0.0    0.703078    0.006674 -0.092768
# 13         1.0    0.699134    0.006674  0.018461
# 14         0.0    0.697625    0.006674 -0.036615
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0361
#      true_value  pred_value  mkt_return   returns
# 148         1.0    0.432166    0.006674  0.042953
# 149         1.0    0.421289    0.006674  0.015843
# 150         1.0    0.408633    0.006674  0.046386
# 151         1.0    0.375349    0.006674  0.041643
# 152         1.0    0.328027    0.006674  0.033680
# ********************************************************
# Building model to predict for  2018-07-09
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0  ivv_w126_rank_v_L252_avg    0.062807
# 1  ivv_w126_rank_p_L252_avg    0.060246
# 2    ivv_w84_rank_p_L63_avg    0.029549
# 3      w252_rank_v_L252_avg    0.028646
# 4    ivv_w84_rank_v_L63_avg    0.026305
# 5      w252_rank_p_L252_avg    0.026166
# 6      w126_rank_p_L126_avg    0.015416
# 7        w63_rank_v_L10_avg    0.015056
# 8        w10_rank_p_L21_avg    0.014864
# 9        w10_rank_v_L21_avg    0.014732
# *****************************
# roc_auc_score on training: 0.8462
# roc_auc_score on testing: 0.3568
# *****************************
# Confusion Matrix Threshold: 0.648289
# *****************************
# Model Eval Results:
# *****************************
# Confusion Matrix:
#  [[111  13]
#  [ 27   2]]
# Precision: 0.1333
# Model Top Five Picks
#  Avg rtn top 5: 0.0094
#    true_value  pred_value  mkt_return   returns
# 0         0.0    0.704483    0.027376  0.002972
# 1         0.0    0.698472    0.027376  0.002842
# 2         0.0    0.697111    0.027376 -0.006777
# 3         0.0    0.693639    0.027376 -0.001397
# 4         1.0    0.688200    0.027376  0.049395
# Model 2nd Five Picks
#  Avg rtn 2nd 5: 0.0061
#    true_value  pred_value  mkt_return   returns
# 5         1.0    0.686298    0.027376  0.045952
# 6         0.0    0.673933    0.027376 -0.002525
# 7         0.0    0.673867    0.027376  0.005103
# 8         0.0    0.658303    0.027376 -0.005765
# 9         0.0    0.654930    0.027376 -0.012062
# Model 3rd Five Picks
#  Avg rtn 3rd 5: -0.0102
#     true_value  pred_value  mkt_return   returns
# 10         0.0    0.653287    0.027376 -0.002059
# 11         0.0    0.652698    0.027376  0.000047
# 12         0.0    0.651821    0.027376  0.001808
# 13         0.0    0.651680    0.027376 -0.048780
# 14         0.0    0.648289    0.027376 -0.001994
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0033
#      true_value  pred_value  mkt_return   returns
# 148         0.0    0.085928    0.027376 -0.004768
# 149         0.0    0.084629    0.027376  0.007524
# 150         0.0    0.081738    0.027376 -0.014706
# 151         0.0    0.081350    0.027376 -0.001107
# 152         0.0    0.073359    0.027376 -0.003314
# ********************************************************

# %%
import pandas as pd
import numpy as np
import os
import sklearn
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error
import xgboost
from xgboost import XGBClassifier
# %matplotlib notebook

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 500)
pd.options.mode.chained_assignment = None  # default='warn'

# %%
data_path = '/home/mvkrein/etf_model/data'
etf_data_file = os.path.join(data_path,'etf_new_var_20180910.csv')
etf_data = pd.read_csv(etf_data_file,index_col=0)

# %%
etf_study_file = os.path.join(data_path,'ETF_list_min_6yr_history.csv')
etf_list = pd.read_csv(etf_study_file,index_col=0)
etf_data.sort_values(['Date','sym'],ascending=True,inplace=True)
etf_data.reset_index(drop=True,inplace=True)

# %%
drop_columns = ['Date','sym','p', 'v', 'p_L05', 'v_L05', 'p_L10', 'v_L10', 'p_L21', 'v_L21', 'p_L42', 'v_L42', 'p_L63', \
                'v_L63', 'p_L84', 'v_L84', 'p_L126', 'v_L126', 'p_L189', 'v_L189', 'p_L252', 'v_L252',\
                'p_L-21', 'v_L-21', 'delta_p_L05', 'delta_p_L10', 'delta_p_L21', 'delta_p_L42', 'delta_p_L63', \
                'delta_p_L84', 'delta_p_L126', 'delta_p_L189', 'delta_p_L252', 'delta_p_L-21', 'delta_v_L05',\
                'delta_v_L10', 'delta_v_L21', 'delta_v_L42', 'delta_v_L63', 'delta_v_L84', 'delta_v_L126', \
                'delta_v_L189', 'delta_v_L252','rank_p_L-21', 'ivv_delta_p_L-21', 'target']

rank_col = ['rank_p_L05','rank_p_L10','rank_p_L21','rank_p_L42',\
            'rank_p_L63','rank_p_L84','rank_p_L126','rank_p_L189','rank_p_L252']

# %%
all_columns = list(etf_data.columns)

# %%
include_columns = [x for x in all_columns if x not in drop_columns]
# include_columns = ['rank_p_L05','rank_p_L10','rank_p_L21','rank_p_L42',\
#             'rank_p_L63','rank_p_L84','rank_p_L126','rank_p_L189','rank_p_L252']
# include_columns = ['rank_p_L05','rank_p_L21','rank_p_L42','rank_p_L252']

# %%
len(include_columns)
# Out:
# 360

# %%
dates = list(etf_data['Date'].unique())
# dates[1671]

# %%
symbols = etf_list['Symbol'].unique()

# %%
len(symbols)
# Out:
# 153

# %%
#Each year has 252 trading dates.  Need two years to fully develop variables.
dt1 = 504 #This is the first day that all variables are developed
# dt1 = 504 + 21 + 273 #This is the first day that all variables are developed 2016-04-07
# make all dates relative to dt1
# for one year training - add 252
# to evaluate for one month outside the training window - add 273
# to predict for the first day outside of the evaluation window (have to lag 21) - add 294
dt_end = (len(dates) - 273 - 21) - 1
# dt_end = dt1 + 1
etf_predict_file = os.path.join(data_path,'etf_pred_random_forest_regress_20181008.csv')

# %%
print(dates[504], dates[504+251], dates[504+273])
# Out:
# 2014-01-06 2015-01-05 2015-02-05

# %%
print(dates[504+21], dates[504+251+21], dates[504+273+21])
# Out:
# 2014-02-05 2015-02-04 2015-03-09

# %%
for i in range(dt1,dt_end,21):
    print("Building model to predict for ",dates[i+273])
    x_train = etf_data.loc[((etf_data['Date']>=dates[i]) & (etf_data['Date']<dates[i+252])),include_columns] #train with 12 mos
    y_train = etf_data.loc[((etf_data['Date']>=dates[i]) & (etf_data['Date']<dates[i+252])),['rank_p_L-21']] #train with 12 mos
#     x_eval = etf_data.loc[((etf_data['Date']>=dates[i+252]) & (etf_data['Date']<dates[i+273])),include_columns] #eval with 1 mos
#     y_eval = etf_data.loc[((etf_data['Date']>=dates[i+252]) & (etf_data['Date']<dates[i+273])),['rank_p_L-21']] #eval with 1 mos
#     x_train, x_eval, y_train, y_eval = train_test_split\
#     (etf_data.loc[((etf_data['Date']>=dates[i]) & (etf_data['Date']<dates[i+252])),include_columns],\
#      etf_data.loc[((etf_data['Date']>=dates[i]) & (etf_data['Date']<dates[i+252])),['rank_p_L-21']],\
#      test_size=0.3, random_state=1234)
#     x_eval = x_train
#     y_eval = y_train
#predict one day
    x_test = etf_data.loc[(etf_data['Date']==dates[i+273]),include_columns] #predict one day-must be 21 days removed from training
    y_test = etf_data.loc[(etf_data['Date']==dates[i+273]),['rank_p_L-21']] #predict if etf >= market
    returns = etf_data.loc[(etf_data['Date']==dates[i+273]),['delta_p_L-21']]
    mkt_return = etf_data.loc[(etf_data['Date']==dates[i+273]),['ivv_delta_p_L-21']]
    x_train_nmpy = x_train.as_matrix()
    y_train_nmpy = np.ravel(y_train.as_matrix())
#     x_eval_nmpy = x_eval.as_matrix()
#     y_eval_nmpy = y_eval.as_matrix()
    x_test_nmpy = x_test.as_matrix()
    y_test_nmpy = np.ravel(y_test.as_matrix())
    returns_nmpy = returns.as_matrix()
    mkt_return_nmpy = mkt_return.as_matrix()
    
#     param_grid = { 
#     'n_estimators': [100,300,500,700,1000],
#     'max_features': ['auto','log2',None],
#     'max_depth' : [4,5,6,7,8,None],
#     'criterion' :['gini','entropy']

#     param_grid = { 
#     'n_estimators': [500],
#     'max_features': ['auto',None],
#     'max_depth' : [4,5,6,7,8,None],
#     'criterion' :['gini']}

    
#     rfc=RandomForestClassifier(n_jobs=32,random_state=54321)
#     CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5, n_jobs=32, verbose=1)
#     CV_rfc.fit(x_train_nmpy, y_train_nmpy)
    
#     print(CV_rfc.best_params_)
    #{'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'n_estimators': 700}
    
#     rf = RandomForestClassifier(**CV_rfc.best_params_,n_jobs=32,random_state=54321,verbose=1)

    rf = RandomForestRegressor(n_estimators=500, n_jobs=32, max_depth=8, criterion='mse',max_features='auto',random_state=54321)
    rf.fit(x_train_nmpy, y_train_nmpy)
    
    y_pred_model = rf.predict(x_test_nmpy)

    y_check = np.column_stack((y_test_nmpy, y_pred_model,mkt_return_nmpy,returns_nmpy))
    y_check_df = pd.DataFrame(y_check,columns=['true_value','pred_value','mkt_return','returns'])
    y_check_df.sort_values('pred_value',inplace=True,ascending=False)

    feat_import = pd.DataFrame({'Feature':include_columns,'Importance': rf.feature_importances_})
    feat_import.sort_values(by='Importance',inplace=True,ascending=False) 
    feat_import.reset_index(drop=True,inplace=True)
    train_error = mean_squared_error(y_train_nmpy,rf.predict(x_train_nmpy))
    eval_error = mean_squared_error(y_test_nmpy,y_pred_model)

    print('Model Eval Results:')
    print('*****************************')

    print(f'training error: {train_error:.3}')
    print(f'evaluation error: {eval_error:.3}')
    print('Model Variable Importance Top 10:')
    print(feat_import.iloc[0:10,])
    print('*****************************')
    print("Model Top Five Picks")
    print(" Avg rtn top 5:", round(y_check_df['returns'][0:5].mean(),4))
    print(y_check_df.head(5))
    print("Model Bottom Five Picks")
    print(" Avg rtn bottom 5:", round(y_check_df['returns'][-5:].mean(),4))
    print(y_check_df.tail(5))
    print('********************************************************')
    if i == dt1:
        predict_data = etf_data.loc[(etf_data['Date']==dates[i+273]),['Date','sym','rank_p_L-21']]
        predict_data['predict'] = y_pred_model
        predict_data.to_csv(etf_predict_file)
    else:
        predict_data = etf_data.loc[(etf_data['Date']==dates[i+273]),['Date','sym','rank_p_L-21']]
        predict_data['predict'] = y_pred_model
        predict_data.to_csv(etf_predict_file,header=False,mode='a')
# Out:
# Building model to predict for  2015-02-05
# Model Eval Results:
# *****************************
# training error: 0.039
# evaluation error: 0.0905
# Model Variable Importance Top 10:
#                   Feature  Importance
# 0  ivv_w42_rank_v_L21_avg    0.032759
# 1  ivv_w42_rank_p_L21_avg    0.031055
# 2      w42_rank_v_L21_avg    0.025841
# 3      w42_rank_p_L21_avg    0.025527
# 4    w252_rank_v_L252_avg    0.021734
# 5    w252_rank_p_L252_avg    0.020819
# 6      w21_rank_p_L42_avg    0.012042
# 7      w21_rank_v_L42_avg    0.011510
# 8      w84_rank_p_L21_avg    0.009998
# 9      w10_rank_v_L84_avg    0.009857
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: -0.0455
#     true_value  pred_value  mkt_return   returns
# 32    0.993464    0.790951    0.010741  0.091887
# 97    0.026144    0.739632    0.010741 -0.089870
# 54    0.013072    0.734960    0.010741 -0.133239
# 44    0.104575    0.733633    0.010741 -0.047549
# 81    0.098039    0.729124    0.010741 -0.048962
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0295
#      true_value  pred_value  mkt_return   returns
# 146    0.078431    0.350062    0.010741 -0.063284
# 88     0.980392    0.340563    0.010741  0.069374
# 150    0.437908    0.313487    0.010741 -0.005800
# 133    0.065359    0.238359    0.010741 -0.072484
# 71     0.058824    0.217998    0.010741 -0.075522
# ********************************************************
# Building model to predict for  2015-03-09
# Model Eval Results:
# *****************************
# training error: 0.034
# evaluation error: 0.0803
# Model Variable Importance Top 10:
#                   Feature  Importance
# 0    w252_rank_p_L252_avg    0.023838
# 1    w252_rank_v_L252_avg    0.022165
# 2      w10_rank_p_L21_avg    0.014972
# 3      w10_rank_v_L21_avg    0.014955
# 4      w42_rank_p_L42_avg    0.014254
# 5      w42_rank_v_L42_avg    0.014098
# 6      w42_rank_v_L21_avg    0.012503
# 7  ivv_w42_rank_v_L21_avg    0.010917
# 8      w42_rank_p_L21_avg    0.010916
# 9  ivv_w42_rank_p_L21_avg    0.010674
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0616
#     true_value  pred_value  mkt_return   returns
# 62    0.019608    0.738217     0.00266 -0.024067
# 11    0.980392    0.732398     0.00266  0.130311
# 17    0.934641    0.722890     0.00266  0.084779
# 18    0.895425    0.717599     0.00266  0.074383
# 53    0.738562    0.714975     0.00266  0.042591
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0278
#      true_value  pred_value  mkt_return   returns
# 37     0.241830    0.373054     0.00266  0.009546
# 32     0.973856    0.371303     0.00266  0.120546
# 84     0.026144    0.362019     0.00266 -0.018820
# 41     0.823529    0.339508     0.00266  0.052975
# 139    0.013072    0.322374     0.00266 -0.025271
# ********************************************************
# Building model to predict for  2015-04-08
# Model Eval Results:
# *****************************
# training error: 0.0371
# evaluation error: 0.0767
# Model Variable Importance Top 10:
#                 Feature  Importance
# 0    w42_rank_p_L42_avg    0.032830
# 1    w42_rank_v_L42_avg    0.030036
# 2  w252_rank_v_L252_avg    0.025197
# 3  w252_rank_p_L252_avg    0.024339
# 4    w10_rank_v_L21_avg    0.016210
# 5    w10_rank_p_L21_avg    0.016135
# 6    w21_rank_v_L84_avg    0.011476
# 7   w252_rank_v_L84_avg    0.011212
# 8   w252_rank_p_L84_avg    0.011185
# 9    w21_rank_p_L84_avg    0.010458
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0028
#      true_value  pred_value  mkt_return   returns
# 81     0.875817    0.662619    0.004202  0.022437
# 35     0.084967    0.659586    0.004202 -0.036927
# 139    0.503268    0.641836    0.004202 -0.001698
# 50     0.941176    0.633365    0.004202  0.034722
# 37     0.424837    0.626777    0.004202 -0.004433
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0192
#      true_value  pred_value  mkt_return   returns
# 69     0.254902    0.421345    0.004202 -0.017182
# 148    0.143791    0.414848    0.004202 -0.028416
# 134    0.241830    0.412593    0.004202 -0.018089
# 140    0.601307    0.392590    0.004202  0.000301
# 89     0.111111    0.356724    0.004202 -0.032771
# ********************************************************
# Building model to predict for  2015-05-07
# Model Eval Results:
# *****************************
# training error: 0.0351
# evaluation error: 0.0904
# Model Variable Importance Top 10:
#                 Feature  Importance
# 0    w42_rank_p_L21_avg    0.030664
# 1    w42_rank_v_L21_avg    0.030570
# 2  w252_rank_p_L252_avg    0.027814
# 3  w252_rank_v_L252_avg    0.027492
# 4    w42_rank_v_L42_avg    0.017609
# 5    w42_rank_p_L42_avg    0.016915
# 6    w10_rank_p_L21_avg    0.014397
# 7    w10_rank_v_L21_avg    0.013501
# 8  w252_rank_p_L189_avg    0.011170
# 9  w252_rank_v_L189_avg    0.010161
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: -0.0043
#      true_value  pred_value  mkt_return   returns
# 52     0.261438    0.700723   -0.001902 -0.026155
# 66     0.967320    0.661432   -0.001902  0.038891
# 47     0.281046    0.642928   -0.001902 -0.023092
# 102    0.392157    0.642833   -0.001902 -0.012224
# 67     0.745098    0.635417   -0.001902  0.001003
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0199
#      true_value  pred_value  mkt_return   returns
# 150    0.431373    0.389518   -0.001902 -0.010214
# 110    0.699346    0.379405   -0.001902 -0.000261
# 28     0.078431    0.378408   -0.001902 -0.062866
# 121    0.816993    0.378287   -0.001902  0.007027
# 133    0.176471    0.375509   -0.001902 -0.033232
# ********************************************************
# Building model to predict for  2015-06-08
# Model Eval Results:
# *****************************
# training error: 0.0365
# evaluation error: 0.112
# Model Variable Importance Top 10:
#                 Feature  Importance
# 0    w42_rank_p_L42_avg    0.055174
# 1    w42_rank_v_L42_avg    0.047740
# 2    w10_rank_v_L21_avg    0.024640
# 3    w10_rank_p_L21_avg    0.023854
# 4  w252_rank_p_L252_avg    0.019763
# 5  w252_rank_v_L252_avg    0.019315
# 6    w21_rank_v_L42_avg    0.012220
# 7    w21_rank_p_L42_avg    0.011870
# 8    w10_rank_p_L84_avg    0.011854
# 9    w10_rank_v_L84_avg    0.011846
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: -0.1296
#      true_value  pred_value  mkt_return   returns
# 29     0.084967    0.683061    -0.01377 -0.086011
# 60     0.013072    0.676467    -0.01377 -0.207625
# 126    0.019608    0.647540    -0.01377 -0.203870
# 0      0.065359    0.634027    -0.01377 -0.096049
# 3      0.196078    0.628667    -0.01377 -0.054592
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0149
#      true_value  pred_value  mkt_return   returns
# 139    0.098039    0.342946    -0.01377 -0.079822
# 121    0.470588    0.334024    -0.01377 -0.021433
# 103    0.555556    0.328592    -0.01377 -0.015785
# 104    1.000000    0.318165    -0.01377  0.042595
# 90     0.790850    0.318111    -0.01377 -0.000083
# ********************************************************
# Building model to predict for  2015-07-08
# Model Eval Results:
# *****************************
# training error: 0.0368
# evaluation error: 0.0827
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0        w42_rank_p_L42_avg    0.057371
# 1        w42_rank_v_L42_avg    0.056681
# 2        w21_rank_p_L21_avg    0.020962
# 3        w21_rank_v_L21_avg    0.020922
# 4      w252_rank_v_L252_avg    0.013104
# 5      w252_rank_p_L252_avg    0.012687
# 6  ivv_w189_rank_p_L126_avg    0.012499
# 7  ivv_w189_rank_v_L126_avg    0.012158
# 8        w10_rank_v_L84_avg    0.009027
# 9        w10_rank_p_L84_avg    0.009017
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0154
#      true_value  pred_value  mkt_return   returns
# 84     0.751634    0.603327    0.018605  0.031509
# 123    0.130719    0.592524    0.018605 -0.028146
# 129    0.627451    0.590166    0.018605  0.021705
# 110    0.725490    0.582432    0.018605  0.029565
# 113    0.653595    0.576684    0.018605  0.022566
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0187
#      true_value  pred_value  mkt_return   returns
# 78     0.071895    0.370684    0.018605 -0.051396
# 62     0.019608    0.346332    0.018605 -0.101574
# 60     0.732026    0.330943    0.018605  0.029782
# 126    0.803922    0.319312    0.018605  0.041403
# 144    0.196078    0.311871    0.018605 -0.011585
# ********************************************************
# Building model to predict for  2015-08-06
# Model Eval Results:
# *****************************
# training error: 0.0356
# evaluation error: 0.088
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0  ivv_w189_rank_v_L126_avg    0.031798
# 1  ivv_w189_rank_p_L126_avg    0.031224
# 2      w252_rank_v_L252_avg    0.028235
# 3      w252_rank_p_L252_avg    0.026110
# 4        w21_rank_p_L42_avg    0.025407
# 5        w21_rank_v_L42_avg    0.025014
# 6        w21_rank_p_L21_avg    0.023646
# 7        w21_rank_v_L21_avg    0.023580
# 8        w10_rank_v_L21_avg    0.014938
# 9        w10_rank_p_L21_avg    0.014195
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: -0.0753
#      true_value  pred_value  mkt_return   returns
# 90     0.346405    0.672112   -0.076446 -0.083280
# 87     0.359477    0.659506   -0.076446 -0.081408
# 135    0.431373    0.650628   -0.076446 -0.078000
# 106    0.581699    0.648015   -0.076446 -0.069621
# 121    0.660131    0.644903   -0.076446 -0.064390
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.1102
#     true_value  pred_value  mkt_return   returns
# 31    0.091503    0.288953   -0.076446 -0.138261
# 78    0.699346    0.272641   -0.076446 -0.060486
# 15    0.006536    0.270784   -0.076446 -0.170840
# 32    0.673203    0.264160   -0.076446 -0.063880
# 97    0.137255    0.254979   -0.076446 -0.117469
# ********************************************************
# Building model to predict for  2015-09-04
# Model Eval Results:
# *****************************
# training error: 0.0347
# evaluation error: 0.101
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0        w21_rank_p_L42_avg    0.044641
# 1        w21_rank_v_L42_avg    0.042979
# 2      w189_rank_p_L252_avg    0.020303
# 3      w189_rank_v_L252_avg    0.019768
# 4  ivv_w189_rank_v_L126_avg    0.018011
# 5  ivv_w189_rank_p_L126_avg    0.017669
# 6        w21_rank_v_L21_avg    0.017269
# 7        w21_rank_p_L21_avg    0.016388
# 8      w252_rank_p_L252_avg    0.014470
# 9      w252_rank_v_L252_avg    0.014378
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: -0.0015
#      true_value  pred_value  mkt_return   returns
# 132    0.379085    0.684158    0.032631  0.017924
# 118    0.457516    0.661430    0.032631  0.024867
# 88     0.013072    0.661229    0.032631 -0.081203
# 106    0.372549    0.661070    0.032631  0.017549
# 130    0.326797    0.656841    0.032631  0.013312
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.018
#      true_value  pred_value  mkt_return   returns
# 66     0.071895    0.267898    0.032631 -0.014258
# 36     0.575163    0.247670    0.032631  0.032092
# 97     0.607843    0.247413    0.032631  0.033491
# 101    0.026144    0.237375    0.032631 -0.041594
# 75     0.921569    0.217727    0.032631  0.080246
# ********************************************************
# Building model to predict for  2015-10-06
# Model Eval Results:
# *****************************
# training error: 0.0374
# evaluation error: 0.085
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0        w21_rank_v_L42_avg    0.044634
# 1        w21_rank_p_L42_avg    0.044591
# 2      w189_rank_p_L252_avg    0.024103
# 3      w189_rank_v_L252_avg    0.023640
# 4        w21_rank_v_L21_avg    0.023293
# 5        w21_rank_p_L21_avg    0.022779
# 6  ivv_w252_rank_p_L126_avg    0.013887
# 7  ivv_w252_rank_v_L126_avg    0.013846
# 8        w63_rank_v_L42_avg    0.009882
# 9        w63_rank_p_L42_avg    0.009715
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0133
#      true_value  pred_value  mkt_return   returns
# 132    0.058824    0.716620    0.063911 -0.024366
# 118    0.444444    0.713137    0.063911  0.023881
# 98     0.098039    0.618031    0.063911 -0.009954
# 103    0.869281    0.617022    0.063911  0.064830
# 134    0.352941    0.614307    0.063911  0.012152
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.004
#      true_value  pred_value  mkt_return   returns
# 31     0.078431    0.346862    0.063911 -0.015030
# 62     0.013072    0.341233    0.063911 -0.046656
# 97     0.372549    0.337963    0.063911  0.013295
# 99     0.032680    0.322806    0.063911 -0.028930
# 117    0.797386    0.292762    0.063911  0.057326
# ********************************************************
# Building model to predict for  2015-11-04
# Model Eval Results:
# *****************************
# training error: 0.0377
# evaluation error: 0.116
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0     w189_rank_v_L252_avg    0.033143
# 1     w189_rank_p_L252_avg    0.030505
# 2  ivv_w252_rank_v_L21_avg    0.019661
# 3  ivv_w252_rank_p_L21_avg    0.018502
# 4       w21_rank_p_L42_avg    0.017273
# 5       w21_rank_v_L42_avg    0.015525
# 6       w42_rank_p_L42_avg    0.015255
# 7  ivv_w63_rank_v_L252_avg    0.014477
# 8       w42_rank_v_L42_avg    0.014215
# 9  ivv_w63_rank_p_L252_avg    0.012662
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: -0.0605
#     true_value  pred_value  mkt_return   returns
# 31    0.071895    0.783196   -0.003687 -0.058949
# 75    0.032680    0.762558   -0.003687 -0.088637
# 54    0.202614    0.761232   -0.003687 -0.026534
# 97    0.124183    0.754002   -0.003687 -0.051660
# 55    0.058824    0.714150   -0.003687 -0.076829
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0009
#      true_value  pred_value  mkt_return   returns
# 151    0.333333    0.318422   -0.003687 -0.012527
# 110    0.620915    0.317821   -0.003687 -0.002597
# 87     0.830065    0.312666   -0.003687  0.005758
# 129    0.601307    0.311480   -0.003687 -0.003295
# 83     0.875817    0.275693   -0.003687  0.008278
# ********************************************************
# Building model to predict for  2015-12-04
# Model Eval Results:
# *****************************
# training error: 0.0405
# evaluation error: 0.123
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0     w189_rank_v_L252_avg    0.034322
# 1     w189_rank_p_L252_avg    0.033285
# 2       w42_rank_v_L42_avg    0.023454
# 3       w42_rank_p_L42_avg    0.022719
# 4  ivv_w10_rank_v_L252_avg    0.022055
# 5  ivv_w10_rank_p_L252_avg    0.021362
# 6       w21_rank_v_L84_avg    0.014899
# 7       w10_rank_p_L84_avg    0.012905
# 8       w10_rank_v_L84_avg    0.012716
# 9       w21_rank_p_L84_avg    0.012140
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: -0.0453
#      true_value  pred_value  mkt_return   returns
# 79     0.627451    0.673973   -0.046016 -0.036216
# 152    0.653595    0.618780   -0.046016 -0.033397
# 45     0.346405    0.616126   -0.046016 -0.060635
# 119    0.529412    0.614078   -0.046016 -0.046505
# 116    0.457516    0.613927   -0.046016 -0.049784
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0054
#      true_value  pred_value  mkt_return   returns
# 145    0.954248    0.221133   -0.046016  0.012286
# 4      0.901961    0.220059   -0.046016  0.003819
# 5      0.895425    0.218770   -0.046016  0.003378
# 63     0.882353    0.215941   -0.046016  0.002426
# 125    0.908497    0.212446   -0.046016  0.004888
# ********************************************************
# Building model to predict for  2016-01-06
# Model Eval Results:
# *****************************
# training error: 0.0402
# evaluation error: 0.14
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0        w21_rank_p_L21_avg    0.039607
# 1        w21_rank_v_L21_avg    0.038983
# 2      w189_rank_p_L252_avg    0.033512
# 3      w189_rank_v_L252_avg    0.032910
# 4   ivv_w126_rank_v_L63_avg    0.026392
# 5   ivv_w126_rank_p_L63_avg    0.024778
# 6  ivv_w189_rank_v_L126_avg    0.017645
# 7  ivv_w189_rank_p_L126_avg    0.017095
# 8  ivv_w252_rank_p_L252_avg    0.016558
# 9  ivv_w252_rank_v_L252_avg    0.015673
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: -0.0911
#      true_value  pred_value  mkt_return   returns
# 67     0.326797    0.714936   -0.054663 -0.059386
# 110    0.202614    0.677953   -0.054663 -0.067246
# 117    0.071895    0.669682   -0.054663 -0.112000
# 68     0.124183    0.665927   -0.054663 -0.095862
# 66     0.045752    0.663971   -0.054663 -0.121197
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0108
#      true_value  pred_value  mkt_return   returns
# 75     0.091503    0.321128   -0.054663 -0.106242
# 148    0.986928    0.312420   -0.054663  0.070366
# 23     0.980392    0.293924   -0.054663  0.067271
# 54     0.810458    0.226600   -0.054663  0.007028
# 55     0.882353    0.224238   -0.054663  0.015385
# ********************************************************
# Building model to predict for  2016-02-05
# Model Eval Results:
# *****************************
# training error: 0.043
# evaluation error: 0.0932
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0      w252_rank_p_L252_avg    0.035602
# 1      w252_rank_v_L252_avg    0.030602
# 2        w21_rank_p_L21_avg    0.022431
# 3        w21_rank_v_L21_avg    0.021779
# 4      w189_rank_v_L252_avg    0.020566
# 5      w189_rank_p_L252_avg    0.018233
# 6  ivv_w252_rank_p_L252_avg    0.012715
# 7  ivv_w252_rank_v_L252_avg    0.011848
# 8       w63_rank_v_L126_avg    0.011728
# 9        w10_rank_p_L42_avg    0.011427
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0678
#      true_value  pred_value  mkt_return   returns
# 110    0.581699    0.623244    0.055758  0.055450
# 83     0.803922    0.615856    0.055758  0.077209
# 87     0.921569    0.614514    0.055758  0.096087
# 150    0.509804    0.603525    0.055758  0.049184
# 106    0.692810    0.592967    0.055758  0.060871
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0959
#     true_value  pred_value  mkt_return   returns
# 75    0.869281    0.338862    0.055758  0.087978
# 31    0.986928    0.323183    0.055758  0.179185
# 78    0.941176    0.316568    0.055758  0.101131
# 62    0.679739    0.311023    0.055758  0.060816
# 29    0.529412    0.288848    0.055758  0.050488
# ********************************************************
# Building model to predict for  2016-03-08
# Model Eval Results:
# *****************************
# training error: 0.0407
# evaluation error: 0.0983
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0        w21_rank_p_L21_avg    0.022474
# 1      w252_rank_v_L252_avg    0.022195
# 2        w21_rank_v_L21_avg    0.020794
# 3      w252_rank_p_L252_avg    0.020411
# 4  ivv_w126_rank_p_L189_avg    0.017313
# 5        w84_rank_v_L84_avg    0.016599
# 6  ivv_w126_rank_v_L189_avg    0.016124
# 7        w84_rank_p_L84_avg    0.015963
# 8  ivv_w189_rank_v_L126_avg    0.015366
# 9       w126_rank_p_L42_avg    0.014164
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: -0.0094
#     true_value  pred_value  mkt_return   returns
# 62    0.065359    0.838011    0.033627 -0.019594
# 78    0.026144    0.834305    0.033627 -0.027024
# 47    0.052288    0.699995    0.033627 -0.023476
# 31    0.254902    0.691855    0.033627  0.010408
# 72    0.287582    0.671429    0.033627  0.012514
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0264
#      true_value  pred_value  mkt_return   returns
# 92     0.581699    0.396395    0.033627  0.026582
# 42     0.849673    0.389960    0.033627  0.042413
# 138    0.098039    0.375999    0.033627 -0.009576
# 24     0.875817    0.327591    0.033627  0.048234
# 146    0.549020    0.303308    0.033627  0.024198
# ********************************************************
# Building model to predict for  2016-04-07
# Model Eval Results:
# *****************************
# training error: 0.0402
# evaluation error: 0.0795
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0       w21_rank_p_L42_avg    0.033360
# 1  ivv_w189_rank_p_L42_avg    0.029205
# 2       w21_rank_v_L42_avg    0.028150
# 3  ivv_w189_rank_v_L42_avg    0.028146
# 4  ivv_w21_rank_v_L252_avg    0.024430
# 5  ivv_w21_rank_p_L252_avg    0.022203
# 6       w84_rank_p_L21_avg    0.013889
# 7       w84_rank_v_L21_avg    0.013697
# 8  ivv_w126_rank_p_L84_avg    0.012115
# 9  ivv_w126_rank_v_L84_avg    0.011975
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0664
#      true_value  pred_value  mkt_return   returns
# 11     0.692810    0.650286    0.008977  0.025533
# 55     0.986928    0.599275    0.008977  0.125000
# 78     0.973856    0.595074    0.008977  0.099176
# 117    0.921569    0.589861    0.008977  0.061634
# 114    0.614379    0.582631    0.008977  0.020519
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0054
#      true_value  pred_value  mkt_return   returns
# 27     0.810458    0.354465    0.008977  0.037230
# 29     0.032680    0.353802    0.008977 -0.045311
# 28     0.071895    0.325057    0.008977 -0.031795
# 14     0.928105    0.318900    0.008977  0.061669
# 148    0.026144    0.297948    0.008977 -0.048619
# ********************************************************
# Building model to predict for  2016-05-06
# Model Eval Results:
# *****************************
# training error: 0.0384
# evaluation error: 0.0827
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0       w21_rank_p_L42_avg    0.034049
# 1       w21_rank_v_L42_avg    0.032718
# 2  ivv_w10_rank_v_L252_avg    0.016812
# 3  ivv_w10_rank_p_L252_avg    0.014191
# 4       w84_rank_p_L84_avg    0.014185
# 5       w84_rank_v_L84_avg    0.013167
# 6  ivv_w189_rank_p_L42_avg    0.012293
# 7       w63_rank_p_L84_avg    0.011490
# 8       w63_rank_v_L84_avg    0.010767
# 9  ivv_w189_rank_v_L42_avg    0.010715
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0474
#      true_value  pred_value  mkt_return   returns
# 92     0.810458    0.652694    0.028819  0.051350
# 101    0.196078    0.651016    0.028819  0.005061
# 24     0.790850    0.589944    0.028819  0.049097
# 36     0.875817    0.573216    0.028819  0.060794
# 81     0.908497    0.567700    0.028819  0.070886
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.018
#      true_value  pred_value  mkt_return   returns
# 62     0.947712    0.382100    0.028819  0.081246
# 146    0.300654    0.370068    0.028819  0.018264
# 54     0.052288    0.357434    0.028819 -0.011803
# 69     0.019608    0.352714    0.028819 -0.036174
# 31     0.666667    0.257504    0.028819  0.038618
# ********************************************************
# Building model to predict for  2016-06-07
# Model Eval Results:
# *****************************
# training error: 0.0354
# evaluation error: 0.0676
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w10_rank_v_L252_avg    0.060894
# 1  ivv_w10_rank_p_L252_avg    0.056391
# 2       w21_rank_v_L42_avg    0.031505
# 3       w21_rank_p_L42_avg    0.031170
# 4      w252_rank_v_L05_avg    0.019073
# 5      w252_rank_p_L05_avg    0.018601
# 6     w252_rank_p_L252_avg    0.013417
# 7   ivv_w42_rank_v_L21_avg    0.013044
# 8     w252_rank_v_L252_avg    0.012143
# 9   ivv_w42_rank_p_L21_avg    0.011823
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0533
#      true_value  pred_value  mkt_return   returns
# 150    0.934641    0.645513   -0.005191  0.037809
# 71     0.954248    0.644586   -0.005191  0.058194
# 133    0.973856    0.639661   -0.005191  0.062289
# 146    0.980392    0.635549   -0.005191  0.077340
# 2      0.901961    0.629757   -0.005191  0.030851
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0408
#     true_value  pred_value  mkt_return   returns
# 62    0.137255    0.262512   -0.005191 -0.078272
# 78    0.143791    0.262425   -0.005191 -0.077806
# 75    0.156863    0.260563   -0.005191 -0.075920
# 88    0.594771    0.233692   -0.005191 -0.006118
# 27    0.921569    0.199168   -0.005191  0.034001
# ********************************************************
# Building model to predict for  2016-07-07
# Model Eval Results:
# *****************************
# training error: 0.0369
# evaluation error: 0.0929
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w10_rank_v_L252_avg    0.032270
# 1  ivv_w10_rank_p_L252_avg    0.024259
# 2       w21_rank_p_L42_avg    0.017652
# 3       w42_rank_v_L42_avg    0.017601
# 4   ivv_w5_rank_p_L252_avg    0.017286
# 5       w42_rank_p_L42_avg    0.016743
# 6   ivv_w5_rank_v_L252_avg    0.016667
# 7       w21_rank_v_L42_avg    0.014880
# 8      w252_rank_v_L05_avg    0.013759
# 9     w252_rank_v_L252_avg    0.013433
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0801
#      true_value  pred_value  mkt_return   returns
# 28     0.339869    0.651881    0.041489  0.032778
# 81     0.307190    0.642476    0.041489  0.021686
# 97     0.960784    0.615095    0.041489  0.119874
# 55     0.993464    0.609814    0.041489  0.225937
# 102    0.176471    0.603501    0.041489  0.000000
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0703
#      true_value  pred_value  mkt_return   returns
# 117    0.901961    0.378195    0.041489  0.098691
# 41     0.607843    0.369849    0.041489  0.053090
# 70     0.934641    0.367447    0.041489  0.109954
# 43     0.346405    0.361607    0.041489  0.034067
# 88     0.627451    0.334947    0.041489  0.055845
# ********************************************************
# Building model to predict for  2016-08-05
# Model Eval Results:
# *****************************
# training error: 0.0406
# evaluation error: 0.091
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w10_rank_v_L189_avg    0.036611
# 1  ivv_w10_rank_p_L189_avg    0.036500
# 2       w21_rank_v_L42_avg    0.032270
# 3       w21_rank_p_L42_avg    0.031244
# 4       w63_rank_p_L84_avg    0.018120
# 5       w84_rank_p_L63_avg    0.016503
# 6       w63_rank_v_L84_avg    0.015492
# 7       w84_rank_v_L63_avg    0.015374
# 8       w84_rank_v_L84_avg    0.014962
# 9       w84_rank_p_L84_avg    0.013798
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0014
#      true_value  pred_value  mkt_return   returns
# 140    0.124183    0.576887    0.004421  0.000006
# 125    0.222222    0.572651    0.004421  0.003602
# 86     0.150327    0.570291    0.004421  0.000728
# 5      0.196078    0.569595    0.004421  0.002742
# 137    0.130719    0.567254    0.004421  0.000119
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0538
#      true_value  pred_value  mkt_return   returns
# 64     0.346405    0.423891    0.004421  0.007040
# 126    1.000000    0.416344    0.004421  0.097877
# 11     0.960784    0.408154    0.004421  0.071319
# 50     0.562092    0.376762    0.004421  0.016861
# 60     0.973856    0.290628    0.004421  0.075682
# ********************************************************
# Building model to predict for  2016-09-06
# Model Eval Results:
# *****************************
# training error: 0.0376
# evaluation error: 0.0793
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0       w21_rank_p_L42_avg    0.048885
# 1       w21_rank_v_L42_avg    0.046466
# 2       w42_rank_v_L84_avg    0.022546
# 3       w42_rank_p_L84_avg    0.021849
# 4   ivv_w5_rank_v_L189_avg    0.016970
# 5   ivv_w5_rank_p_L189_avg    0.016580
# 6       w84_rank_v_L63_avg    0.012651
# 7  ivv_w10_rank_p_L252_avg    0.012462
# 8       w84_rank_p_L63_avg    0.012265
# 9  ivv_w10_rank_v_L252_avg    0.011881
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0222
#      true_value  pred_value  mkt_return   returns
# 89     0.725490    0.704092   -0.010794 -0.001543
# 78     1.000000    0.672488   -0.010794  0.060375
# 62     0.993464    0.660054   -0.010794  0.059566
# 102    0.418301    0.643740   -0.010794 -0.009978
# 140    0.830065    0.635186   -0.010794  0.002784
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0418
#      true_value  pred_value  mkt_return   returns
# 52     0.111111    0.421166   -0.010794 -0.039992
# 138    0.006536    0.420468   -0.010794 -0.115486
# 77     0.261438    0.402362   -0.010794 -0.017177
# 69     0.052288    0.400049   -0.010794 -0.060723
# 118    0.960784    0.362755   -0.010794  0.024350
# ********************************************************
# Building model to predict for  2016-10-05
# Model Eval Results:
# *****************************
# training error: 0.0381
# evaluation error: 0.0933
# Model Variable Importance Top 10:
#                   Feature  Importance
# 0      w21_rank_p_L42_avg    0.066246
# 1      w21_rank_v_L42_avg    0.060472
# 2     w126_rank_p_L05_avg    0.022327
# 3     w126_rank_v_L05_avg    0.021042
# 4  ivv_w63_rank_v_L63_avg    0.018590
# 5  ivv_w63_rank_p_L63_avg    0.018421
# 6  ivv_w10_rank_p_L21_avg    0.013758
# 7  ivv_w10_rank_v_L21_avg    0.013704
# 8     w126_rank_p_L21_avg    0.011439
# 9  ivv_w21_rank_v_L21_avg    0.011240
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: -0.0128
#      true_value  pred_value  mkt_return   returns
# 68     0.934641    0.752074   -0.031675  0.003338
# 66     0.607843    0.746552   -0.031675 -0.024738
# 15     0.222222    0.741058   -0.031675 -0.047461
# 117    0.797386    0.740908   -0.031675 -0.004250
# 46     0.960784    0.729121   -0.031675  0.009158
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.01
#      true_value  pred_value  mkt_return   returns
# 101    0.888889    0.416583   -0.031675  0.000902
# 62     0.137255    0.414763   -0.031675 -0.058862
# 97     0.973856    0.402323   -0.031675  0.023529
# 57     0.640523    0.388056   -0.031675 -0.022890
# 31     0.954248    0.294649   -0.031675  0.007152
# ********************************************************
# Building model to predict for  2016-11-03
# Model Eval Results:
# *****************************
# training error: 0.0386
# evaluation error: 0.0754
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0       w21_rank_v_L42_avg    0.029676
# 1       w21_rank_p_L42_avg    0.029492
# 2  ivv_w63_rank_v_L189_avg    0.020856
# 3      w126_rank_v_L05_avg    0.020816
# 4  ivv_w63_rank_p_L189_avg    0.020281
# 5      w126_rank_p_L05_avg    0.020077
# 6      w126_rank_p_L21_avg    0.018014
# 7      w126_rank_v_L21_avg    0.017838
# 8  ivv_w84_rank_v_L189_avg    0.017559
# 9       w42_rank_p_L84_avg    0.016132
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0226
#     true_value  pred_value  mkt_return   returns
# 90    0.359477    0.703730    0.057947 -0.014310
# 40    0.594771    0.643182    0.057947  0.018722
# 97    0.052288    0.634625    0.057947 -0.063895
# 95    0.980392    0.626061    0.057947  0.184885
# 27    0.372549    0.621255    0.057947 -0.012349
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0468
#      true_value  pred_value  mkt_return   returns
# 85     0.098039    0.355286    0.057947 -0.055249
# 2      0.366013    0.352450    0.057947 -0.013669
# 69     0.026144    0.343816    0.057947 -0.102789
# 64     0.627451    0.309580    0.057947  0.026356
# 138    0.039216    0.283149    0.057947 -0.088404
# ********************************************************
# Building model to predict for  2016-12-05
# Model Eval Results:
# *****************************
# training error: 0.0361
# evaluation error: 0.0835
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w63_rank_v_L189_avg    0.030329
# 1  ivv_w63_rank_p_L189_avg    0.025335
# 2     w189_rank_p_L126_avg    0.022969
# 3     w189_rank_v_L126_avg    0.020262
# 4       w21_rank_p_L42_avg    0.015858
# 5       w63_rank_p_L84_avg    0.015113
# 6       w21_rank_v_L42_avg    0.014861
# 7       w84_rank_v_L63_avg    0.014832
# 8      w21_rank_p_L252_avg    0.013799
# 9       w84_rank_p_L63_avg    0.013467
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0376
#      true_value  pred_value  mkt_return   returns
# 70     0.392157    0.666578    0.030848  0.023041
# 132    0.601307    0.665902    0.030848  0.032253
# 83     0.679739    0.664085    0.030848  0.035409
# 17     0.620915    0.659985    0.030848  0.033145
# 38     0.928105    0.658828    0.030848  0.063904
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0448
#      true_value  pred_value  mkt_return   returns
# 44     0.235294    0.395389    0.030848  0.014915
# 79     0.888889    0.377386    0.030848  0.053258
# 62     0.313725    0.358431    0.030848  0.018229
# 71     0.954248    0.319729    0.030848  0.071988
# 151    0.934641    0.304359    0.030848  0.065497
# ********************************************************
# Building model to predict for  2017-01-05
# Model Eval Results:
# *****************************
# training error: 0.0366
# evaluation error: 0.0838
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0     w189_rank_p_L126_avg    0.030677
# 1     w189_rank_v_L126_avg    0.029189
# 2  ivv_w63_rank_p_L189_avg    0.028966
# 3  ivv_w63_rank_v_L189_avg    0.027789
# 4       w84_rank_p_L63_avg    0.018323
# 5       w84_rank_v_L63_avg    0.018181
# 6      w21_rank_p_L252_avg    0.017539
# 7      w21_rank_v_L252_avg    0.016184
# 8       w42_rank_p_L42_avg    0.015968
# 9       w42_rank_v_L42_avg    0.014755
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0123
#      true_value  pred_value  mkt_return   returns
# 15     0.823529    0.683038    0.011592  0.035272
# 47     0.156863    0.622832    0.011592 -0.001833
# 70     0.712418    0.620578    0.011592  0.019561
# 100    0.398693    0.619398    0.011592  0.005642
# 147    0.339869    0.616951    0.011592  0.002688
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0053
#      true_value  pred_value  mkt_return   returns
# 73     0.189542    0.318883    0.011592 -0.000951
# 49     0.901961    0.312394    0.011592  0.049424
# 74     0.307190    0.304069    0.011592  0.002045
# 127    0.235294    0.303331    0.011592  0.000798
# 133    0.039216    0.298868    0.011592 -0.024627
# ********************************************************
# Building model to predict for  2017-02-06
# Model Eval Results:
# *****************************
# training error: 0.0366
# evaluation error: 0.0949
# Model Variable Importance Top 10:
#                  Feature  Importance
# 0   w252_rank_p_L126_avg    0.023956
# 1   w252_rank_v_L126_avg    0.023326
# 2    w126_rank_v_L05_avg    0.017281
# 3    w126_rank_p_L05_avg    0.017237
# 4  ivv_w5_rank_v_L42_avg    0.016182
# 5  ivv_w5_rank_p_L42_avg    0.014439
# 6   w189_rank_v_L189_avg    0.012742
# 7     w21_rank_p_L42_avg    0.012641
# 8     w42_rank_v_L42_avg    0.012610
# 9   w189_rank_p_L189_avg    0.012445
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0118
#     true_value  pred_value  mkt_return   returns
# 72    0.849673    0.714583    0.033467  0.031213
# 47    0.810458    0.693497    0.033467  0.029747
# 51    0.392157    0.682616    0.033467  0.002550
# 79    0.346405    0.673631    0.033467 -0.000303
# 61    0.228758    0.653927    0.033467 -0.004268
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0237
#     true_value  pred_value  mkt_return   returns
# 32    0.006536    0.380744    0.033467 -0.109298
# 54    0.196078    0.373739    0.033467 -0.005941
# 55    0.764706    0.371465    0.033467  0.027904
# 78    0.013072    0.349385    0.033467 -0.078063
# 90    0.973856    0.347055    0.033467  0.046861
# ********************************************************
# Building model to predict for  2017-03-08
# Model Eval Results:
# *****************************
# training error: 0.0383
# evaluation error: 0.0909
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0      w126_rank_v_L05_avg    0.020210
# 1      w126_rank_p_L05_avg    0.019087
# 2        w5_rank_v_L63_avg    0.017928
# 3        w5_rank_p_L63_avg    0.016617
# 4               rank_p_L63    0.013539
# 5     w252_rank_p_L189_avg    0.013481
# 6     w252_rank_v_L189_avg    0.012869
# 7  ivv_w84_rank_p_L189_avg    0.012826
# 8  ivv_w63_rank_p_L189_avg    0.012785
# 9     w126_rank_v_L126_avg    0.012717
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0317
#     true_value  pred_value  mkt_return   returns
# 44    0.516340    0.749772   -0.000638  0.016032
# 79    0.928105    0.717579   -0.000638  0.050437
# 92    0.222222    0.690521   -0.000638  0.000649
# 32    0.986928    0.688787   -0.000638  0.081152
# 62    0.379085    0.678636   -0.000638  0.010128
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0192
#     true_value  pred_value  mkt_return   returns
# 42    0.869281    0.335604   -0.000638  0.043382
# 54    0.150327    0.322142   -0.000638 -0.000815
# 97    0.705882    0.310089   -0.000638  0.029345
# 55    0.065359    0.300023   -0.000638 -0.012473
# 11    0.790850    0.259076   -0.000638  0.036374
# ********************************************************
# Building model to predict for  2017-04-06
# Model Eval Results:
# *****************************
# training error: 0.0396
# evaluation error: 0.0832
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0     w252_rank_v_L189_avg    0.021405
# 1      w126_rank_p_L05_avg    0.021296
# 2     w252_rank_p_L189_avg    0.021140
# 3      w126_rank_v_L05_avg    0.020467
# 4        w5_rank_p_L63_avg    0.014070
# 5        w5_rank_v_L63_avg    0.012404
# 6  ivv_w84_rank_v_L189_avg    0.012002
# 7  ivv_w84_rank_p_L189_avg    0.011311
# 8      w42_rank_p_L252_avg    0.009819
# 9      w42_rank_v_L252_avg    0.009796
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0468
#      true_value  pred_value  mkt_return   returns
# 148    1.000000    0.757885    0.018024  0.097962
# 84     0.437908    0.714366    0.018024  0.010753
# 66     0.392157    0.705145    0.018024  0.008718
# 44     0.810458    0.699653    0.018024  0.043392
# 79     0.915033    0.662984    0.018024  0.073150
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0153
#      true_value  pred_value  mkt_return   returns
# 124    0.313725    0.348777    0.018024  0.003733
# 94     0.660131    0.348521    0.018024  0.023434
# 149    0.274510    0.346865    0.018024  0.002298
# 96     0.699346    0.330278    0.018024  0.026246
# 114    0.640523    0.303903    0.018024  0.020873
# ********************************************************
# Building model to predict for  2017-05-08
# Model Eval Results:
# *****************************
# training error: 0.0406
# evaluation error: 0.0798
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0  ivv_w189_rank_v_L126_avg    0.020920
# 1      w252_rank_v_L189_avg    0.020636
# 2      w252_rank_p_L189_avg    0.019508
# 3  ivv_w189_rank_p_L126_avg    0.018186
# 4       w126_rank_p_L05_avg    0.015585
# 5       w42_rank_v_L126_avg    0.014977
# 6   ivv_w63_rank_v_L189_avg    0.014859
# 7       w126_rank_v_L05_avg    0.014354
# 8   ivv_w63_rank_p_L189_avg    0.014106
# 9      w252_rank_p_L252_avg    0.013757
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0076
#      true_value  pred_value  mkt_return   returns
# 75     0.013072    0.738688    0.016918 -0.074023
# 62     0.065359    0.683909    0.016918 -0.012830
# 104    0.660131    0.629663    0.016918  0.024542
# 99     0.869281    0.612901    0.016918  0.041844
# 87     0.960784    0.608718    0.016918  0.058320
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0072
#      true_value  pred_value  mkt_return   returns
# 63     0.248366    0.394660    0.016918  0.008071
# 5      0.274510    0.394331    0.016918  0.009493
# 141    0.189542    0.390819    0.016918  0.003709
# 74     0.261438    0.384965    0.016918  0.009211
# 55     0.019608    0.383970    0.016918 -0.066334
# ********************************************************
# Building model to predict for  2017-06-07
# Model Eval Results:
# *****************************
# training error: 0.0381
# evaluation error: 0.111
# Model Variable Importance Top 10:
#                 Feature  Importance
# 0  w252_rank_p_L252_avg    0.030083
# 1  w252_rank_v_L252_avg    0.029595
# 2  w189_rank_p_L252_avg    0.013385
# 3  w189_rank_v_L252_avg    0.012548
# 4   w189_rank_p_L05_avg    0.012269
# 5   w189_rank_v_L05_avg    0.012222
# 6   w42_rank_v_L126_avg    0.010847
# 7  w252_rank_p_L126_avg    0.009869
# 8   w42_rank_p_L126_avg    0.009735
# 9    w84_rank_v_L63_avg    0.009050
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: -0.0041
#     true_value  pred_value  mkt_return   returns
# 51    0.130719    0.707658   -0.001747 -0.021573
# 20    0.084967    0.696080   -0.001747 -0.025541
# 40    0.895425    0.684787   -0.001747  0.023072
# 25    0.830065    0.679070   -0.001747  0.013815
# 24    0.287582    0.669235   -0.001747 -0.010377
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0008
#      true_value  pred_value  mkt_return   returns
# 136    0.686275    0.324480   -0.001747  0.000735
# 140    0.470588    0.323925   -0.001747 -0.005667
# 137    0.640523    0.320573   -0.001747 -0.000746
# 59     0.712418    0.316615   -0.001747  0.001790
# 86     0.666667    0.313519   -0.001747  0.000057
# ********************************************************
# Building model to predict for  2017-07-07
# Model Eval Results:
# *****************************
# training error: 0.0395
# evaluation error: 0.0761
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0      w189_rank_p_L05_avg    0.024450
# 1      w189_rank_v_L05_avg    0.023859
# 2      w63_rank_p_L126_avg    0.018919
# 3      w63_rank_v_L126_avg    0.017144
# 4  ivv_w252_rank_v_L05_avg    0.016165
# 5     w126_rank_v_L126_avg    0.014951
# 6     w252_rank_v_L252_avg    0.014841
# 7     w126_rank_p_L126_avg    0.014650
# 8  ivv_w63_rank_v_L189_avg    0.014394
# 9  ivv_w252_rank_p_L05_avg    0.014351
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0485
#      true_value  pred_value  mkt_return   returns
# 95     0.058824    0.641757     0.02384 -0.001719
# 11     0.967320    0.594184     0.02384  0.103587
# 113    0.535948    0.591503     0.02384  0.026525
# 130    0.653595    0.589886     0.02384  0.038159
# 16     0.928105    0.586748     0.02384  0.075857
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0414
#      true_value  pred_value  mkt_return   returns
# 144    0.307190    0.333360     0.02384  0.013495
# 82     0.215686    0.327581     0.02384  0.009078
# 81     0.575163    0.324608     0.02384  0.028893
# 55     1.000000    0.324142     0.02384  0.155606
# 78     0.091503    0.317284     0.02384 -0.000307
# ********************************************************
# Building model to predict for  2017-08-07
# Model Eval Results:
# *****************************
# training error: 0.0408
# evaluation error: 0.101
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0      w189_rank_p_L05_avg    0.024894
# 1      w189_rank_v_L05_avg    0.024866
# 2     w252_rank_v_L252_avg    0.020466
# 3     w252_rank_p_L252_avg    0.019810
# 4      w84_rank_v_L189_avg    0.017362
# 5  ivv_w252_rank_v_L05_avg    0.016457
# 6  ivv_w252_rank_p_L05_avg    0.016064
# 7      w84_rank_p_L189_avg    0.014713
# 8  ivv_w126_rank_v_L05_avg    0.014395
# 9  ivv_w126_rank_p_L05_avg    0.013868
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0045
#      true_value  pred_value  mkt_return   returns
# 25     0.398693    0.705955   -0.003647 -0.001242
# 133    0.843137    0.701253   -0.003647  0.019033
# 53     0.045752    0.698513   -0.003647 -0.035303
# 139    0.738562    0.692165   -0.003647  0.008196
# 87     0.921569    0.680102   -0.003647  0.031861
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0044
#     true_value  pred_value  mkt_return   returns
# 59    0.470588    0.277069   -0.003647  0.000925
# 4     0.725490    0.276989   -0.003647  0.007843
# 82    0.614379    0.274487   -0.003647  0.005480
# 86    0.535948    0.272851   -0.003647  0.002250
# 63    0.640523    0.266766   -0.003647  0.005621
# ********************************************************
# Building model to predict for  2017-09-06
# Model Eval Results:
# *****************************
# training error: 0.0427
# evaluation error: 0.0988
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0       w189_rank_p_L05_avg    0.029456
# 1       w189_rank_v_L05_avg    0.027710
# 2       w42_rank_v_L189_avg    0.018859
# 3       w42_rank_p_L189_avg    0.018505
# 4      w252_rank_v_L252_avg    0.017129
# 5   ivv_w63_rank_p_L189_avg    0.016379
# 6      w252_rank_p_L252_avg    0.016177
# 7   ivv_w63_rank_v_L189_avg    0.015882
# 8  ivv_w189_rank_v_L189_avg    0.015697
# 9  ivv_w189_rank_p_L189_avg    0.015288
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.007
#      true_value  pred_value  mkt_return   returns
# 120    0.575163    0.648123    0.036537  0.028226
# 52     0.032680    0.634381    0.036537 -0.038804
# 134    0.490196    0.631114    0.036537  0.024043
# 30     0.137255    0.627740    0.036537 -0.008567
# 130    0.607843    0.614616    0.036537  0.030035
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0646
#      true_value  pred_value  mkt_return   returns
# 64     0.692810    0.334204    0.036537  0.036617
# 108    0.823529    0.331225    0.036537  0.048949
# 107    0.836601    0.326504    0.036537  0.050314
# 112    0.986928    0.323104    0.036537  0.107059
# 114    0.928105    0.316868    0.036537  0.080050
# ********************************************************
# Building model to predict for  2017-10-05
# Model Eval Results:
# *****************************
# training error: 0.0416
# evaluation error: 0.0724
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0      w189_rank_p_L05_avg    0.036085
# 1      w189_rank_v_L05_avg    0.035576
# 2  ivv_w252_rank_p_L63_avg    0.013467
# 3  ivv_w252_rank_v_L63_avg    0.013410
# 4     w252_rank_p_L252_avg    0.013026
# 5       w10_rank_p_L10_avg    0.012988
# 6       w10_rank_v_L10_avg    0.012933
# 7     w252_rank_v_L252_avg    0.012024
# 8       w21_rank_p_L84_avg    0.009646
# 9      w42_rank_v_L189_avg    0.009511
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: -0.0011
#      true_value  pred_value  mkt_return   returns
# 85     0.222222    0.628832    0.014822 -0.003892
# 102    0.143791    0.623470    0.014822 -0.014020
# 23     0.535948    0.616350    0.014822  0.007084
# 50     0.928105    0.615662    0.014822  0.034662
# 123    0.065359    0.610702    0.014822 -0.029510
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0004
#      true_value  pred_value  mkt_return   returns
# 92     0.235294    0.305757    0.014822 -0.002523
# 149    0.424837    0.305437    0.014822  0.002283
# 82     0.352941    0.304045    0.014822  0.001203
# 86     0.294118    0.298858    0.014822 -0.000401
# 59     0.366013    0.295036    0.014822  0.001376
# ********************************************************
# Building model to predict for  2017-11-03
# Model Eval Results:
# *****************************
# training error: 0.0416
# evaluation error: 0.0894
# Model Variable Importance Top 10:
#                 Feature  Importance
# 0   w189_rank_p_L63_avg    0.016925
# 1   w189_rank_p_L05_avg    0.016386
# 2   w189_rank_v_L63_avg    0.016263
# 3  w252_rank_p_L252_avg    0.014698
# 4   w189_rank_v_L05_avg    0.014578
# 5   w84_rank_v_L126_avg    0.014564
# 6  w252_rank_v_L252_avg    0.013861
# 7   w84_rank_p_L126_avg    0.013575
# 8   w252_rank_v_L05_avg    0.011344
# 9   w252_rank_p_L05_avg    0.010949
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: -0.0088
#      true_value  pred_value  mkt_return   returns
# 78     0.633987    0.691911    0.018487  0.008657
# 138    0.039216    0.647867    0.018487 -0.043342
# 39     0.679739    0.634008    0.018487  0.011986
# 90     0.248366    0.633579    0.018487 -0.004847
# 126    0.117647    0.631803    0.018487 -0.016406
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0007
#      true_value  pred_value  mkt_return   returns
# 61     0.411765    0.411051    0.018487 -0.000045
# 82     0.352941    0.409693    0.018487 -0.002229
# 4      0.424837    0.408371    0.018487  0.000383
# 149    0.529412    0.398723    0.018487  0.002838
# 124    0.522876    0.385592    0.018487  0.002758
# ********************************************************
# Building model to predict for  2017-12-05
# Model Eval Results:
# *****************************
# training error: 0.0409
# evaluation error: 0.0905
# Model Variable Importance Top 10:
#                   Feature  Importance
# 0     w189_rank_p_L05_avg    0.024660
# 1     w189_rank_v_L05_avg    0.024383
# 2     w252_rank_p_L05_avg    0.023762
# 3     w252_rank_v_L05_avg    0.022852
# 4    w252_rank_v_L252_avg    0.019727
# 5    w252_rank_p_L252_avg    0.018253
# 6     w84_rank_v_L126_avg    0.016111
# 7  ivv_w84_rank_p_L05_avg    0.016058
# 8     w84_rank_p_L126_avg    0.015262
# 9  ivv_w84_rank_v_L05_avg    0.014768
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0723
#      true_value  pred_value  mkt_return   returns
# 78     0.993464    0.727014    0.043916  0.137926
# 101    0.287582    0.721708    0.043916  0.026256
# 126    0.960784    0.648689    0.043916  0.104608
# 45     0.516340    0.607316    0.043916  0.043878
# 47     0.607843    0.604721    0.043916  0.048639
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0741
#      true_value  pred_value  mkt_return   returns
# 83     0.790850    0.279242    0.043916  0.067578
# 11     0.941176    0.271950    0.043916  0.097964
# 103    0.712418    0.271004    0.043916  0.055779
# 143    0.882353    0.261084    0.043916  0.085751
# 104    0.745098    0.250142    0.043916  0.063630
# ********************************************************
# Building model to predict for  2018-01-05
# Model Eval Results:
# *****************************
# training error: 0.0396
# evaluation error: 0.0841
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0       w252_rank_v_L05_avg    0.030800
# 1       w252_rank_p_L21_avg    0.028929
# 2       w252_rank_p_L05_avg    0.028042
# 3       w252_rank_v_L21_avg    0.026584
# 4      w252_rank_v_L252_avg    0.015259
# 5      w252_rank_p_L252_avg    0.014297
# 6       w84_rank_v_L126_avg    0.013286
# 7       w84_rank_p_L126_avg    0.011724
# 8         w5_rank_p_L84_avg    0.009976
# 9  ivv_w126_rank_v_L189_avg    0.009889
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0132
#     true_value  pred_value  mkt_return   returns
# 29    0.614379    0.726592   -0.014782 -0.012035
# 55    0.875817    0.715410   -0.014782  0.008201
# 40    0.980392    0.709876   -0.014782  0.032339
# 60    0.986928    0.698135   -0.014782  0.045941
# 50    0.660131    0.697501   -0.014782 -0.008542
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0188
#      true_value  pred_value  mkt_return   returns
# 95     0.091503    0.429925   -0.014782 -0.043780
# 65     0.522876    0.427761   -0.014782 -0.015310
# 66     0.856209    0.427623   -0.014782  0.006709
# 143    0.947712    0.425576   -0.014782  0.021816
# 75     0.058824    0.397025   -0.014782 -0.063244
# ********************************************************
# Building model to predict for  2018-02-06
# Model Eval Results:
# *****************************
# training error: 0.0362
# evaluation error: 0.0837
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0       w21_rank_v_L252_avg    0.059641
# 1       w21_rank_p_L252_avg    0.058053
# 2   ivv_w63_rank_v_L189_avg    0.020758
# 3   ivv_w63_rank_p_L189_avg    0.020529
# 4      w252_rank_p_L252_avg    0.015873
# 5       w84_rank_v_L126_avg    0.015346
# 6       w84_rank_p_L126_avg    0.015236
# 7      w252_rank_v_L252_avg    0.015228
# 8  ivv_w126_rank_v_L189_avg    0.015038
# 9  ivv_w126_rank_p_L189_avg    0.013987
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: -0.0093
#      true_value  pred_value  mkt_return   returns
# 133    0.745098    0.731948    0.017953  0.018685
# 24     0.555556    0.655470    0.017953  0.004421
# 79     0.666667    0.653721    0.017953  0.013029
# 58     0.124183    0.653591    0.017953 -0.015653
# 78     0.006536    0.653083    0.017953 -0.066834
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0189
#     true_value  pred_value  mkt_return   returns
# 9     0.594771    0.462342    0.017953  0.005567
# 8     0.490196    0.449628    0.017953  0.001289
# 53    0.228758    0.439820    0.017953 -0.008170
# 29    0.019608    0.431303    0.017953 -0.057685
# 14    0.065359    0.416600    0.017953 -0.035435
# ********************************************************
# Building model to predict for  2018-03-08
# Model Eval Results:
# *****************************
# training error: 0.042
# evaluation error: 0.0797
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0      w252_rank_v_L42_avg    0.042545
# 1      w252_rank_p_L42_avg    0.041273
# 2       w21_rank_p_L05_avg    0.018983
# 3       w21_rank_v_L05_avg    0.018524
# 4     w252_rank_v_L252_avg    0.014658
# 5  ivv_w42_rank_p_L189_avg    0.014224
# 6  ivv_w42_rank_v_L189_avg    0.013324
# 7     w252_rank_p_L252_avg    0.012895
# 8      w21_rank_p_L252_avg    0.012792
# 9      w21_rank_v_L252_avg    0.012338
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: -0.0182
#      true_value  pred_value  mkt_return   returns
# 138    0.660131    0.653592   -0.044343  0.000643
# 6      0.405229    0.635667   -0.044343 -0.024337
# 88     0.228758    0.630433   -0.044343 -0.036757
# 29     0.287582    0.630319   -0.044343 -0.032700
# 65     0.699346    0.620716   -0.044343  0.002102
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0143
#      true_value  pred_value  mkt_return   returns
# 40     0.915033    0.436671   -0.044343  0.014475
# 139    0.013072    0.410386   -0.044343 -0.091123
# 104    0.836601    0.410140   -0.044343  0.008038
# 48     0.758170    0.409138   -0.044343  0.003772
# 45     0.542484    0.400706   -0.044343 -0.006782
# ********************************************************
# Building model to predict for  2018-04-09
# Model Eval Results:
# *****************************
# training error: 0.0432
# evaluation error: 0.0763
# Model Variable Importance Top 10:
#                     Feature  Importance
# 0       w252_rank_v_L63_avg    0.034351
# 1       w252_rank_p_L63_avg    0.029313
# 2    ivv_w63_rank_v_L63_avg    0.018741
# 3    ivv_w63_rank_p_L63_avg    0.017000
# 4   ivv_w42_rank_v_L189_avg    0.016115
# 5  ivv_w252_rank_v_L126_avg    0.015677
# 6   ivv_w42_rank_p_L189_avg    0.015441
# 7  ivv_w252_rank_p_L126_avg    0.015169
# 8    ivv_w21_rank_v_L84_avg    0.013173
# 9    ivv_w21_rank_p_L84_avg    0.012439
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: -0.0023
#      true_value  pred_value  mkt_return   returns
# 37     0.660131    0.621196    0.022764  0.016743
# 104    0.209150    0.605050    0.022764 -0.011566
# 132    0.562092    0.595236    0.022764  0.012972
# 47     0.607843    0.588922    0.022764  0.014907
# 54     0.045752    0.576496    0.022764 -0.044545
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0139
#     true_value  pred_value  mkt_return   returns
# 92    0.908497    0.361431    0.022764  0.038999
# 98    0.117647    0.360959    0.022764 -0.028193
# 45    0.235294    0.357583    0.022764 -0.008380
# 26    0.058824    0.355229    0.022764 -0.040167
# 88    0.091503    0.354956    0.022764 -0.032006
# ********************************************************
# Building model to predict for  2018-05-08
# Model Eval Results:
# *****************************
# training error: 0.0401
# evaluation error: 0.0872
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0      w21_rank_v_L252_avg    0.034982
# 1      w21_rank_p_L252_avg    0.034754
# 2  ivv_w189_rank_p_L05_avg    0.024992
# 3  ivv_w189_rank_v_L05_avg    0.024291
# 4  ivv_w21_rank_p_L252_avg    0.023278
# 5  ivv_w21_rank_v_L252_avg    0.020408
# 6  ivv_w189_rank_p_L42_avg    0.019243
# 7  ivv_w189_rank_v_L42_avg    0.017949
# 8     w252_rank_p_L252_avg    0.016512
# 9     w252_rank_v_L252_avg    0.016150
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0007
#      true_value  pred_value  mkt_return   returns
# 42     0.137255    0.668077    0.039378 -0.017874
# 120    0.718954    0.643296    0.039378  0.030226
# 33     0.039216    0.618450    0.039378 -0.056563
# 27     0.869281    0.597598    0.039378  0.043397
# 29     0.366013    0.590619    0.039378  0.004198
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0103
#      true_value  pred_value  mkt_return   returns
# 87     0.758170    0.432404    0.039378  0.033820
# 26     0.411765    0.426192    0.039378  0.004637
# 98     0.385621    0.420386    0.039378  0.004397
# 149    0.333333    0.404635    0.039378  0.003625
# 124    0.418301    0.390566    0.039378  0.004783
# ********************************************************
# Building model to predict for  2018-06-07
# Model Eval Results:
# *****************************
# training error: 0.0412
# evaluation error: 0.0984
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0  ivv_w189_rank_v_L05_avg    0.032704
# 1  ivv_w189_rank_p_L05_avg    0.031172
# 2     w252_rank_v_L189_avg    0.025876
# 3     w252_rank_p_L189_avg    0.024635
# 4  ivv_w21_rank_v_L252_avg    0.023391
# 5     w189_rank_p_L126_avg    0.022706
# 6  ivv_w21_rank_p_L252_avg    0.022564
# 7     w189_rank_v_L126_avg    0.017064
# 8     w252_rank_v_L252_avg    0.016893
# 9     w252_rank_p_L252_avg    0.015150
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: -0.0123
#     true_value  pred_value  mkt_return   returns
# 81    0.790850    0.721666    0.006674  0.012536
# 78    0.261438    0.718426    0.006674 -0.013455
# 28    0.045752    0.660170    0.006674 -0.073943
# 47    0.869281    0.635252    0.006674  0.022087
# 22    0.326797    0.628752    0.006674 -0.008615
# Model Bottom Five Picks
#  Avg rtn bottom 5: -0.0036
#      true_value  pred_value  mkt_return   returns
# 24     0.294118    0.365330    0.006674 -0.010229
# 139    0.130719    0.347555    0.006674 -0.045480
# 131    0.836601    0.346970    0.006674  0.018013
# 87     0.816993    0.340692    0.006674  0.016114
# 8      0.535948    0.321287    0.006674  0.003735
# ********************************************************
# Building model to predict for  2018-07-09
# Model Eval Results:
# *****************************
# training error: 0.0372
# evaluation error: 0.0984
# Model Variable Importance Top 10:
#                    Feature  Importance
# 0     w189_rank_p_L126_avg    0.030517
# 1     w189_rank_v_L126_avg    0.028637
# 2  ivv_w189_rank_p_L21_avg    0.027951
# 3  ivv_w189_rank_p_L05_avg    0.026428
# 4  ivv_w189_rank_v_L05_avg    0.023837
# 5  ivv_w189_rank_v_L21_avg    0.021052
# 6  ivv_w21_rank_p_L252_avg    0.014268
# 7  ivv_w21_rank_v_L252_avg    0.014119
# 8     w252_rank_v_L252_avg    0.013034
# 9     w252_rank_p_L252_avg    0.012877
# *****************************
# Model Top Five Picks
#  Avg rtn top 5: 0.0168
#      true_value  pred_value  mkt_return   returns
# 22     0.313725    0.658618    0.027376 -0.002476
# 144    0.196078    0.654157    0.027376 -0.009421
# 28     1.000000    0.645572    0.027376  0.092049
# 86     0.464052    0.638244    0.027376  0.002435
# 136    0.431373    0.637846    0.027376  0.001406
# Model Bottom Five Picks
#  Avg rtn bottom 5: 0.0309
#      true_value  pred_value  mkt_return   returns
# 55     0.986928    0.378404    0.027376  0.073643
# 100    0.869281    0.373341    0.027376  0.032465
# 143    0.960784    0.370623    0.027376  0.058922
# 133    0.614379    0.364298    0.027376  0.010722
# 24     0.091503    0.358028    0.027376 -0.021436
# ********************************************************

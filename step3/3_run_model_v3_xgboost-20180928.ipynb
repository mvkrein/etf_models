# %%
import os
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import xgboost
from xgboost import XGBClassifier
from xgboostextension import XGBRanker
#%matplotlib notebook

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 2000)
pd.set_option('display.width', 2000)
pd.options.mode.chained_assignment = None  # default='warn'

# %%
data_path = '/home/mvkrein/etf_model/data'
etf_data_file = os.path.join(data_path,'etf_new_var_20180910.csv')
etf_data = pd.read_csv(etf_data_file,index_col=0)

# %%
etf_study_file = os.path.join(data_path,'ETF_list_min_6yr_history.csv')
etf_list = pd.read_csv(etf_study_file,index_col=0)
etf_data.sort_values(['Date','sym'],ascending=True,inplace=True)
etf_data.reset_index(drop=True,inplace=True)

# %%
drop_columns = ['Date','sym','p', 'v', 'p_L05', 'v_L05', 'p_L10', 'v_L10', 'p_L21', 'v_L21', 'p_L42', 'v_L42', 'p_L63', \
                'v_L63', 'p_L84', 'v_L84', 'p_L126', 'v_L126', 'p_L189', 'v_L189', 'p_L252', 'v_L252',\
                'p_L-21', 'v_L-21', 'delta_p_L05', 'delta_p_L10', 'delta_p_L21', 'delta_p_L42', 'delta_p_L63', \
                'delta_p_L84', 'delta_p_L126', 'delta_p_L189', 'delta_p_L252', 'delta_p_L-21', 'delta_v_L05',\
                'delta_v_L10', 'delta_v_L21', 'delta_v_L42', 'delta_v_L63', 'delta_v_L84', 'delta_v_L126', \
                'delta_v_L189', 'delta_v_L252','rank_p_L-21', 'ivv_delta_p_L-21', 'target']

rank_col = ['rank_p_L05','rank_p_L10','rank_p_L21','rank_p_L42',\
            'rank_p_L63','rank_p_L84','rank_p_L126','rank_p_L189','rank_p_L252']

# %%
all_columns = list(etf_data.columns)

# %%
include_columns = [x for x in all_columns if x not in drop_columns]
# include_columns = ['rank_p_L05','rank_p_L10','rank_p_L21','rank_p_L42',\
#             'rank_p_L63','rank_p_L84','rank_p_L126','rank_p_L189','rank_p_L252']
# include_columns = ['rank_p_L05','rank_p_L21','rank_p_L42','rank_p_L252']

# %%
dates = list(etf_data['Date'].unique())
# dates[1671]

# %%
#Each year has 252 trading dates.  Need two years to fully develop variables.
dt1 = 504 #This is the first day that all variables are developed
# make all dates relative to dt1
# for one year training - add 252
# to evaluate for one month outside the training window - add 273
# to predict for the first day outside of the evaluation window (have to lag 21) - add 294
dt_end = (len(dates) - 273 - 21) - 1
# dt_end = 505
rpeat = len(etf_data['sym'].unique())
etf_predict_file = os.path.join(data_path,'etf_pred_xgboost_binary_reg_20180928.csv')

# %%
for i in range(dt1,dt_end,21):
    print("Building model to predict for ",dates[i+273])
    x_train = etf_data.loc[((etf_data['Date']>=dates[i]) & (etf_data['Date']<dates[i+231])),include_columns] #train with 12 mos
    y_train = etf_data.loc[((etf_data['Date']>=dates[i]) & (etf_data['Date']<dates[i+231])),['target']] #train with 12 mos
    x_eval = etf_data.loc[((etf_data['Date']>=dates[i+231]) & (etf_data['Date']<dates[i+252])),include_columns] #eval with 1 mos
    y_eval = etf_data.loc[((etf_data['Date']>=dates[i+231]) & (etf_data['Date']<dates[i+252])),['rank_p_L-21']] #eval with 1 mos
#     x_train, x_eval, y_train, y_eval = train_test_split\
#     (etf_data.loc[((etf_data['Date']>=dates[i]) & (etf_data['Date']<dates[i+252])),include_columns],\
#      etf_data.loc[((etf_data['Date']>=dates[i]) & (etf_data['Date']<dates[i+252])),['target']],\
#      test_size=0.2, random_state=54321)
#     x_eval = x_train
#     y_eval = y_train
#predict one day
    x_test = etf_data.loc[(etf_data['Date']==dates[i+273]),include_columns] #predict one day-must be 21 days removed from training
    y_test = etf_data.loc[(etf_data['Date']==dates[i+273]),['target']] #predict if etf >= market
    returns = etf_data.loc[(etf_data['Date']==dates[i+273]),['delta_p_L-21']]
    mkt_return = etf_data.loc[(etf_data['Date']==dates[i+273]),['ivv_delta_p_L-21']]
    x_train_nmpy = x_train.as_matrix()
    y_train_nmpy = y_train.as_matrix()
    x_eval_nmpy = x_eval.as_matrix()
    y_eval_nmpy = y_eval.as_matrix()
    x_test_nmpy = x_test.as_matrix()
    y_test_nmpy = y_test.as_matrix()
    returns_nmpy = returns.as_matrix()
    mkt_return_nmpy = mkt_return.as_matrix()
    x_train_groups = np.repeat(rpeat,231)
    x_eval_groups = np.repeat(rpeat,21)
    x_test_groups = np.repeat(rpeat,1)
    train_xgb = xgboost.DMatrix(x_train_nmpy,label=y_train_nmpy,feature_names=include_columns)
    train_xgb.set_group(x_train_groups)
    eval_xgb = xgboost.DMatrix(x_eval_nmpy,label=y_eval_nmpy,feature_names=include_columns)
    eval_xgb.set_group(x_eval_groups)
    pred_xgb = xgboost.DMatrix(x_test_nmpy,feature_names=include_columns)
    pred_xgb.set_group(x_test_groups)
#turn down learning rate from default value of 0.3, otherwise accept defaults

    param = {'eta':0.3,'seed':54321,'objective':'binary:logistic','max_depth':4, 'subsample': 0.8,'scale_pos_weight':1,\
             'colsample_bytree':0.8,'min_child_weight':1,'gamma':10,'nthread':32,'eval_metric':'auc'\
            ,'lambda':5,'alpha':2}
    param['nthread']=32  #change this to the number of cores on your machine
    param['random_state']=54321 #random number to start
    param['silent']=1 #set to 1 if you don't want all the output

    evallist = [(train_xgb,'train'),(eval_xgb,'eval')]
#     evallist = [(train_xgb,'train')]
    plst = param.items()
    num_round = 500 #max number of rounds -- shouldn't ever get there with early stopping
    evals_result = {}
    bst = xgboost.train(plst,train_xgb,num_round,evals=evallist,early_stopping_rounds=30,verbose_eval=False,\
                        evals_result=evals_result)

    y_model = bst.predict(pred_xgb)
    y_model_array = y_model.reshape((y_test_nmpy.shape))
#     y_model_df = pd.DataFrame(y_model_array,columns=['probability'])
#     y_model_df.sort_values(by='probability',ascending=False,inplace=True)
#     check_val = y_model_df.iloc[4][0]
    y_check = np.column_stack((y_test_nmpy, y_model_array,mkt_return_nmpy,returns_nmpy))
    y_check_df = pd.DataFrame(y_check,columns=['true_value','model_value','mkt_return','returns'])
    y_check_df.sort_values('model_value',inplace=True,ascending=False)
    var_fscore = pd.DataFrame.from_dict(bst.get_fscore(),orient='index')
    var_fscore.columns = ['fscore']
    var_fscore.sort_values(by='fscore',ascending=False,inplace=True)
#     train_error = evals_result['train']['auc'][len(evals_result['train']['auc'])-1]
#     eval_error = evals_result['eval']['auc'][len(evals_result['eval']['auc'])-1]
    number_of_rounds = len(evals_result['train']['auc'])
    train_error = evals_result['train']['auc'][bst.best_iteration]
    eval_error = evals_result['eval']['auc'][bst.best_iteration]
#     number_of_rounds = len(evals_result['eval']['ndcg'])
    print('Model Eval Results:')
    print('Training auc: ',train_error)
    print('Evaluation auc: ',eval_error)
    print('Number of rounds: ',number_of_rounds)
    print('Model Variable Importance:')
    print(var_fscore.iloc[0:10])
    print('*****************************')
    confusion = confusion_matrix(y_test_nmpy, (y_model_array>=0.8).astype(int))
#     fpr, tpr, thresholds = roc_curve(y_test_nmpy, (y_model_array>0.5).astype(int), pos_label=1)
    precision = confusion[1,1]/(confusion[1,1]+confusion[0,1])
    print('xgboost prediction - confusion matrix\n', confusion,'\nprecision: ',round(precision,3))
    print('*****************************')
    print("Model Top 5 Picks")
    print(" Avg rtn top 5:", round(y_check_df['returns'][0:5].mean(),4))
    print(y_check_df.head(5))
    print("Model Bottom 5 Picks")
    print(" Avg rtn bottom 5:", round(y_check_df['returns'][-5:].mean(),4))
    print(y_check_df.tail(5))
    print('********************************************************')
    if i == dt1:
        predict_data = etf_data.loc[(etf_data['Date']==dates[i+273]),['Date','sym','target']]
        predict_data['predict'] = y_model_array
        predict_data.to_csv(etf_predict_file)
    else:
        predict_data = etf_data.loc[(etf_data['Date']==dates[i+273]),['Date','sym','target']]
        predict_data['predict'] = y_model_array
        predict_data.to_csv(etf_predict_file,header=False,mode='a')
# Out:
# Building model to predict for  2015-02-05
# Model Eval Results:
# Training auc:  0.976447
# Evaluation auc:  0.560165
# Number of rounds:  224
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      59
# w189_rank_p_L252_avg      29
# w189_rank_p_L42_avg       29
# w42_rank_p_L21_avg        26
# w63_rank_p_L63_avg        25
# w252_rank_p_L126_avg      22
# w252_rank_p_L21_avg       22
# w189_rank_p_L21_avg       21
# w84_rank_p_L252_avg       20
# w252_rank_p_L189_avg      20
# *****************************
# xgboost prediction - confusion matrix
#  [[106   0]
#  [ 41   6]]
# precision:  1.0
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0411
#      true_value  model_value  mkt_return   returns
# 70          1.0     0.963484    0.010741  0.071770
# 83          1.0     0.950708    0.010741  0.038518
# 88          1.0     0.907849    0.010741  0.069374
# 129         1.0     0.866472    0.010741  0.013101
# 113         1.0     0.810586    0.010741  0.012604
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.009
#      true_value  model_value  mkt_return   returns
# 135         1.0     0.015700    0.010741  0.016322
# 39          0.0     0.015058    0.010741 -0.016544
# 45          1.0     0.011035    0.010741  0.036401
# 57          0.0     0.005714    0.010741 -0.085190
# 38          0.0     0.004533    0.010741  0.004112
# ********************************************************
# Building model to predict for  2015-03-09
# Model Eval Results:
# Training auc:  0.971526
# Evaluation auc:  0.635849
# Number of rounds:  191
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      57
# w42_rank_p_L21_avg        33
# w126_rank_p_L252_avg      25
# w189_rank_p_L252_avg      25
# w21_rank_p_L21_avg        24
# w252_rank_p_L189_avg      23
# w252_rank_p_L63_avg       23
# w252_rank_p_L126_avg      23
# w252_rank_p_L42_avg       21
# w42_rank_p_L126_avg       21
# *****************************
# xgboost prediction - confusion matrix
#  [[ 14   5]
#  [120  14]]
# precision:  0.737
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0742
#      true_value  model_value  mkt_return   returns
# 71          1.0     0.946692     0.00266  0.044556
# 133         1.0     0.938974     0.00266  0.052917
# 75          1.0     0.936863     0.00266  0.056148
# 81          1.0     0.917342     0.00266  0.037932
# 60          1.0     0.913049     0.00266  0.179205
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0449
#      true_value  model_value  mkt_return   returns
# 38          1.0     0.080178     0.00266  0.033106
# 72          1.0     0.068579     0.00266  0.070009
# 41          1.0     0.066231     0.00266  0.052975
# 135         1.0     0.061871     0.00266  0.038219
# 76          1.0     0.038313     0.00266  0.030317
# ********************************************************
# Building model to predict for  2015-04-08
# Model Eval Results:
# Training auc:  0.679064
# Evaluation auc:  0.551141
# Number of rounds:  30
# Model Variable Importance:
#                          fscore
# w252_rank_p_L252_avg         22
# w252_rank_p_L189_avg         13
# w252_rank_p_L126_avg          9
# w252_rank_p_L63_avg           8
# w21_rank_p_L84_avg            8
# ivv_w252_rank_p_L84_avg       7
# w189_rank_p_L252_avg          7
# w252_rank_p_L84_avg           7
# w84_rank_p_L21_avg            6
# w42_rank_p_L21_avg            6
# *****************************
# xgboost prediction - confusion matrix
#  [[106   0]
#  [ 46   1]]
# precision:  1.0
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0346
#      true_value  model_value  mkt_return   returns
# 62          1.0     0.814874    0.004202  0.078510
# 102         1.0     0.788946    0.004202  0.031851
# 110         0.0     0.687766    0.004202 -0.000261
# 130         0.0     0.674416    0.004202 -0.001081
# 54          1.0     0.670107    0.004202  0.064196
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.0311
#      true_value  model_value  mkt_return   returns
# 80          0.0     0.107410    0.004202 -0.020911
# 21          0.0     0.107271    0.004202 -0.000831
# 43          1.0     0.101125    0.004202  0.015840
# 23          0.0     0.095904    0.004202 -0.083423
# 146         0.0     0.079816    0.004202 -0.066340
# ********************************************************
# Building model to predict for  2015-05-07
# Model Eval Results:
# Training auc:  0.928079
# Evaluation auc:  0.558481
# Number of rounds:  81
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      36
# w252_rank_p_L126_avg      20
# w21_rank_p_L21_avg        18
# w189_rank_p_L252_avg      18
# w42_rank_p_L21_avg        16
# w252_rank_p_L189_avg      15
# w252_rank_p_L63_avg       14
# w252_rank_p_L84_avg       13
# w126_rank_p_L126_avg      13
# w252_rank_v_L252_avg      12
# *****************************
# xgboost prediction - confusion matrix
#  [[71 24]
#  [51  7]]
# precision:  0.226
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: -0.0033
#      true_value  model_value  mkt_return   returns
# 45          1.0     0.958081   -0.001902  0.004224
# 38          0.0     0.918639   -0.001902 -0.031292
# 36          0.0     0.912460   -0.001902 -0.046041
# 68          1.0     0.897487   -0.001902  0.045688
# 135         1.0     0.892380   -0.001902  0.010878
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.0124
#      true_value  model_value  mkt_return   returns
# 150         0.0     0.128111   -0.001902 -0.010214
# 151         0.0     0.103998   -0.001902 -0.029686
# 145         0.0     0.101651   -0.001902 -0.015658
# 139         1.0     0.089538   -0.001902  0.027010
# 133         0.0     0.063167   -0.001902 -0.033232
# ********************************************************
# Building model to predict for  2015-06-08
# Model Eval Results:
# Training auc:  0.828352
# Evaluation auc:  0.634551
# Number of rounds:  38
# Model Variable Importance:
#                           fscore
# w252_rank_p_L252_avg          19
# w252_rank_p_L189_avg          14
# w252_rank_p_L126_avg          14
# w252_rank_p_L63_avg           10
# w126_rank_p_L21_avg            9
# w42_rank_p_L21_avg             9
# w42_rank_p_L42_avg             9
# rank_p_L10                     9
# ivv_w189_rank_p_L126_avg       8
# w63_rank_p_L05_avg             7
# *****************************
# xgboost prediction - confusion matrix
#  [[77 15]
#  [56  5]]
# precision:  0.25
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: -0.0202
#      true_value  model_value  mkt_return   returns
# 102         1.0     0.957217    -0.01377 -0.007125
# 31          0.0     0.920582    -0.01377 -0.032401
# 123         1.0     0.918340    -0.01377 -0.011724
# 52          1.0     0.917460    -0.01377 -0.010439
# 44          0.0     0.912048    -0.01377 -0.039553
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.0174
#      true_value  model_value  mkt_return   returns
# 131         1.0     0.094044    -0.01377 -0.009344
# 139         0.0     0.092238    -0.01377 -0.079822
# 93          1.0     0.085674    -0.01377 -0.007524
# 89          1.0     0.077206    -0.01377  0.015872
# 96          1.0     0.073977    -0.01377 -0.006254
# ********************************************************
# Building model to predict for  2015-07-08
# Model Eval Results:
# Training auc:  0.936535
# Evaluation auc:  0.570188
# Number of rounds:  84
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      30
# w252_rank_p_L189_avg      19
# w252_rank_p_L126_avg      18
# w42_rank_p_L42_avg        17
# w252_rank_p_L84_avg       17
# w126_rank_p_L252_avg      16
# w84_rank_p_L84_avg        15
# w252_rank_p_L63_avg       15
# w21_rank_p_L21_avg        15
# w189_rank_p_L252_avg      15
# *****************************
# xgboost prediction - confusion matrix
#  [[90  0]
#  [62  1]]
# precision:  1.0
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0162
#      true_value  model_value  mkt_return   returns
# 84          1.0     0.863523    0.018605  0.031509
# 110         1.0     0.794696    0.018605  0.029565
# 83          1.0     0.777967    0.018605  0.045770
# 139         0.0     0.756457    0.018605 -0.031814
# 121         0.0     0.720422    0.018605  0.005747
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0213
#      true_value  model_value  mkt_return   returns
# 134         1.0     0.021980    0.018605  0.041711
# 132         0.0     0.019516    0.018605 -0.019248
# 98          0.0     0.018292    0.018605  0.017032
# 80          1.0     0.017174    0.018605  0.044429
# 146         1.0     0.013992    0.018605  0.022512
# ********************************************************
# Building model to predict for  2015-08-06
# Model Eval Results:
# Training auc:  0.949889
# Evaluation auc:  0.582422
# Number of rounds:  102
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      43
# w21_rank_p_L21_avg        21
# w252_rank_p_L63_avg       20
# w252_rank_p_L126_avg      19
# w252_rank_p_L84_avg       16
# w42_rank_p_L42_avg        16
# w84_rank_p_L84_avg        15
# w252_rank_p_L05_avg       15
# w42_rank_p_L21_avg        15
# w252_rank_p_L189_avg      15
# *****************************
# xgboost prediction - confusion matrix
#  [[69  1]
#  [82  1]]
# precision:  0.5
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: -0.073
#      true_value  model_value  mkt_return   returns
# 55          0.0     0.811831   -0.076446 -0.131111
# 121         1.0     0.800127   -0.076446 -0.064390
# 132         1.0     0.782817   -0.076446 -0.033645
# 105         1.0     0.733822   -0.076446 -0.075197
# 122         1.0     0.733147   -0.076446 -0.060650
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.1249
#      true_value  model_value  mkt_return   returns
# 39          0.0     0.054050   -0.076446 -0.149520
# 25          0.0     0.047713   -0.076446 -0.090285
# 118         1.0     0.046837   -0.076446 -0.067310
# 126         0.0     0.024987   -0.076446 -0.154767
# 60          0.0     0.022675   -0.076446 -0.162802
# ********************************************************
# Building model to predict for  2015-09-04
# Model Eval Results:
# Training auc:  0.968302
# Evaluation auc:  0.603718
# Number of rounds:  155
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      53
# w252_rank_p_L63_avg       33
# w189_rank_p_L252_avg      31
# w252_rank_p_L126_avg      27
# w252_rank_p_L42_avg       25
# w252_rank_p_L05_avg       19
# w42_rank_p_L42_avg        19
# w84_rank_p_L84_avg        19
# w189_rank_p_L21_avg       18
# w21_rank_p_L21_avg        17
# *****************************
# xgboost prediction - confusion matrix
#  [[85  4]
#  [64  0]]
# precision:  0.0
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: -0.0451
#      true_value  model_value  mkt_return   returns
# 88          0.0     0.962338    0.032631 -0.081203
# 70          0.0     0.946919    0.032631 -0.104385
# 90          0.0     0.946738    0.032631 -0.021609
# 89          0.0     0.863020    0.032631 -0.048146
# 110         0.0     0.797644    0.032631  0.029623
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0245
#     true_value  model_value  mkt_return   returns
# 40         1.0     0.011418    0.032631  0.043994
# 37         0.0     0.009609    0.032631  0.023327
# 14         0.0     0.009537    0.032631  0.021016
# 29         0.0     0.008273    0.032631  0.010875
# 69         0.0     0.002512    0.032631  0.023084
# ********************************************************
# Building model to predict for  2015-10-06
# Model Eval Results:
# Training auc:  0.959219
# Evaluation auc:  0.626344
# Number of rounds:  113
# Model Variable Importance:
#                           fscore
# w252_rank_p_L252_avg          44
# w252_rank_p_L126_avg          24
# w189_rank_p_L252_avg          22
# w252_rank_p_L84_avg           21
# w252_rank_p_L63_avg           19
# ivv_w189_rank_p_L126_avg      17
# w21_rank_p_L21_avg            15
# w252_rank_p_L05_avg           15
# w126_rank_p_L63_avg           15
# w63_rank_p_L21_avg            14
# *****************************
# xgboost prediction - confusion matrix
#  [[124   7]
#  [ 22   0]]
# precision:  0.0
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0024
#      true_value  model_value  mkt_return   returns
# 132         0.0     0.888693    0.063911 -0.024366
# 123         0.0     0.872617    0.063911  0.011274
# 62          0.0     0.871961    0.063911 -0.046656
# 32          0.0     0.852637    0.063911  0.047994
# 118         0.0     0.833213    0.063911  0.023881
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0671
#      true_value  model_value  mkt_return   returns
# 17          0.0     0.063456    0.063911  0.027884
# 120         1.0     0.057543    0.063911  0.065964
# 114         0.0     0.033244    0.063911  0.051560
# 148         1.0     0.022950    0.063911  0.104081
# 66          1.0     0.021665    0.063911  0.086203
# ********************************************************
# Building model to predict for  2015-11-04
# Model Eval Results:
# Training auc:  0.9543
# Evaluation auc:  0.552429
# Number of rounds:  123
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      35
# w252_rank_p_L126_avg      28
# w189_rank_p_L252_avg      20
# w21_rank_p_L21_avg        18
# rank_p_L05                18
# w42_rank_p_L42_avg        17
# w252_rank_p_L84_avg       17
# w252_rank_p_L42_avg       16
# w42_rank_p_L21_avg        14
# w126_rank_p_L21_avg       14
# *****************************
# xgboost prediction - confusion matrix
#  [[78  6]
#  [63  6]]
# precision:  0.5
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0081
#      true_value  model_value  mkt_return   returns
# 44          1.0     0.944424   -0.003687  0.037356
# 76          1.0     0.929473   -0.003687  0.028771
# 143         0.0     0.918835   -0.003687 -0.057326
# 93          1.0     0.908740   -0.003687 -0.003418
# 134         1.0     0.882230   -0.003687  0.035149
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.0295
#     true_value  model_value  mkt_return   returns
# 58         0.0     0.225983   -0.003687 -0.010321
# 77         0.0     0.211491   -0.003687 -0.016064
# 70         0.0     0.195077   -0.003687 -0.017504
# 54         0.0     0.079448   -0.003687 -0.026534
# 55         0.0     0.031158   -0.003687 -0.076829
# ********************************************************
# Building model to predict for  2015-12-04
# Model Eval Results:
# Training auc:  0.757929
# Evaluation auc:  0.599477
# Number of rounds:  34
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      18
# w21_rank_p_L21_avg         9
# w252_rank_p_L189_avg       9
# w42_rank_p_L42_avg         8
# w252_rank_p_L126_avg       8
# w189_rank_p_L252_avg       7
# rank_p_L21                 6
# w126_rank_p_L126_avg       6
# w63_rank_p_L126_avg        6
# w21_rank_p_L63_avg         6
# *****************************
# xgboost prediction - confusion matrix
#  [[81  0]
#  [72  0]]
# precision:  nan
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: -0.0392
#      true_value  model_value  mkt_return   returns
# 151         1.0     0.688428   -0.046016  0.025416
# 105         1.0     0.645300   -0.046016 -0.042974
# 129         0.0     0.626329   -0.046016 -0.047366
# 110         0.0     0.620927   -0.046016 -0.049025
# 126         0.0     0.614030   -0.046016 -0.082203
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.0778
#      true_value  model_value  mkt_return   returns
# 138         1.0     0.087138   -0.046016 -0.036770
# 31          0.0     0.085977   -0.046016 -0.082093
# 55          0.0     0.080719   -0.046016 -0.134393
# 54          0.0     0.073509   -0.046016 -0.142214
# 69          1.0     0.060086   -0.046016  0.006667
# ********************************************************
# Building model to predict for  2016-01-06
# /home/mvkrein/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:75: RuntimeWarning: invalid value encountered in long_scalars
# Model Eval Results:
# Training auc:  0.876377
# Evaluation auc:  0.597048
# Number of rounds:  50
# Model Variable Importance:
#                           fscore
# w252_rank_p_L252_avg          19
# w252_rank_p_L126_avg          16
# w189_rank_p_L252_avg          11
# ivv_w189_rank_p_L126_avg      11
# rank_p_L05                    10
# w21_rank_p_L21_avg             9
# w42_rank_p_L05_avg             9
# w126_rank_p_L05_avg            9
# w84_rank_p_L63_avg             8
# w42_rank_v_L42_avg             8
# *****************************
# xgboost prediction - confusion matrix
#  [[60  0]
#  [93  0]]
# precision:  nan
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: -0.0601
#      true_value  model_value  mkt_return   returns
# 93          0.0     0.799279   -0.054663 -0.071105
# 90          0.0     0.752710   -0.054663 -0.065998
# 97          1.0     0.745717   -0.054663  0.001966
# 104         0.0     0.741275   -0.054663 -0.107185
# 78          0.0     0.711851   -0.054663 -0.058267
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0198
#     true_value  model_value  mkt_return   returns
# 42         0.0     0.049156   -0.054663 -0.054857
# 69         1.0     0.048749   -0.054663  0.071902
# 23         1.0     0.048279   -0.054663  0.067271
# 27         1.0     0.040365   -0.054663 -0.024027
# 85         1.0     0.033247   -0.054663  0.038818
# ********************************************************
# Building model to predict for  2016-02-05
# Model Eval Results:
# Training auc:  0.719637
# Evaluation auc:  0.536988
# Number of rounds:  32
# Model Variable Importance:
#                           fscore
# w252_rank_p_L252_avg          19
# w42_rank_p_L42_avg            10
# w21_rank_p_L21_avg             9
# w252_rank_p_L126_avg           9
# w126_rank_p_L63_avg            7
# ivv_w189_rank_p_L126_avg       7
# w21_rank_p_L42_avg             7
# w84_rank_p_L21_avg             6
# ivv_w252_rank_p_L252_avg       6
# w252_rank_p_L189_avg           6
# *****************************
# xgboost prediction - confusion matrix
#  [[90  0]
#  [63  0]]
# precision:  nan
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0701
#      true_value  model_value  mkt_return   returns
# 106         1.0     0.767123    0.055758  0.060871
# 87          1.0     0.745505    0.055758  0.096087
# 67          0.0     0.732653    0.055758  0.043027
# 96          1.0     0.730903    0.055758  0.077083
# 93          1.0     0.727712    0.055758  0.073184
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0277
#      true_value  model_value  mkt_return   returns
# 12          0.0     0.146266    0.055758 -0.005671
# 127         0.0     0.146266    0.055758 -0.005545
# 14          1.0     0.125342    0.055758  0.072744
# 53          0.0     0.118792    0.055758  0.018931
# 148         1.0     0.118779    0.055758  0.058258
# ********************************************************
# Building model to predict for  2016-03-08
# Model Eval Results:
# Training auc:  0.904922
# Evaluation auc:  0.568785
# Number of rounds:  65
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      24
# w252_rank_p_L189_avg      16
# w252_rank_p_L126_avg      15
# w21_rank_p_L21_avg        13
# w84_rank_p_L63_avg        13
# w126_rank_p_L42_avg       13
# rank_p_L05                11
# w21_rank_p_L42_avg        11
# w84_rank_p_L21_avg        10
# w84_rank_p_L05_avg        10
# *****************************
# xgboost prediction - confusion matrix
#  [[106   0]
#  [ 47   0]]
# precision:  nan
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0513
#      true_value  model_value  mkt_return   returns
# 71          1.0     0.781377    0.033627  0.059693
# 128         0.0     0.778827    0.033627  0.013430
# 133         1.0     0.774794    0.033627  0.063681
# 130         1.0     0.755224    0.033627  0.058610
# 151         1.0     0.748863    0.033627  0.061096
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0368
#      true_value  model_value  mkt_return   returns
# 11          0.0     0.069109    0.033627  0.019979
# 102         0.0     0.063787    0.033627  0.033325
# 75          1.0     0.057826    0.033627  0.065267
# 44          1.0     0.048508    0.033627  0.063882
# 54          0.0     0.046947    0.033627  0.001605
# ********************************************************
# Building model to predict for  2016-04-07
# Model Eval Results:
# Training auc:  0.946524
# Evaluation auc:  0.689821
# Number of rounds:  105
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      35
# w189_rank_p_L252_avg      24
# w252_rank_p_L126_avg      19
# w126_rank_p_L42_avg       19
# w84_rank_p_L21_avg        19
# w252_rank_p_L189_avg      18
# w84_rank_p_L126_avg       16
# w252_rank_p_L05_avg       16
# w252_rank_p_L63_avg       16
# w189_rank_p_L189_avg      15
# *****************************
# xgboost prediction - confusion matrix
#  [[63  0]
#  [85  5]]
# precision:  1.0
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0584
#      true_value  model_value  mkt_return   returns
# 33          1.0     0.912511    0.008977  0.060911
# 78          1.0     0.875193    0.008977  0.099176
# 143         1.0     0.843016    0.008977  0.028981
# 62          1.0     0.831699    0.008977  0.093264
# 8           1.0     0.821834    0.008977  0.009596
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0095
#     true_value  model_value  mkt_return   returns
# 52         0.0     0.065339    0.008977  0.008440
# 17         0.0     0.049557    0.008977 -0.001238
# 0          0.0     0.048440    0.008977 -0.010818
# 6          0.0     0.045978    0.008977 -0.005029
# 32         1.0     0.028825    0.008977  0.056305
# ********************************************************
# Building model to predict for  2016-05-06
# Model Eval Results:
# Training auc:  0.952306
# Evaluation auc:  0.576056
# Number of rounds:  109
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      39
# w84_rank_p_L63_avg        18
# w252_rank_p_L189_avg      17
# w252_rank_p_L42_avg       17
# w252_rank_p_L05_avg       16
# w84_rank_p_L21_avg        15
# w126_rank_p_L42_avg       15
# w126_rank_p_L05_avg       15
# w252_rank_p_L126_avg      15
# rank_p_L05                15
# *****************************
# xgboost prediction - confusion matrix
#  [[64  0]
#  [88  1]]
# precision:  1.0
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0767
#      true_value  model_value  mkt_return   returns
# 70          1.0     0.866573    0.028819  0.091978
# 148         0.0     0.754094    0.028819  0.011163
# 88          1.0     0.750680    0.028819  0.114706
# 24          1.0     0.693242    0.028819  0.049097
# 139         1.0     0.692008    0.028819  0.116694
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0315
#      true_value  model_value  mkt_return   returns
# 123         0.0     0.042554    0.028819  0.008543
# 102         0.0     0.036071    0.028819 -0.001328
# 117         1.0     0.035256    0.028819  0.038305
# 132         1.0     0.031607    0.028819  0.030815
# 62          1.0     0.021122    0.028819  0.081246
# ********************************************************
# Building model to predict for  2016-06-07
# Model Eval Results:
# Training auc:  0.945431
# Evaluation auc:  0.61193
# Number of rounds:  104
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      27
# w189_rank_p_L252_avg      23
# w84_rank_p_L63_avg        20
# w126_rank_p_L252_avg      16
# w84_rank_p_L21_avg        16
# w126_rank_p_L42_avg       15
# w252_rank_p_L126_avg      15
# w84_rank_p_L05_avg        14
# w252_rank_p_L189_avg      14
# w63_rank_p_L21_avg        14
# *****************************
# xgboost prediction - confusion matrix
#  [[94  1]
#  [56  2]]
# precision:  0.667
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0196
#      true_value  model_value  mkt_return   returns
# 133         1.0     0.915789   -0.005191  0.062289
# 83          0.0     0.890284   -0.005191 -0.020969
# 151         1.0     0.809048   -0.005191  0.047154
# 127         1.0     0.772132   -0.005191  0.026092
# 87          0.0     0.771945   -0.005191 -0.016681
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.0626
#      true_value  model_value  mkt_return   returns
# 81          0.0     0.034209   -0.005191 -0.028057
# 38          0.0     0.034012   -0.005191 -0.104869
# 112         0.0     0.021497   -0.005191 -0.023581
# 117         0.0     0.015391   -0.005191 -0.080719
# 75          0.0     0.007249   -0.005191 -0.075920
# ********************************************************
# Building model to predict for  2016-07-07
# Model Eval Results:
# Training auc:  0.962091
# Evaluation auc:  0.569914
# Number of rounds:  135
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      43
# w252_rank_p_L189_avg      28
# w126_rank_p_L63_avg       20
# w189_rank_p_L252_avg      20
# w252_rank_p_L42_avg       20
# w84_rank_p_L05_avg        18
# w126_rank_p_L05_avg       18
# w252_rank_p_L126_avg      17
# w126_rank_p_L42_avg       17
# w84_rank_p_L21_avg        17
# *****************************
# xgboost prediction - confusion matrix
#  [[57  4]
#  [87  5]]
# precision:  0.556
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0716
#     true_value  model_value  mkt_return   returns
# 83         1.0     0.894033    0.041489  0.085523
# 15         0.0     0.875649    0.041489  0.040554
# 25         1.0     0.862342    0.041489  0.052247
# 38         1.0     0.856404    0.041489  0.102897
# 45         1.0     0.856001    0.041489  0.076716
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0048
#      true_value  model_value  mkt_return   returns
# 138         0.0     0.054557    0.041489  0.000000
# 88          1.0     0.053212    0.041489  0.055845
# 124         0.0     0.038593    0.041489 -0.007521
# 146         0.0     0.024872    0.041489 -0.030151
# 26          0.0     0.018464    0.041489  0.005809
# ********************************************************
# Building model to predict for  2016-08-05
# Model Eval Results:
# Training auc:  0.832757
# Evaluation auc:  0.566772
# Number of rounds:  44
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      19
# w84_rank_p_L63_avg        13
# w252_rank_p_L189_avg      13
# w21_rank_p_L42_avg         9
# w252_rank_p_L126_avg       8
# rank_p_L05                 8
# rank_p_L10                 8
# w84_rank_p_L05_avg         7
# w84_rank_p_L42_avg         7
# w63_rank_p_L84_avg         7
# *****************************
# xgboost prediction - confusion matrix
#  [[ 39   0]
#  [114   0]]
# precision:  nan
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0419
#      true_value  model_value  mkt_return   returns
# 40          1.0     0.772564    0.004421  0.051188
# 104         0.0     0.727033    0.004421  0.000000
# 47          1.0     0.710846    0.004421  0.060218
# 140         0.0     0.671493    0.004421  0.000006
# 126         1.0     0.648296    0.004421  0.097877
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0169
#     true_value  model_value  mkt_return   returns
# 35         0.0     0.145313    0.004421 -0.005286
# 16         1.0     0.134712    0.004421  0.043419
# 99         1.0     0.132282    0.004421  0.036394
# 54         1.0     0.127790    0.004421  0.024905
# 23         0.0     0.095451    0.004421 -0.014706
# ********************************************************
# Building model to predict for  2016-09-06
# Model Eval Results:
# Training auc:  0.903413
# Evaluation auc:  0.648857
# Number of rounds:  65
# Model Variable Importance:
#                          fscore
# w252_rank_p_L252_avg         32
# w189_rank_p_L252_avg         16
# w84_rank_p_L21_avg           12
# w252_rank_p_L63_avg          12
# w189_rank_p_L42_avg          12
# w189_rank_p_L84_avg          12
# w42_rank_p_L84_avg           10
# w126_rank_p_L42_avg          10
# w252_rank_p_L126_avg          9
# ivv_w189_rank_p_L10_avg       9
# *****************************
# xgboost prediction - confusion matrix
#  [[55  2]
#  [93  3]]
# precision:  0.6
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: -0.0103
#      true_value  model_value  mkt_return   returns
# 127         1.0     0.854696   -0.010794 -0.009145
# 128         1.0     0.844901   -0.010794 -0.009241
# 63          1.0     0.818257   -0.010794 -0.004151
# 12          0.0     0.813495   -0.010794 -0.011552
# 85          0.0     0.805143   -0.010794 -0.017474
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0029
#      true_value  model_value  mkt_return   returns
# 112         1.0     0.061016   -0.010794  0.017487
# 114         1.0     0.058913   -0.010794 -0.002705
# 6           1.0     0.045437   -0.010794  0.002385
# 99          0.0     0.040322   -0.010794 -0.027062
# 118         1.0     0.028485   -0.010794  0.024350
# ********************************************************
# Building model to predict for  2016-10-05
# Model Eval Results:
# Training auc:  0.816934
# Evaluation auc:  0.570156
# Number of rounds:  37
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      20
# w252_rank_p_L63_avg       10
# w252_rank_p_L126_avg      10
# w252_rank_p_L05_avg        7
# w21_rank_p_L42_avg         7
# rank_p_L05                 7
# w84_rank_p_L63_avg         7
# w42_rank_p_L126_avg        6
# w252_rank_p_L189_avg       6
# w42_rank_p_L05_avg         6
# *****************************
# xgboost prediction - confusion matrix
#  [[72  1]
#  [78  2]]
# precision:  0.667
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: -0.0381
#      true_value  model_value  mkt_return   returns
# 133         1.0     0.874671   -0.031675 -0.027193
# 151         0.0     0.822575   -0.031675 -0.038622
# 150         1.0     0.818568   -0.031675 -0.023110
# 89          0.0     0.715639   -0.031675 -0.073389
# 64          1.0     0.702628   -0.031675 -0.027982
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.0202
#     true_value  model_value  mkt_return   returns
# 23         0.0     0.018804   -0.031675 -0.039201
# 60         0.0     0.014609   -0.031675 -0.054320
# 35         0.0     0.014225   -0.031675 -0.040191
# 97         1.0     0.014041   -0.031675  0.023529
# 46         1.0     0.012851   -0.031675  0.009158
# ********************************************************
# Building model to predict for  2016-11-03
# Model Eval Results:
# Training auc:  0.954908
# Evaluation auc:  0.545314
# Number of rounds:  123
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      44
# w252_rank_p_L63_avg       27
# w252_rank_p_L126_avg      22
# w252_rank_p_L05_avg       19
# w126_rank_p_L126_avg      17
# w63_rank_p_L63_avg        16
# w126_rank_p_L05_avg       16
# w189_rank_p_L42_avg       15
# w189_rank_p_L252_avg      15
# w126_rank_p_L63_avg       15
# *****************************
# xgboost prediction - confusion matrix
#  [[114   2]
#  [ 37   0]]
# precision:  0.0
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.016
#      true_value  model_value  mkt_return   returns
# 71          0.0     0.893956    0.057947  0.022309
# 133         0.0     0.870671    0.057947 -0.008985
# 151         0.0     0.793504    0.057947  0.030402
# 40          0.0     0.767554    0.057947  0.018722
# 83          0.0     0.757903    0.057947  0.017425
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.0329
#      true_value  model_value  mkt_return   returns
# 137         0.0     0.022078    0.057947 -0.004825
# 152         0.0     0.019913    0.057947 -0.036252
# 101         0.0     0.018023    0.057947 -0.001358
# 99          0.0     0.011225    0.057947 -0.062415
# 57          0.0     0.007638    0.057947 -0.059846
# ********************************************************
# Building model to predict for  2016-12-05
# Model Eval Results:
# Training auc:  0.857964
# Evaluation auc:  0.539793
# Number of rounds:  50
# Model Variable Importance:
#                          fscore
# w252_rank_p_L252_avg         19
# w252_rank_p_L63_avg          12
# ivv_w63_rank_p_L126_avg      10
# w63_rank_p_L63_avg            9
# w126_rank_p_L252_avg          9
# w252_rank_p_L21_avg           9
# w63_rank_p_L84_avg            9
# w10_rank_p_L252_avg           9
# w84_rank_p_L63_avg            9
# rank_p_L05                    9
# *****************************
# xgboost prediction - confusion matrix
#  [[78  5]
#  [62  8]]
# precision:  0.615
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0413
#      true_value  model_value  mkt_return   returns
# 55          1.0     0.937821    0.030848  0.140577
# 84          0.0     0.925322    0.030848  0.027470
# 126         0.0     0.922060    0.030848  0.002209
# 97          1.0     0.917921    0.030848  0.050816
# 39          0.0     0.908338    0.030848 -0.014527
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0317
#      true_value  model_value  mkt_return   returns
# 151         1.0     0.123275    0.030848  0.065497
# 89          0.0     0.101716    0.030848  0.009895
# 71          1.0     0.097625    0.030848  0.071988
# 62          0.0     0.079093    0.030848  0.018229
# 49          0.0     0.074697    0.030848 -0.007029
# ********************************************************
# Building model to predict for  2017-01-05
# Model Eval Results:
# Training auc:  0.843735
# Evaluation auc:  0.617806
# Number of rounds:  47
# Model Variable Importance:
#                       fscore
# w84_rank_p_L42_avg        12
# w252_rank_p_L252_avg      12
# w63_rank_p_L63_avg         9
# w126_rank_p_L252_avg       9
# w189_rank_p_L84_avg        9
# w252_rank_p_L189_avg       9
# w126_rank_p_L189_avg       9
# w189_rank_p_L42_avg        9
# w63_rank_p_L126_avg        8
# w189_rank_p_L05_avg        8
# *****************************
# xgboost prediction - confusion matrix
#  [[82  0]
#  [71  0]]
# precision:  nan
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0228
#      true_value  model_value  mkt_return   returns
# 84          1.0     0.794751    0.011592  0.017468
# 66          1.0     0.764820    0.011592  0.025671
# 117         0.0     0.733234    0.011592  0.010482
# 135         1.0     0.726794    0.011592  0.018192
# 83          1.0     0.714155    0.011592  0.042040
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0083
#      true_value  model_value  mkt_return   returns
# 133         0.0     0.058596    0.011592 -0.024627
# 31          1.0     0.055394    0.011592  0.043210
# 151         0.0     0.051443    0.011592 -0.018622
# 71          0.0     0.047709    0.011592 -0.025810
# 138         1.0     0.038549    0.011592  0.067259
# ********************************************************
# Building model to predict for  2017-02-06
# Model Eval Results:
# Training auc:  0.803542
# Evaluation auc:  0.58658
# Number of rounds:  39
# Model Variable Importance:
#                       fscore
# w252_rank_p_L05_avg       12
# w126_rank_p_L252_avg      10
# w252_rank_p_L63_avg        9
# w252_rank_p_L252_avg       9
# w84_rank_p_L42_avg         8
# w126_rank_p_L189_avg       7
# w5_rank_p_L189_avg         7
# w189_rank_p_L252_avg       7
# w63_rank_p_L63_avg         7
# w252_rank_p_L189_avg       7
# *****************************
# xgboost prediction - confusion matrix
#  [[133   0]
#  [ 20   0]]
# precision:  nan
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: -0.0029
#      true_value  model_value  mkt_return   returns
# 63          0.0     0.790321    0.033467 -0.004422
# 141         0.0     0.789376    0.033467  0.003220
# 5           0.0     0.763882    0.033467 -0.004016
# 125         0.0     0.760376    0.033467 -0.007041
# 12          0.0     0.745342    0.033467 -0.002435
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.0234
#     true_value  model_value  mkt_return   returns
# 75         0.0     0.107318    0.033467 -0.073599
# 11         0.0     0.100358    0.033467  0.012370
# 31         0.0     0.096260    0.033467 -0.077487
# 54         0.0     0.080751    0.033467 -0.005941
# 55         0.0     0.041779    0.033467  0.027904
# ********************************************************
# Building model to predict for  2017-03-08
# Model Eval Results:
# Training auc:  0.649922
# Evaluation auc:  0.485589
# Number of rounds:  30
# Model Variable Importance:
#                       fscore
# w252_rank_p_L05_avg        9
# w252_rank_p_L252_avg       8
# w21_rank_p_L21_avg         8
# w252_rank_p_L84_avg        7
# w126_rank_p_L126_avg       7
# w84_rank_p_L42_avg         6
# w126_rank_p_L252_avg       6
# w21_rank_p_L252_avg        6
# w252_rank_p_L21_avg        6
# w42_rank_p_L21_avg         5
# *****************************
# xgboost prediction - confusion matrix
#  [[17  8]
#  [78 50]]
# precision:  0.862
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.022
#     true_value  model_value  mkt_return   returns
# 79         1.0     0.945021   -0.000638  0.050437
# 81         1.0     0.943028   -0.000638  0.030403
# 36         1.0     0.937111   -0.000638  0.015472
# 41         1.0     0.935856   -0.000638 -0.000196
# 10         1.0     0.916962   -0.000638  0.013952
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0126
#      true_value  model_value  mkt_return   returns
# 83          1.0     0.253965   -0.000638  0.009368
# 87          1.0     0.240782   -0.000638  0.013727
# 29          1.0     0.237805   -0.000638  0.047098
# 104         1.0     0.234321   -0.000638  0.005475
# 55          0.0     0.193217   -0.000638 -0.012473
# ********************************************************
# Building model to predict for  2017-04-06
# Model Eval Results:
# Training auc:  0.645458
# Evaluation auc:  0.564847
# Number of rounds:  30
# Model Variable Importance:
#                       fscore
# w21_rank_p_L21_avg         8
# w63_rank_p_L252_avg        7
# w42_rank_p_L189_avg        6
# w252_rank_p_L252_avg       6
# w63_rank_p_L126_avg        6
# w252_rank_p_L05_avg        6
# w252_rank_p_L21_avg        6
# w252_rank_p_L42_avg        5
# w42_rank_p_L252_avg        5
# ivv_rank_p_L05             5
# *****************************
# xgboost prediction - confusion matrix
#  [[84  0]
#  [69  0]]
# precision:  nan
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0156
#      true_value  model_value  mkt_return   returns
# 138         0.0     0.718120    0.018024 -0.107184
# 57          1.0     0.691393    0.018024  0.052544
# 96          1.0     0.690727    0.018024  0.026246
# 102         0.0     0.680340    0.018024  0.014173
# 33          1.0     0.643411    0.018024  0.092040
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.0054
#      true_value  model_value  mkt_return   returns
# 149         0.0     0.226577    0.018024  0.002298
# 112         1.0     0.216957    0.018024  0.028095
# 146         0.0     0.215707    0.018024 -0.002624
# 54          0.0     0.203355    0.018024  0.008972
# 32          0.0     0.181133    0.018024 -0.063862
# ********************************************************
# Building model to predict for  2017-05-08
# Model Eval Results:
# Training auc:  0.757274
# Evaluation auc:  0.596543
# Number of rounds:  34
# Model Variable Importance:
#                       fscore
# w126_rank_p_L05_avg        8
# w252_rank_p_L252_avg       8
# w252_rank_p_L05_avg        8
# w189_rank_p_L189_avg       8
# w252_rank_p_L84_avg        8
# w42_rank_p_L21_avg         7
# w63_rank_p_L252_avg        7
# w63_rank_p_L21_avg         7
# w189_rank_p_L10_avg        7
# w252_rank_p_L189_avg       7
# *****************************
# xgboost prediction - confusion matrix
#  [[68  7]
#  [78  0]]
# precision:  0.0
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: -0.0187
#      true_value  model_value  mkt_return   returns
# 137         0.0     0.867862    0.016918  0.001705
# 81          0.0     0.855481    0.016918 -0.040798
# 75          0.0     0.850109    0.016918 -0.074023
# 125         0.0     0.828588    0.016918  0.010166
# 74          0.0     0.828310    0.016918  0.009211
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0044
#     true_value  model_value  mkt_return   returns
# 89         1.0     0.175768    0.016918  0.023484
# 9          0.0     0.168388    0.016918  0.015761
# 80         1.0     0.154059    0.016918  0.039340
# 55         0.0     0.151708    0.016918 -0.066334
# 28         0.0     0.145949    0.016918  0.009941
# ********************************************************
# Building model to predict for  2017-06-07
# Model Eval Results:
# Training auc:  0.926964
# Evaluation auc:  0.652737
# Number of rounds:  82
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      31
# w63_rank_p_L252_avg       20
# w189_rank_p_L05_avg       15
# w189_rank_p_L21_avg       14
# w126_rank_p_L63_avg       14
# w63_rank_p_L126_avg       13
# w126_rank_p_L42_avg       13
# w126_rank_p_L05_avg       13
# w252_rank_p_L42_avg       13
# w84_rank_p_L21_avg        12
# *****************************
# xgboost prediction - confusion matrix
#  [[91  2]
#  [58  2]]
# precision:  0.5
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: -0.0024
#      true_value  model_value  mkt_return   returns
# 62          0.0     0.884044   -0.001747 -0.009386
# 22          1.0     0.827107   -0.001747 -0.001687
# 56          1.0     0.806120   -0.001747  0.008537
# 85          0.0     0.804901   -0.001747 -0.010050
# 105         1.0     0.754436   -0.001747  0.000356
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.0185
#      true_value  model_value  mkt_return   returns
# 138         0.0     0.095178   -0.001747 -0.115315
# 71          0.0     0.073165   -0.001747 -0.007519
# 151         0.0     0.069116   -0.001747 -0.004285
# 131         1.0     0.068197   -0.001747  0.009755
# 52          1.0     0.063282   -0.001747  0.024692
# ********************************************************
# Building model to predict for  2017-07-07
# Model Eval Results:
# Training auc:  0.954535
# Evaluation auc:  0.587712
# Number of rounds:  114
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      32
# w189_rank_p_L189_avg      23
# w189_rank_p_L252_avg      22
# w21_rank_p_L21_avg        18
# w63_rank_p_L126_avg       17
# w126_rank_p_L126_avg      17
# w252_rank_p_L42_avg       16
# w252_rank_p_L21_avg       16
# w63_rank_p_L63_avg        16
# w126_rank_p_L252_avg      15
# *****************************
# xgboost prediction - confusion matrix
#  [[76  1]
#  [75  1]]
# precision:  0.5
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0465
#      true_value  model_value  mkt_return   returns
# 134         1.0     0.838012     0.02384  0.057068
# 145         0.0     0.835141     0.02384  0.014380
# 80          1.0     0.763814     0.02384  0.049929
# 46          1.0     0.752847     0.02384  0.090909
# 142         0.0     0.752639     0.02384  0.020180
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0136
#     true_value  model_value  mkt_return   returns
# 72         1.0     0.052755     0.02384  0.072345
# 88         0.0     0.051867     0.02384 -0.019644
# 68         0.0     0.043992     0.02384 -0.000867
# 66         0.0     0.037674     0.02384  0.021186
# 84         0.0     0.028565     0.02384 -0.004970
# ********************************************************
# Building model to predict for  2017-08-07
# Model Eval Results:
# Training auc:  0.929187
# Evaluation auc:  0.645923
# Number of rounds:  84
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      34
# w252_rank_p_L42_avg       18
# w252_rank_p_L63_avg       18
# w126_rank_p_L126_avg      15
# w126_rank_p_L84_avg       15
# w189_rank_p_L126_avg      14
# w252_rank_p_L21_avg       13
# w63_rank_p_L21_avg        13
# w126_rank_p_L252_avg      13
# w189_rank_p_L63_avg       13
# *****************************
# xgboost prediction - confusion matrix
#  [[51  0]
#  [96  6]]
# precision:  1.0
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0087
#      true_value  model_value  mkt_return   returns
# 89          1.0     0.934562   -0.003647  0.010811
# 25          1.0     0.924867   -0.003647 -0.001242
# 133         1.0     0.850421   -0.003647  0.019033
# 90          1.0     0.843176   -0.003647  0.018235
# 142         1.0     0.827579   -0.003647 -0.003361
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0259
#     true_value  model_value  mkt_return   returns
# 47         0.0     0.058880   -0.003647 -0.041522
# 99         0.0     0.050175   -0.003647 -0.018086
# 69         1.0     0.046920   -0.003647  0.060331
# 48         0.0     0.038118   -0.003647 -0.003665
# 55         1.0     0.037699   -0.003647  0.132673
# ********************************************************
# Building model to predict for  2017-09-06
# Model Eval Results:
# Training auc:  0.923753
# Evaluation auc:  0.539463
# Number of rounds:  81
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      31
# w189_rank_p_L189_avg      20
# w189_rank_p_L42_avg       17
# w252_rank_p_L42_avg       15
# w252_rank_p_L84_avg       15
# w252_rank_p_L21_avg       14
# w252_rank_p_L63_avg       14
# w21_rank_p_L21_avg        13
# w126_rank_p_L126_avg      12
# w63_rank_p_L126_avg       12
# *****************************
# xgboost prediction - confusion matrix
#  [[93 11]
#  [44  5]]
# precision:  0.312
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.022
#      true_value  model_value  mkt_return   returns
# 45          0.0     0.973104    0.036537  0.022824
# 47          0.0     0.971337    0.036537 -0.014741
# 132         1.0     0.949844    0.036537  0.039657
# 33          1.0     0.915753    0.036537  0.037500
# 43          0.0     0.906839    0.036537  0.024511
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0505
#      true_value  model_value  mkt_return   returns
# 144         0.0     0.058002    0.036537 -0.010478
# 140         0.0     0.046925    0.036537 -0.001014
# 81          1.0     0.044345    0.036537  0.056768
# 75          1.0     0.043556    0.036537  0.105987
# 95          1.0     0.030036    0.036537  0.101030
# ********************************************************
# Building model to predict for  2017-10-05
# Model Eval Results:
# Training auc:  0.714175
# Evaluation auc:  0.605837
# Number of rounds:  31
# Model Variable Importance:
#                          fscore
# w189_rank_p_L126_avg          9
# w84_rank_p_L05_avg            8
# w21_rank_p_L21_avg            7
# w252_rank_p_L252_avg          7
# w252_rank_p_L10_avg           6
# w189_rank_p_L05_avg           6
# w252_rank_p_L05_avg           6
# w252_rank_p_L21_avg           6
# ivv_w189_rank_p_L05_avg       6
# ivv_w63_rank_p_L42_avg        5
# *****************************
# xgboost prediction - confusion matrix
#  [[111   0]
#  [ 42   0]]
# precision:  nan
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: -0.0
#      true_value  model_value  mkt_return   returns
# 15          0.0     0.780077    0.014822 -0.014119
# 30          1.0     0.767665    0.014822  0.017282
# 138         0.0     0.751678    0.014822  0.014659
# 102         0.0     0.744616    0.014822 -0.014020
# 85          0.0     0.741007    0.014822 -0.003892
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.0062
#      true_value  model_value  mkt_return   returns
# 92          0.0     0.107332    0.014822 -0.002523
# 122         0.0     0.106649    0.014822 -0.013872
# 65          0.0     0.103133    0.014822 -0.002084
# 124         0.0     0.075353    0.014822  0.003319
# 84          0.0     0.073919    0.014822 -0.016043
# ********************************************************
# Building model to predict for  2017-11-03
# Model Eval Results:
# Training auc:  0.793317
# Evaluation auc:  0.626871
# Number of rounds:  35
# Model Variable Importance:
#                         fscore
# w252_rank_p_L252_avg        12
# w189_rank_p_L05_avg          9
# w189_rank_p_L126_avg         8
# w189_rank_p_L252_avg         8
# ivv_w63_rank_p_L84_avg       7
# w252_rank_p_L21_avg          7
# w189_rank_p_L84_avg          7
# w189_rank_p_L21_avg          7
# w21_rank_p_L21_avg           7
# rank_p_L10                   7
# *****************************
# xgboost prediction - confusion matrix
#  [[92 27]
#  [26  8]]
# precision:  0.229
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0228
#      true_value  model_value  mkt_return   returns
# 54          0.0     0.933042    0.018487  0.006105
# 118         1.0     0.909525    0.018487  0.051119
# 132         1.0     0.909321    0.018487  0.028094
# 27          0.0     0.908529    0.018487  0.001318
# 89          1.0     0.901647    0.018487  0.027577
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.0207
#      true_value  model_value  mkt_return   returns
# 0           0.0     0.287911    0.018487 -0.011594
# 6           0.0     0.280946    0.018487 -0.009786
# 134         0.0     0.268353    0.018487  0.009583
# 139         0.0     0.258449    0.018487 -0.052727
# 87          0.0     0.209309    0.018487 -0.038826
# ********************************************************
# Building model to predict for  2017-12-05
# Model Eval Results:
# Training auc:  0.946238
# Evaluation auc:  0.576535
# Number of rounds:  100
# Model Variable Importance:
#                          fscore
# w252_rank_p_L252_avg         34
# w252_rank_p_L126_avg         18
# w189_rank_p_L252_avg         18
# w252_rank_p_L10_avg          17
# w252_rank_p_L189_avg         16
# w189_rank_p_L126_avg         16
# w189_rank_p_L189_avg         15
# ivv_w42_rank_p_L252_avg      14
# w189_rank_p_L05_avg          14
# w252_rank_p_L84_avg          14
# *****************************
# xgboost prediction - confusion matrix
#  [[44 35]
#  [20 54]]
# precision:  0.607
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0569
#      true_value  model_value  mkt_return   returns
# 42          1.0     0.988122    0.043916  0.050981
# 18          1.0     0.987395    0.043916  0.074557
# 90          1.0     0.986240    0.043916  0.046139
# 138         1.0     0.984262    0.043916  0.065003
# 50          1.0     0.982463    0.043916  0.047591
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0471
#      true_value  model_value  mkt_return   returns
# 104         1.0     0.252061    0.043916  0.063630
# 75          1.0     0.240018    0.043916  0.098219
# 68          0.0     0.209938    0.043916  0.018845
# 122         0.0     0.166147    0.043916  0.028536
# 92          0.0     0.156912    0.043916  0.026212
# ********************************************************
# Building model to predict for  2018-01-05
# Model Eval Results:
# Training auc:  0.871452
# Evaluation auc:  0.612633
# Number of rounds:  50
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      22
# w126_rank_p_L252_avg      11
# w252_rank_p_L21_avg       11
# w126_rank_p_L126_avg      10
# w252_rank_p_L84_avg       10
# w252_rank_p_L10_avg        9
# w21_rank_p_L21_avg         8
# w10_rank_p_L42_avg         8
# w189_rank_p_L126_avg       8
# w10_rank_p_L10_avg         8
# *****************************
# xgboost prediction - confusion matrix
#  [[77  4]
#  [65  7]]
# precision:  0.636
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: -0.0139
#      true_value  model_value  mkt_return   returns
# 138         0.0     0.875298   -0.014782 -0.035142
# 137         1.0     0.868354   -0.014782 -0.001240
# 34          0.0     0.849306   -0.014782 -0.021213
# 74          1.0     0.840786   -0.014782 -0.010541
# 86          1.0     0.840782   -0.014782 -0.001512
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.0171
#      true_value  model_value  mkt_return   returns
# 44          1.0     0.207610   -0.014782  0.022125
# 28          0.0     0.179272   -0.014782 -0.059233
# 143         1.0     0.174666   -0.014782  0.021816
# 75          0.0     0.165611   -0.014782 -0.063244
# 148         1.0     0.124240   -0.014782 -0.007127
# ********************************************************
# Building model to predict for  2018-02-06
# Model Eval Results:
# Training auc:  0.801201
# Evaluation auc:  0.681382
# Number of rounds:  35
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      17
# w252_rank_p_L10_avg        9
# w252_rank_p_L84_avg        8
# w252_rank_p_L42_avg        8
# w84_rank_p_L21_avg         8
# w63_rank_p_L252_avg        7
# w189_rank_p_L252_avg       7
# w10_rank_p_L10_avg         7
# w126_rank_p_L126_avg       7
# w252_rank_p_L126_avg       7
# *****************************
# xgboost prediction - confusion matrix
#  [[77 37]
#  [19 20]]
# precision:  0.351
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: -0.0012
#      true_value  model_value  mkt_return   returns
# 81          0.0     0.952428    0.017953 -0.038034
# 78          0.0     0.945931    0.017953 -0.066834
# 112         1.0     0.943241    0.017953  0.056330
# 122         1.0     0.942956    0.017953  0.026590
# 121         0.0     0.939181    0.017953  0.015801
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0299
#      true_value  model_value  mkt_return   returns
# 6           0.0     0.354576    0.017953  0.003216
# 139         1.0     0.338634    0.017953  0.078982
# 53          0.0     0.269951    0.017953 -0.008170
# 143         0.0     0.243606    0.017953  0.007930
# 83          1.0     0.203311    0.017953  0.067763
# ********************************************************
# Building model to predict for  2018-03-08
# Model Eval Results:
# Training auc:  0.864332
# Evaluation auc:  0.487167
# Number of rounds:  48
# Model Variable Importance:
#                          fscore
# w252_rank_p_L252_avg         19
# ivv_w189_rank_p_L42_avg      11
# w252_rank_p_L84_avg          11
# w126_rank_p_L42_avg           9
# w189_rank_p_L252_avg          9
# w252_rank_p_L05_avg           8
# w10_rank_p_L42_avg            8
# w63_rank_p_L10_avg            8
# w126_rank_p_L252_avg          7
# ivv_w42_rank_p_L189_avg       7
# *****************************
# xgboost prediction - confusion matrix
#  [[ 8 16]
#  [41 88]]
# precision:  0.846
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: -0.0089
#      true_value  model_value  mkt_return   returns
# 138         1.0     0.986812   -0.044343  0.000643
# 86          1.0     0.977734   -0.044343  0.002809
# 141         1.0     0.976201   -0.044343 -0.001813
# 55          0.0     0.972294   -0.044343 -0.049470
# 140         1.0     0.972000   -0.044343  0.003206
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.0415
#      true_value  model_value  mkt_return   returns
# 118         1.0     0.512280   -0.044343 -0.034047
# 70          0.0     0.509919   -0.044343 -0.086574
# 95          1.0     0.454091   -0.044343 -0.022520
# 75          1.0     0.365122   -0.044343  0.026641
# 57          0.0     0.312107   -0.044343 -0.090860
# ********************************************************
# Building model to predict for  2018-04-09
# Model Eval Results:
# Training auc:  0.820642
# Evaluation auc:  0.595429
# Number of rounds:  38
# Model Variable Importance:
#                          fscore
# w252_rank_p_L252_avg         17
# ivv_w21_rank_p_L252_avg      10
# w252_rank_p_L126_avg          9
# ivv_w42_rank_p_L189_avg       9
# w252_rank_p_L63_avg           8
# ivv_w189_rank_p_L42_avg       8
# w189_rank_p_L189_avg          7
# w21_rank_p_L05_avg            7
# w63_rank_p_L21_avg            7
# w252_rank_p_L05_avg           7
# *****************************
# xgboost prediction - confusion matrix
#  [[86 26]
#  [33  8]]
# precision:  0.235
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0031
#      true_value  model_value  mkt_return   returns
# 73          0.0     0.945301    0.022764 -0.012912
# 138         0.0     0.934095    0.022764 -0.003213
# 25          0.0     0.904700    0.022764  0.018200
# 132         0.0     0.902110    0.022764  0.012972
# 43          0.0     0.893893    0.022764  0.000292
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0026
#      true_value  model_value  mkt_return   returns
# 40          0.0     0.363935    0.022764  0.017911
# 45          0.0     0.337106    0.022764 -0.008380
# 104         0.0     0.331782    0.022764 -0.011566
# 31          0.0     0.286265    0.022764  0.002107
# 58          0.0     0.262527    0.022764  0.012999
# ********************************************************
# Building model to predict for  2018-05-08
# Model Eval Results:
# Training auc:  0.819457
# Evaluation auc:  0.576244
# Number of rounds:  39
# Model Variable Importance:
#                          fscore
# w252_rank_p_L252_avg         15
# w252_rank_p_L63_avg          14
# w252_rank_p_L05_avg          10
# w189_rank_p_L252_avg         10
# w189_rank_p_L10_avg           8
# w189_rank_p_L189_avg          8
# w252_rank_p_L21_avg           7
# w252_rank_p_L42_avg           7
# ivv_w126_rank_p_L63_avg       7
# ivv_w21_rank_p_L252_avg       7
# *****************************
# xgboost prediction - confusion matrix
#  [[75 47]
#  [22  9]]
# precision:  0.161
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0056
#      true_value  model_value  mkt_return   returns
# 138         0.0     0.949498    0.039378  0.013540
# 85          0.0     0.932845    0.039378 -0.007260
# 69          0.0     0.925572    0.039378 -0.014263
# 123         0.0     0.916724    0.039378 -0.035745
# 70          1.0     0.910813    0.039378  0.071770
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0298
#      true_value  model_value  mkt_return   returns
# 96          1.0     0.522609    0.039378  0.062684
# 78          0.0     0.517359    0.039378  0.004237
# 112         1.0     0.492199    0.039378  0.063473
# 62          0.0     0.470115    0.039378 -0.005666
# 75          0.0     0.431851    0.039378  0.024161
# ********************************************************
# Building model to predict for  2018-06-07
# Model Eval Results:
# Training auc:  0.892692
# Evaluation auc:  0.612862
# Number of rounds:  64
# Model Variable Importance:
#                       fscore
# w252_rank_p_L252_avg      31
# w252_rank_p_L63_avg       17
# w189_rank_p_L252_avg      16
# w252_rank_p_L42_avg       13
# w252_rank_p_L126_avg      12
# w252_rank_p_L84_avg       11
# w126_rank_p_L189_avg      10
# w252_rank_p_L189_avg      10
# ivv_rank_p_L05            10
# w252_rank_p_L21_avg       10
# *****************************
# xgboost prediction - confusion matrix
#  [[44 53]
#  [36 20]]
# precision:  0.274
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.0175
#      true_value  model_value  mkt_return   returns
# 71          1.0     0.973174    0.006674  0.042953
# 151         1.0     0.971558    0.006674  0.041643
# 138         0.0     0.952729    0.006674 -0.034987
# 133         1.0     0.951134    0.006674  0.046386
# 22          0.0     0.941597    0.006674 -0.008615
# Model Bottom 5 Picks
#  Avg rtn bottom 5: -0.0121
#      true_value  model_value  mkt_return   returns
# 13          1.0     0.416684    0.006674  0.010422
# 31          0.0     0.369958    0.006674 -0.064151
# 94          1.0     0.351154    0.006674  0.022475
# 139         0.0     0.316889    0.006674 -0.045480
# 87          1.0     0.170570    0.006674  0.016114
# ********************************************************
# Building model to predict for  2018-07-09
# Model Eval Results:
# Training auc:  0.844852
# Evaluation auc:  0.473767
# Number of rounds:  43
# Model Variable Importance:
#                          fscore
# w252_rank_p_L252_avg         16
# w252_rank_p_L63_avg          11
# w189_rank_p_L252_avg         11
# w126_rank_p_L42_avg          11
# ivv_w21_rank_p_L252_avg      10
# w252_rank_p_L10_avg           9
# w63_rank_p_L05_avg            8
# w84_rank_p_L42_avg            8
# w189_rank_p_L189_avg          7
# w126_rank_p_L126_avg          7
# *****************************
# xgboost prediction - confusion matrix
#  [[83 41]
#  [19 10]]
# precision:  0.196
# *****************************
# Model Top 5 Picks
#  Avg rtn top 5: 0.007
#     true_value  model_value  mkt_return   returns
# 11         0.0     0.973264    0.027376 -0.014706
# 16         0.0     0.964194    0.027376  0.002942
# 46         1.0     0.961844    0.027376  0.035387
# 17         0.0     0.960229    0.027376  0.012281
# 6          0.0     0.938943    0.027376 -0.001107
# Model Bottom 5 Picks
#  Avg rtn bottom 5: 0.0194
#      true_value  model_value  mkt_return   returns
# 109         1.0     0.156940    0.027376  0.027376
# 93          0.0     0.153600    0.027376  0.002592
# 116         0.0     0.132707    0.027376  0.022790
# 13          0.0     0.128704    0.027376  0.021978
# 105         0.0     0.115796    0.027376  0.022437
# ********************************************************
